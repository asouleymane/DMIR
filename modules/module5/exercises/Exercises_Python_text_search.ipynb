# %% [markdown]
# # Exercise: Building and Loading Text Search in Python Whoosh
#
#
# ## OUTLINE
#  1. [Whoosh](#Whoosh_text)
#  1. [Task at hand](#task)
#  1. [Buiding our Whoosh Schema](#build_it)
#  1. [Loading Data](#load_it)
#  1. [Executing Queries, Google-lite...very very lite](#search_me)

# %% [markdown]
# ---
# <a id='Whoosh_text' ></a>
#
# ## Whoosh
#
# Whoosh was started as a quick and dirty search server for the online documentation of the Houdini 3D animation software package.
# Side Effects Software generously allowed the code to be open source, in case it might be useful to anyone else who needs a very flexible or pure-Python search engine (or both!).
#
#   * Whoosh is fast, but uses only pure Python, so it will run anywhere Python runs, without requiring a compiler.
#   * By default, Whoosh uses the Okapi BM25F ranking function, but like most things the ranking function can be easily customized.
#   * Whoosh creates fairly small indexes compared to many other search libraries.
#   * All indexed text in Whoosh must be unicode.
#   * Whoosh lets you store arbitrary Python objects with indexed documents.
#
# ### What is Whoosh?
#
# Whoosh is a fast, pure Python search engine library.
#
# The primary design impetus of Whoosh is that it is pure Python.
# You should be able to use Whoosh anywhere you can use Python, no compiler or Java required.
#
# Like one of its ancestors, Lucene, Whoosh is not really a search engine, it’s a programmer library for creating a search engine.
#
# Practically no important behavior of Whoosh is hard-coded.
# Indexing of text, the level of information stored for each term in each field, parsing of search queries, the types of queries allowed, scoring algorithms, etc. are all customizable, replaceable, and extensible.

# %% [markdown]
# ---
# <a id='task' ></a>
#
# ## Task at hand
#
# For this lab, we are going to walk through the process of creating full text search capability within Python for integration into other analytical processes.
#
# You previously read about the _`book`_ data and you have seen the data used for a corpus in a PostgreSQL full text search.
# Now, we are going to walk through the similar process to build the search engine in pure Python.
# The process will take very little time and the useability of the full text search is multiplied by degree of heterogeneous data that can be integrated with the full text search.
#
# Throughout these steps, try to recognize the similarities to the PostgreSQL process.

# %% [markdown]
# ---
# <a id='build_it' ></a>
#
# ## Buiding our Whoosh Schema
#
# Recall, the `book/` folder is composed of a collection of text files, each its own book chapter.
#
# In whoosh, we structure the retrieval system by defining a storage schema.
#
# From the lab with the text files:
# ```
# from whoosh.fields import Schema, TEXT, KEYWORD, ID, STORED
# from whoosh.analysis import StemmingAnalyzer
#
# schema = Schema(filename=ID(stored=True),
#                 content=TEXT(analyzer=StemmingAnalyzer())
#                 )
# ```
#
# This tells us we are defining records to have a `(filename, content)`
#
# ### 1) For this exercise, you should look at a few of these web pages:
#
#   * https://en.wikipedia.org/wiki/Nyctimantis
#   * https://en.wikipedia.org/wiki/Osteocephalus
#   * https://en.wikipedia.org/wiki/Osteopilus
#
# Specifically, inspect the HTML source and the
# ```HTML
# <table class="infobox biota" ... </table>
# ```
#
# You need to extend the schema definition to collec the table data when available.

# %%
from whoosh.fields import Schema,TEXT,KEYWORD,ID,STORED
from whoosh.analysis import StemmingAnalyzer
schema = Schema(filename=ID(stored=True),
                content=TEXT(analyzer=StemmingAnalyzer(),stored=True),
                kingdom=TEXT(analyzer=StemmingAnalyzer(),stored=True),
                phylum=TEXT(analyzer=StemmingAnalyzer(),stored=True),
                class_=TEXT(analyzer=StemmingAnalyzer(),stored=True),
                order=TEXT(analyzer=StemmingAnalyzer(),stored=True),
                family=TEXT(analyzer=StemmingAnalyzer(),stored=True),
                genus=TEXT(analyzer=StemmingAnalyzer(),stored=True)
               )

# %% [markdown]
# ---
# <a id='load_it' ></a>
#
# ## Loading Data
#
# For this exercise, we have created a small folder of a few Wikipedia pages under the `en.wikipedia.org/wiki` folder:
#
# ```Bash
# [scottgs@metal exercises]$ ls en.wikipedia.org/wiki
# Acris.html           Ecnomiohyla.html      Myersiohyla.html    Scinax.html
# Anotheca.html        Exerodonta.html       Nyctimantis.html    Smilisca.html
# Aparasphenodon.html  Hyla.html             Osteocephalus.html  Sphaenorhynchus.html
# Aplastodiscus.html   Hylidae.html          Osteopilus.html     Tepuihyla.html
# Argenteohyla.html    Hylinae.html          Phyllodytes.html    Tlalocohyla.html
# Bokermannohyla.html  Hyloscirtus.html      Phytotriades.html   Trachycephalus.html
# Bromeliohyla.html    Hypsiboas.html        Plectrohyla.html    Triprion.html
# Charadrahyla.html    Isthmohyla.html       Pseudacris.html     Xenohyla.html
# Corythomantis.html   Itapotihyla.html      Pseudis.html
# Dendropsophus.html   Lysapsus.html         Ptychohyla.html
# Duellmanohyla.html   Megastomatohyla.html  Scarthyla.html
#
# ```
# You will create the _whoosh_ index files in the folder then ingest the files.
#
# To load the data, a python script with follow the basic crawling behavior
#
#  1. For each file/folder in the specified starting folder:
#  1. If it is a folder, recurse into folder and process contents
#  1. If it is a file, read contents and load into indexer.
#
# ## Follow the lab for Python IR with whoosh to complete this exercise.
#
# ### Step 2) Create / Initialize the whoosh index and get the `writer` object.

# %%
import os, os.path
from whoosh import index

# Step 1 below this comment"
ix = index.create_in("en.wikipedia.org/wiki",schema)
#Get a writer from the created index
writer = ix.writer()

# %% [markdown]
# ### 3) Adapt the helper functions
#
# Note the subtle changes.
# Please adapt the code below such as provided recursive parsing of the HTML (.html) files, indexing with the Whoosh API.
# Trust no code, verify all code segments.

# %%
import bs4
import re
from sklearn.feature_extraction.text import CountVectorizer
import pprint

# %%
def visible(element):
    if element.parent.name in ['style', 'script', '[document]', 'head', 'title']:
        return False
    elif re.match('<!--.*-->', str(element)):
        return False
    return True


def loadFile(writer, fname):
    '''
    Read file contents, load into database.
    '''
    with open(fname, 'r') as infile:
        content=infile.read()
        soup = bs4.BeautifulSoup(content, 'html.parser')
        texts = soup.findAll(text=True)
        
        # Process all the visible text
        visible_texts = filter(visible, texts)
        # TODO: Assemble all visible_texts into a content string
        visible_content=""
        for line in visible_texts:
            visible_content += "" + line.strip ("\n")
            print(line)

        # TODO: Process the "<table class="infobox biota" ... </table> data
        table = soup.find('table', class_='infobox biota')
        
        # Write to the index
        writer.add_document(filename=fname, content=visible_content, 
                        kingdom=table.get('kingdom'), 
                        phylum=table.get('phylum'), 
                        class_=table.get('class'),
                        family=table.get('family'),
                        genus=table.get('genus'), 
                        )  
        print("Indexed: ", fname)

def processFolder(writer,folder):
    '''
    Process a folder for files and subfolders
    '''
    print('Processing folder: ',folder)
    for root, dirs, files in os.walk(folder):
        print("root = ", root)
        # Process Files
        for file in files:
            if file.endswith(".html"):
                filename = os.path.join(root, file)
                print('Processing File:',filename)
                loadFile(writer,filename)
            else:
                print("Unhandled File")
        # Recurse into subfolders
        for d in dirs:
            print("recursing into ",d)
            processFolder(writer,d)

#processFolder(writer,"en.wikipedia.org/wiki")
#writer.commit() # save changes

# %% [markdown]
# ### 4) Parse with our defined functions in place.

# %%
# Start processing the folder and commit the work
# -----------------------------------------------
import pandas as pd
from bs4 import BeautifulSoup
from html.parser import HTMLParser

processFolder(writer,"en.wikipedia.org/wiki")
writer.commit() # save changes
# Out:
# Processing folder:  en.wikipedia.org/wiki
# root =  en.wikipedia.org/wiki
# Processing File: en.wikipedia.org/wiki/Acris.html
#
#
#
#
#
#
#
#
#
#
#
#
#
#  CentralNotice
#
#
#
#
#
#
# Cricket frog
#
#
#
#
# From Wikipedia, the free encyclopedia
#
#
#   (Redirected from
# Acris
# )
#
#
#
# 					Jump to:
# navigation
# ,
# search
#
#
#
#
# For other uses, see
# Cricket frog (disambiguation)
# .
#
#
# "Acris" redirects here. For the Romanian village, see
# Acriş
# .
#
#
#
#
#
#
#
#
# Cricket frogs
#
#
#
#
#
#
#
#
#
#
#
#
# Acris gryllus
#
#
#
#
#
#
# Scientific classification
#
#
#
#
#
#
# Kingdom:
#
#
# Animalia
#
#
#
#
#
#
# Phylum:
#
#
# Chordata
#
#
#
#
#
#
# Class:
#
#
# Amphibia
#
#
#
#
#
#
# Order:
#
#
# Anura
#
#
#
#
#
#
# Family:
#
#
# Hylidae
#
#
#
#
#
#
# Genus:
#
#
# Acris
#
#
# Duméril
#  &
# Bibron
# , 1841
#
#
#
#
#
#
# Species
#
#
#
#
#
#
#
#
#
#
# Acris blanchardi
#
#
# Acris crepitans
#
#
# Acris gryllus
#
#
#
#
#
#
#
#
#
#
#
#
# Cricket frogs
# , genus
# Acris
# , are small,
# North American
#
# frogs
#  of the family
# Hylidae
# . They are more aquatic than other members of the family, and are generally associated with permanent bodies of water with surface vegetation. The
# common
#  and
# scientific names
#  refer to their call, which resembles that of a
# cricket
# .
#
#
# Species
# [
# edit
# ]
#
#
#
#
# A. crepitans
#
# (Baird, 1854)
#  – northern cricket frog
#
#
#
# A. c. blanchardi
#  (
# Harper
# , 1947)-
# Blanchard's cricket frog
#
#
# A. c. crepitans
#  (
# Baird
# , 1854) - eastern cricket frog
#
#
# A. c. paludicola
#  (Burger, Smith and Smith, 1949) - coastal cricket frog
#
#
#
#
#
#
# A. gryllus
#
# (LeConte, 1825)
#  - southern cricket frog
#
#
#
#
# Notes
# [
# edit
# ]
#
#
#
#
#
#
# Frost, Darrel R
# . 2007. Amphibian Species of the World: an Online Reference. Version 5.1 (10 October, 2007).
# Acris
# . Electronic Database accessible at
# http://research.amnh.org/herpetology/amphibia/index.php
# .
# [
# permanent dead link
# ]
#  American Museum of Natural History, New York, USA. (Accessed: Apr 21, 2008).
#
#
# AmphibiaWeb: Information on amphibian biology and conservation.
#  [web application]. 2008. Berkeley, California:
# Acris
# . AmphibiaWeb, available at
# http://web.archive.org/web/20040827082534/http://www.amphibiaweb.org:80/
#  (Accessed: Apr 21, 2008).
#
#
# eol - Encyclopedia of Life
#  taxon
# Acris
#  at
# http://www.eol.org
# .
#
#
#
#
# External links
# [
# edit
# ]
#
#
#  Data related to
# Acris
#  at Wikispecies
#  Media related to
# Acris
#  at Wikimedia Commons
#
#
#
#
#
#
#
#
# This
# Hylinae
#  article is a
# stub
# . You can help Wikipedia by
# expanding it
# .
#
#
#
#
#
#
# v
#
#
# t
#
#
# e
#
#
#
#
#
#
#
#
#
#
#
#
#
# NewPP limit report
# Parsed by mw1300
# Cached time: 20170311143017
# Cache expiry: 2592000
# Dynamic content: false
# CPU time usage: 0.168 seconds
# Real time usage: 0.225 seconds
# Preprocessor visited node count: 3215/1000000
# Preprocessor generated node count: 0/1500000
# Post‐expand include size: 14212/2097152 bytes
# Template argument size: 2954/2097152 bytes
# Highest expansion depth: 24/40
# Expensive parser function count: 2/500
# Lua time usage: 0.045/10.000 seconds
# Lua memory usage: 2.1 MB/50 MB
#
#
#
#
# Transclusion expansion time report (%,ms,calls,template)
# 100.00%  203.773      1 -total
#  48.02%   97.856      1 Template:Taxobox
#  42.13%   85.851      1 Template:Taxobox/core
#  26.91%   54.842     14 Template:Taxobox_colour
#  23.49%   47.875     14 Template:Delink
#  15.72%   32.031      1 Template:Otheruses
#  13.02%   26.537      1 Template:If_empty
#  12.73%   25.937      1 Template:Dead_link
#  11.03%   22.473     11 Template:Sets_taxobox_colour
#  10.97%   22.346      1 Template:Fix
#
#
#
#  Saved in parser cache with key enwiki:pcache:idhash:2953907-0!*!0!!*!4!* and timestamp 20170311143017 and revision id 730810557
#
#
#
#
#
# 						Retrieved from "
# https://en.wikipedia.org/w/index.php?title=Cricket_frog&oldid=730810557
# "
#
#
# Categories
# :
# Hylinae
# Acris
# Hylinae stubs
# Hidden categories:
# Articles with 'species' microformats
# All articles with dead external links
# Articles with dead external links from July 2016
# Articles with permanently dead external links
# Commons category with local link same as on Wikidata
# All stub articles
#
#
#
#
#
#
#
#
#
# Navigation menu
#
#
#
#
#
#
# Personal tools
#
#
#
#
# Not logged in
# Talk
# Contributions
# Create account
# Log in
#
#
#
#
#
#
#
#
#
# Namespaces
#
#
#
#
# Article
#
#
# Talk
#
#
#
#
#
#
#
#
#
#
# Variants
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Views
#
#
#
#
# Read
#
#
# Edit
#
#
# View history
#
#
#
#
#
#
#
#
# More
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Navigation
#
#
#
#
#
#
# Main page
# Contents
# Featured content
# Current events
# Random article
# Donate to Wikipedia
# Wikipedia store
#
#
#
#
#
#
#
#
#
# Interaction
#
#
#
#
#
#
# Help
# About Wikipedia
# Community portal
# Recent changes
# Contact page
#
#
#
#
#
#
#
#
#
# Tools
#
#
#
#
#
#
# What links here
# Related changes
# Upload file
# Special pages
# Permanent link
# Page information
# Wikidata item
# Cite this page
#
#
#
#
#
#
#
#
#
# Print/export
#
#
#
#
#
#
# Create a book
# Download as PDF
# Printable version
#
#
#
#
#
#
#
#
#
# In other projects
#
#
#
#
#
#
# Wikimedia Commons
# Wikispecies
#
#
#
#
#
#
#
#
#
# Languages
#
#
#
#
#
#
# Azərbaycanca
# Català
# Cebuano
# Español
# Euskara
# Français
# Italiano
# Lietuvių
# Magyar
# Nederlands
# Occitan
# Polski
# Português
# Русский
# Simple English
# Svenska
# Tiếng Việt
# Winaray
#
#
#
# Edit links
#
#
#
#
#
#
#
#
#
#
#
#
#
#  This page was last modified on 21 July 2016, at 07:35.
#
#
# Text is available under the
# Creative Commons Attribution-ShareAlike License
# ;
# additional terms may apply.  By using this site, you agree to the
# Terms of Use
#  and
# Privacy Policy
# . Wikipedia® is a registered trademark of the
# Wikimedia Foundation, Inc.
# , a non-profit organization.
#
#
#
#
#
#
# Privacy policy
#
#
# About Wikipedia
#
#
# Disclaimers
#
#
# Contact Wikipedia
#
#
# Developers
#
#
# Cookie statement
#
#
# Mobile view
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Indexed:  en.wikipedia.org/wiki/Acris.html
# Processing File: en.wikipedia.org/wiki/Anotheca.html
#
#
#
#
#
#
#
#
#
#
#
#
#
#  CentralNotice
#
#
#
#
#
#
# Spiny-headed tree frog
#
#
#
#
# From Wikipedia, the free encyclopedia
#
#
#   (Redirected from
# Anotheca
# )
#
#
#
# 					Jump to:
# navigation
# ,
# search
#
#
#
#
#
#
#
#
#
#
# Spiny-headed tree frog
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Conservation status
#
#
#
#
#
#
#
#
#
#
#
#
# Least Concern
#  (
# IUCN 3.1
# )
#
#
#
#
#
#
#
#
# Scientific classification
#
#
#
#
#
#
# Kingdom:
#
#
# Animalia
#
#
#
#
#
#
# Phylum:
#
#
# Chordata
#
#
#
#
#
#
# Class:
#
#
# Amphibia
#
#
#
#
#
#
# Order:
#
#
# Anura
#
#
#
#
#
#
# Family:
#
#
# Hylidae
#
#
#
#
#
#
# Genus:
#
#
# Anotheca
#
#
# Smith
# , 1939
#
#
#
#
#
#
# Species:
#
#
# A. spinosa
#
#
#
#
#
#
# Binomial name
#
#
#
#
#
#
# Anotheca spinosa
#
#
# (
# Steindachner
# , 1864)
#
#
#
#
#
#
# Synonyms
#
#
#
#
#
#
#
#
# Gastrotheca coronata
#  Stejneger, 1911
#
#
#
#
#
#
#
#
#
#
# The
# spiny-headed tree frog
# ,
# Anotheca spinosa
# , is a species of
# frog
#  in the
# Hylidae
#  family. It is
# monotypic
#  within the genus
# Anotheca
# .
# [
# citation needed
# ]
#  It is found in
# Costa Rica
# ,
# Honduras
# ,
# Mexico
# , and
# Panama
# , and its natural
# habitats
#  are subtropical or tropical moist lowland
# forests
#  and subtropical or tropical moist
# montane forests
# .
# [1]
#  It is threatened by
# habitat loss
# .
#
#
# This species is large (58 to 80 mm), with numerous sharp, pointed projections on the head and dorsal surface, hence the common name.
# [2]
#
#
# References
# [
# edit
# ]
#
#
#
#
#
#
# ^
#
# Santos-Barrera, G., Flores-Villela, O., Solís, F., Ibáñez, R., Savage, J. & Chaves, G. 2004.
# Anotheca spinosa
# .
# 2006 IUCN Red List of Threatened Species.
#  Downloaded on 21 July 2007.
#
#
# ^
#
# http://biogeodb.stri.si.edu/amphibians/en/species/7/
#
#
#
#
#
#
#
#
#
#
#
#
# Wikimedia Commons has media related to
# Anotheca spinosa
# .
#
#
#
#
#
#
#
#
#
#
#
#
# This
# Hylinae
#  article is a
# stub
# . You can help Wikipedia by
# expanding it
# .
#
#
#
#
#
#
# v
#
#
# t
#
#
# e
#
#
#
#
#
#
#
#
#
#
#
#
#
# NewPP limit report
# Parsed by mw1213
# Cached time: 20170219111110
# Cache expiry: 2592000
# Dynamic content: false
# CPU time usage: 0.224 seconds
# Real time usage: 0.275 seconds
# Preprocessor visited node count: 3387/1000000
# Preprocessor generated node count: 0/1500000
# Post‐expand include size: 17734/2097152 bytes
# Template argument size: 3016/2097152 bytes
# Highest expansion depth: 24/40
# Expensive parser function count: 1/500
# Lua time usage: 0.065/10.000 seconds
# Lua memory usage: 2.18 MB/50 MB
#
#
#
#
# Transclusion expansion time report (%,ms,calls,template)
# 100.00%  250.825      1 -total
#  64.89%  162.754      1 Template:Taxobox
#  60.03%  150.568      1 Template:Taxobox/core
#  37.65%   94.439     15 Template:Delink
#  37.25%   93.420     14 Template:Taxobox_colour
#  16.52%   41.432      1 Template:Citation_needed
#  16.51%   41.401      1 Template:If_empty
#  14.82%   37.173      1 Template:Fix
#  14.38%   36.067      7 Template:Taxonomy
#  14.29%   35.852     11 Template:Sets_taxobox_colour
#
#
#
#  Saved in parser cache with key enwiki:pcache:idhash:12371723-0!*!0!*!*!4!* and timestamp 20170219111110 and revision id 732559906
#
#
#
#
#
# 						Retrieved from "
# https://en.wikipedia.org/w/index.php?title=Spiny-headed_tree_frog&oldid=732559906
# "
#
#
# Categories
# :
# IUCN Red List least concern species
# Hylinae
# Animals described in 1911
# Hylinae stubs
# Hidden categories:
# Articles with 'species' microformats
# All articles with unsourced statements
# Articles with unsourced statements from November 2011
# Commons category with local link same as on Wikidata
# All stub articles
#
#
#
#
#
#
#
#
#
# Navigation menu
#
#
#
#
#
#
# Personal tools
#
#
#
#
# Not logged in
# Talk
# Contributions
# Create account
# Log in
#
#
#
#
#
#
#
#
#
# Namespaces
#
#
#
#
# Article
#
#
# Talk
#
#
#
#
#
#
#
#
#
#
# Variants
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Views
#
#
#
#
# Read
#
#
# Edit
#
#
# View history
#
#
#
#
#
#
#
#
# More
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Navigation
#
#
#
#
#
#
# Main page
# Contents
# Featured content
# Current events
# Random article
# Donate to Wikipedia
# Wikipedia store
#
#
#
#
#
#
#
#
#
# Interaction
#
#
#
#
#
#
# Help
# About Wikipedia
# Community portal
# Recent changes
# Contact page
#
#
#
#
#
#
#
#
#
# Tools
#
#
#
#
#
#
# What links here
# Related changes
# Upload file
# Special pages
# Permanent link
# Page information
# Wikidata item
# Cite this page
#
#
#
#
#
#
#
#
#
# Print/export
#
#
#
#
#
#
# Create a book
# Download as PDF
# Printable version
#
#
#
#
#
#
#
#
#
# In other projects
#
#
#
#
#
#
# Wikimedia Commons
# Wikispecies
#
#
#
#
#
#
#
#
#
# Languages
#
#
#
#
#
#
# Azərbaycanca
# Български
# Català
# Cebuano
# Deutsch
# Español
# Euskara
# Français
# Italiano
# Magyar
# Nederlands
# Polski
# Português
# Svenska
# Tiếng Việt
# Winaray
#
#
#
# Edit links
#
#
#
#
#
#
#
#
#
#
#
#
#
#  This page was last modified on 1 August 2016, at 19:29.
#
#
# Text is available under the
# Creative Commons Attribution-ShareAlike License
# ;
# additional terms may apply.  By using this site, you agree to the
# Terms of Use
#  and
# Privacy Policy
# . Wikipedia® is a registered trademark of the
# Wikimedia Foundation, Inc.
# , a non-profit organization.
#
#
#
#
#
#
# Privacy policy
#
#
# About Wikipedia
#
#
# Disclaimers
#
#
# Contact Wikipedia
#
#
# Developers
#
#
# Cookie statement
#
#
# Mobile view
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Indexed:  en.wikipedia.org/wiki/Anotheca.html
# Processing File: en.wikipedia.org/wiki/Aparasphenodon.html
#
#
#
#
#
#
#
#
#
#
#
#
#
#  CentralNotice
#
#
#
#
#
#
# Aparasphenodon
#
#
#
#
# From Wikipedia, the free encyclopedia
#
#
#
#
#
# 					Jump to:
# navigation
# ,
# search
#
#
#
#
#
#
#
#
#
#
# Aparasphenodon
#
#
#
#
#
#
# Scientific classification
#
#
#
#
#
#
# Kingdom:
#
#
# Animalia
#
#
#
#
#
#
# Phylum:
#
#
# Chordata
#
#
#
#
#
#
# Class:
#
#
# Amphibia
#
#
#
#
#
#
# Order:
#
#
# Anura
#
#
#
#
#
#
# Family:
#
#
# Hylidae
#
#
#
#
#
#
# Genus:
#
#
# Aparasphenodon
#
#
# Miranda-Ribeiro
# , 1920
#
#
#
#
#
#
# Species
#
#
#
#
#
#
#
#
# See text.
#
#
#
#
#
#
#
#
#
#
# Aparasphenodon
#  is a genus of
# frogs
#  in the
# Hylidae
#  family, and are found in southeastern
# Brazil
# , the
# Orinoco Basin
# ,
# Venezuela
#  and
# Colombia
# . These are tree-dwelling species usually hiding in the cisterns of
# epiphytic
#
# bromeliads
# . The top of the head carries a bony plate which is fused with the skin.
#
#
# Species
# [
# edit
# ]
#
#
# The genus is composed of five species:
#
#
#
#
#
#
# Binomial Name and Author
#
#
# Common Name
#
#
#
#
#
#
# Aparasphenodon arapapa
#
# Pimenta, Napoli & Haddad, 2009
#
#
#
#
#
#
#
#
# Aparasphenodon bokermanni
#
# Pombal, 1993
#
#
# Bokermann's casque-headed frog
#
#
#
#
#
#
# Aparasphenodon brunoi
#
# Miranda-Ribeiro, 1920
#
#
# Bruno's casque-headed frog
#
#
#
#
#
#
# Aparasphenodon pomba
#
# Assis, Santana, Silva, Quintela, and Feio, 2013
#
#
#
#
#
#
#
#
# Aparasphenodon venezolanus
#
# (Mertens, 1950)
#
#
# Venezuela casque-headed frog
#
#
#
#
#
#
# References
# [
# edit
# ]
#
#
#
#
# Trueb, L.
#  (1970b): The evolutionary relationships of casque-headed treefrogs with co-ossified skulls (family Hylidae). -
# Univ. Kansas Publ. Mus. Nat. Hist
# .
# 18
# , pp. [547-716]
#
#
#
#
# External links
# [
# edit
# ]
#
#
#
#
# Frost, Darrel R
# . 2007. Amphibian Species of the World: an Online Reference. Version 5.1 (10 October, 2007).
# Aparasphenodon
# [
# permanent dead link
# ]
# . Electronic Database accessible at
# https://web.archive.org/web/20071024033938/http://research.amnh.org:80/herpetology/amphibia/index.php
# . American Museum of Natural History, New York, USA. (Accessed: Apr 24, 2008).
#
#
# AmphibiaWeb: Information on amphibian biology and conservation.
#  [web application]. 2008. Berkeley, California:
# Aparasphenodon
# . AmphibiaWeb, available at
# http://amphibiaweb.org/
# . (Accessed: Apr 24, 2008).
#
#
# eol - Encyclopedia of Life
#  taxon
# Aparasphenodon
#  at
# http://www.eol.org
# .
#
#
# ITIS - Integrated Taxonomic Information System on-line database
#  Taxon
# Aparasphenodon
#  at
# https://web.archive.org/web/20160606043808/http://www.itis.gov/index.html
# . (Accessed: Apr 24, 2008).
#
#
# GBIF - Global Biodiversity Information Facility
#  Taxon
# Aparasphenodon
#  at
# https://web.archive.org/web/20080501142231/http://data.gbif.org:80/welcome.htm
#
#
#
#
#
#
#
#
#
#
#
#
# This
# Hylinae
#  article is a
# stub
# . You can help Wikipedia by
# expanding it
# .
#
#
#
#
#
#
# v
#
#
# t
#
#
# e
#
#
#
#
#
#
#
#
#
#
#
#
#
# NewPP limit report
# Parsed by mw1166
# Cached time: 20170311225524
# Cache expiry: 2592000
# Dynamic content: false
# CPU time usage: 0.156 seconds
# Real time usage: 0.185 seconds
# Preprocessor visited node count: 2991/1000000
# Preprocessor generated node count: 0/1500000
# Post‐expand include size: 11744/2097152 bytes
# Template argument size: 2750/2097152 bytes
# Highest expansion depth: 24/40
# Expensive parser function count: 1/500
# Lua time usage: 0.044/10.000 seconds
# Lua memory usage: 2.1 MB/50 MB
#
#
#
#
# Transclusion expansion time report (%,ms,calls,template)
# 100.00%  166.142      1 -total
#  66.60%  110.649      1 Template:Taxobox
#  58.07%   96.479      1 Template:Taxobox/core
#  39.32%   65.323     14 Template:Taxobox_colour
#  34.35%   57.064     14 Template:Delink
#  20.19%   33.552      1 Template:If_empty
#  17.47%   29.028     11 Template:Sets_taxobox_colour
#  14.61%   24.280      6 Template:Taxonomy
#  13.70%   22.760      1 Template:Dead_link
#  11.34%   18.836      1 Template:Fix
#
#
#
#  Saved in parser cache with key enwiki:pcache:idhash:2969740-0!*!*!!*!4!* and timestamp 20170311225524 and revision id 752402429
#
#
#
#
#
# 						Retrieved from "
# https://en.wikipedia.org/w/index.php?title=Aparasphenodon&oldid=752402429
# "
#
#
# Categories
# :
# Hylinae stubs
# Aparasphenodon
# Hylinae
# Amphibians of South America
# Amphibian genera
# Taxa named by Alípio de Miranda-Ribeiro
# Hidden categories:
# Articles with 'species' microformats
# All articles with dead external links
# Articles with dead external links from October 2016
# Articles with permanently dead external links
# All stub articles
#
#
#
#
#
#
#
#
#
# Navigation menu
#
#
#
#
#
#
# Personal tools
#
#
#
#
# Not logged in
# Talk
# Contributions
# Create account
# Log in
#
#
#
#
#
#
#
#
#
# Namespaces
#
#
#
#
# Article
#
#
# Talk
#
#
#
#
#
#
#
#
#
#
# Variants
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Views
#
#
#
#
# Read
#
#
# Edit
#
#
# View history
#
#
#
#
#
#
#
#
# More
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Navigation
#
#
#
#
#
#
# Main page
# Contents
# Featured content
# Current events
# Random article
# Donate to Wikipedia
# Wikipedia store
#
#
#
#
#
#
#
#
#
# Interaction
#
#
#
#
#
#
# Help
# About Wikipedia
# Community portal
# Recent changes
# Contact page
#
#
#
#
#
#
#
#
#
# Tools
#
#
#
#
#
#
# What links here
# Related changes
# Upload file
# Special pages
# Permanent link
# Page information
# Wikidata item
# Cite this page
#
#
#
#
#
#
#
#
#
# Print/export
#
#
#
#
#
#
# Create a book
# Download as PDF
# Printable version
#
#
#
#
#
#
#
#
#
# In other projects
#
#
#
#
#
#
# Wikispecies
#
#
#
#
#
#
#
#
#
# Languages
#
#
#
#
#
#
# Azərbaycanca
# Català
# Cebuano
# Español
# Euskara
# Français
# Magyar
# Nederlands
# Polski
# Português
# Svenska
# Tiếng Việt
# Winaray
#
#
#
# Edit links
#
#
#
#
#
#
#
#
#
#
#
#
#
#  This page was last modified on 1 December 2016, at 01:41.
#
#
# Text is available under the
# Creative Commons Attribution-ShareAlike License
# ;
# additional terms may apply.  By using this site, you agree to the
# Terms of Use
#  and
# Privacy Policy
# . Wikipedia® is a registered trademark of the
# Wikimedia Foundation, Inc.
# , a non-profit organization.
#
#
#
#
#
#
# Privacy policy
#
#
# About Wikipedia
#
#
# Disclaimers
#
#
# Contact Wikipedia
#
#
# Developers
#
#
# Cookie statement
#
#
# Mobile view
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Indexed:  en.wikipedia.org/wiki/Aparasphenodon.html
# Processing File: en.wikipedia.org/wiki/Aplastodiscus.html
#
#
#
#
#
#
#
#
#
#
#
#
#
#  CentralNotice
#
#
#
#
#
#
# Canebrake tree frogs
#
#
#
#
# From Wikipedia, the free encyclopedia
#
#
#   (Redirected from
# Aplastodiscus
# )
#
#
#
# 					Jump to:
# navigation
# ,
# search
#
#
#
#
#
#
#
#
#
#
# Canebrake tree frogs
#
#
#
#
#
#
#
#
#
#
#
#
# Aplastodiscus callipygius
#
#
#
#
#
#
# Scientific classification
#
#
#
#
#
#
# Kingdom:
#
#
# Animalia
#
#
#
#
#
#
# Phylum:
#
#
# Chordata
#
#
#
#
#
#
# Class:
#
#
# Amphibia
#
#
#
#
#
#
# Order:
#
#
# Anura
#
#
#
#
#
#
# Family:
#
#
# Hylidae
#
#
#
#
#
#
# Genus:
#
#
# Aplastodiscus
#
#
# Lutz
# , 1950
#
#
#
#
#
#
# Species
#
#
#
#
#
#
#
#
# See text.
#
#
#
#
#
#
#
#
#
#
# The
# canebrake tree frogs
#  comprise the
# Aplastodiscus
#  genus of
# frogs
#  in the
# Hylidae
#  family, and are found in southern
# Brazil
#  and
# Argentina
# . This genus contained only two species until recently, when a major revision of the Hylidae family moved an additional 12 species to this genus from the
# Hyla
#  genus.
# [1]
#
#
# Species
# [
# edit
# ]
#
#
#
#
# Aplastodiscus albofrenatus
#  (A. Lutz, 1924)
#
#
# Aplastodiscus albosignatus
#  (A. Lutz and B. Lutz, 1938)
#
#
# Aplastodiscus arildae
#  (Cruz and Peixoto, 1987)
#
#
# Aplastodiscus callipygius
#  (Cruz and Peixoto, 1985)
#
#
# Aplastodiscus cavicola
#  (Cruz and Peixoto, 1985)
#
#
# Aplastodiscus cochranae
#  (Mertens, 1952)
#
#
# Aplastodiscus ehrhardti
#  (Müller, 1924)
#
#
# Aplastodiscus flumineus
#  (Cruz and Peixoto, 1985)
#
#
# Aplastodiscus ibirapitanga
#  (Cruz, Pimenta, and Silvano, 2003)
#
#
# Aplastodiscus leucopygius
#  (Cruz and Peixoto, 1985)
#
#
# Aplastodiscus musicus
#  (B. Lutz, 1948)
#
#
# Aplastodiscus perviridis
#  A. Lutz
# In
#  B. Lutz, 1950
#
#
# Aplastodiscus sibilatus
#  (Cruz, Pimenta, and Silvano, 2003)
#
#
# Aplastodiscus weygoldti
#  (Cruz and Peixoto, 1987)
#
#
#
#
#
#
#
#
#
#
# This
# Hylinae
#  article is a
# stub
# . You can help Wikipedia by
# expanding it
# .
#
#
#
#
#
#
# v
#
#
# t
#
#
# e
#
#
#
#
#
#
#
#
#
#
#
#
#
# NewPP limit report
# Parsed by mw1305
# Cached time: 20170311143016
# Cache expiry: 2592000
# Dynamic content: false
# CPU time usage: 0.124 seconds
# Real time usage: 0.150 seconds
# Preprocessor visited node count: 2825/1000000
# Preprocessor generated node count: 0/1500000
# Post‐expand include size: 9679/2097152 bytes
# Template argument size: 1838/2097152 bytes
# Highest expansion depth: 24/40
# Expensive parser function count: 0/500
# Lua time usage: 0.032/10.000 seconds
# Lua memory usage: 1.67 MB/50 MB
#
#
#
#
# Transclusion expansion time report (%,ms,calls,template)
# 100.00%  136.139      1 -total
#  92.98%  126.578      1 Template:Taxobox
#  82.12%  111.794      1 Template:Taxobox/core
#  54.68%   74.436     14 Template:Taxobox_colour
#  49.16%   66.926     14 Template:Delink
#  23.70%   32.264      1 Template:If_empty
#  20.56%   27.992     11 Template:Sets_taxobox_colour
#  18.74%   25.518      6 Template:Taxonomy
#   9.52%   12.961     12 Template:Anglicise_rank
#   6.96%    9.481      1 Template:Hylinae-stub
#
#
#
#  Saved in parser cache with key enwiki:pcache:idhash:2969715-0!*!*!*!*!4!* and timestamp 20170311143016 and revision id 549090220
#
#
#
#
#
# 						Retrieved from "
# https://en.wikipedia.org/w/index.php?title=Canebrake_tree_frogs&oldid=549090220
# "
#
#
# Categories
# :
# Hylinae stubs
# Hylinae
# Aplastodiscus
# Hidden categories:
# Articles with 'species' microformats
# All stub articles
#
#
#
#
#
#
#
#
#
# Navigation menu
#
#
#
#
#
#
# Personal tools
#
#
#
#
# Not logged in
# Talk
# Contributions
# Create account
# Log in
#
#
#
#
#
#
#
#
#
# Namespaces
#
#
#
#
# Article
#
#
# Talk
#
#
#
#
#
#
#
#
#
#
# Variants
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Views
#
#
#
#
# Read
#
#
# Edit
#
#
# View history
#
#
#
#
#
#
#
#
# More
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Navigation
#
#
#
#
#
#
# Main page
# Contents
# Featured content
# Current events
# Random article
# Donate to Wikipedia
# Wikipedia store
#
#
#
#
#
#
#
#
#
# Interaction
#
#
#
#
#
#
# Help
# About Wikipedia
# Community portal
# Recent changes
# Contact page
#
#
#
#
#
#
#
#
#
# Tools
#
#
#
#
#
#
# What links here
# Related changes
# Upload file
# Special pages
# Permanent link
# Page information
# Wikidata item
# Cite this page
#
#
#
#
#
#
#
#
#
# Print/export
#
#
#
#
#
#
# Create a book
# Download as PDF
# Printable version
#
#
#
#
#
#
#
#
#
# In other projects
#
#
#
#
#
#
# Wikimedia Commons
# Wikispecies
#
#
#
#
#
#
#
#
#
# Languages
#
#
#
#
#
#
# Azərbaycanca
# Català
# Cebuano
# Español
# Euskara
# Français
# Magyar
# Nederlands
# Polski
# Português
# Svenska
# Tiếng Việt
# Winaray
#
#
#
# Edit links
#
#
#
#
#
#
#
#
#
#
#
#
#
#  This page was last modified on 7 April 2013, at 02:35.
#
#
# Text is available under the
# Creative Commons Attribution-ShareAlike License
# ;
# additional terms may apply.  By using this site, you agree to the
# Terms of Use
#  and
# Privacy Policy
# . Wikipedia® is a registered trademark of the
# Wikimedia Foundation, Inc.
# , a non-profit organization.
#
#
#
#
#
#
# Privacy policy
#
#
# About Wikipedia
#
#
# Disclaimers
#
#
# Contact Wikipedia
#
#
# Developers
#
#
# Cookie statement
#
#
# Mobile view
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Indexed:  en.wikipedia.org/wiki/Aplastodiscus.html
# Processing File: en.wikipedia.org/wiki/Argenteohyla.html
#
#
#
#
#
#
#
#
#
#
#
#
#
#  CentralNotice
#
#
#
#
#
#
# Argenteohyla siemersi
#
#
#
#
# From Wikipedia, the free encyclopedia
#
#
#   (Redirected from
# Argenteohyla
# )
#
#
#
# 					Jump to:
# navigation
# ,
# search
#
#
#
#
#
#
#
#
#
#
# Argenteohyla siemersi
#
#
#
#
#
#
#
#
# Conservation status
#
#
#
#
#
#
#
#
#
#
#
#
# Endangered
#  (
# IUCN 3.1
# )
# [1]
#
#
#
#
#
#
#
#
# Scientific classification
#
#
#
#
#
#
#
# Kingdom:
#
#
# Animalia
#
#
#
#
#
#
# Phylum:
#
#
# Chordata
#
#
#
#
#
#
# Class:
#
#
# Amphibia
#
#
#
#
#
#
# Order:
#
#
# Anura
#
#
#
#
#
#
# Family:
#
#
# Hylidae
#
#
#
#
#
#
# Genus:
#
#
# Argenteohyla
#
#
# Trueb, 1970
#
#
#
#
#
#
# Species:
#
#
# A. siemersi
#
#
#
#
#
#
# Binomial name
#
#
#
#
#
#
# Argenteohyla siemersi
#
#
# (
# Mertens
# , 1937)
#
#
#
#
#
#
# Synonyms
#
#
#
#
#
#
#
#
# Hyla siemersi
#
# Mertens, 1937
#
#
#
#
#
#
#
#
#
#
# Argenteohyla siemersi
#  (common name:
# red-spotted Argentina frog
# ) is a species of
# frog
#  in the
# Hylidae
#  family.
# [2]
#  It is
# monotypic
#  within the genus
# Argenteohyla
# .
# [3]
#  It is found in the catchment of
# Paraná River
#  in
# Argentina
#  and
# Paraguay
#  and in the southern coast of
# Uruguay
# .
# [2]
#
#
# There are two
# subspecies
#  that might be distinct species:
# Argenteohyla siemersi siemersi
#  and
# Argenteohyla siemersi pederseni
#
# Williams and Bosso, 1994
# .
# [2]
#
# A. s. pederseni
#  occurs in
# leaf axils
#  of terrestrial
# Aechmea
#
# bromeliads
#  in gallery forests along main river systems. It reproduces in temporary pools close to the bromeliads. The nominal subspecies occurs and reproduces in wetlands and the delta of Río Paraná. This rare frog is threatened by habitat loss.
# [1]
#
#
# References
# [
# edit
# ]
#
#
#
#
#
#
# ^
# a
#
# b
#
# Lavilla, E.; Céspedez, V; Baldo, D.; Blotto, B. & Langone, J. (2004).
# "
# Argenteohyla siemersi
# "
# .
# IUCN Red List of Threatened Species.
#  Version 2014.2
# .
# International Union for Conservation of Nature
# . Retrieved
# 5 August
#  2014
# .
#
#
#
# ^
# a
#
# b
#
# c
#
# Frost, Darrel R. (2014).
# "
# Argenteohyla siemersi
#  (Mertens, 1937)"
# .
# Amphibian Species of the World: an Online Reference. Version 6.0
# . American Museum of Natural History
# . Retrieved
# 5 August
#  2014
# .
#
#
#
# ^
#
# Frost, Darrel R. (2014).
# "
# Argenteohyla
#  Trueb, 1970"
# .
# Amphibian Species of the World: an Online Reference. Version 6.0
# . American Museum of Natural History
# . Retrieved
# 5 August
#  2014
# .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# This
# Hylinae
#  article is a
# stub
# . You can help Wikipedia by
# expanding it
# .
#
#
#
#
#
#
# v
#
#
# t
#
#
# e
#
#
#
#
#
#
#
#
#
#
#
#
#
# NewPP limit report
# Parsed by mw1277
# Cached time: 20170312140106
# Cache expiry: 2592000
# Dynamic content: false
# CPU time usage: 0.376 seconds
# Real time usage: 0.447 seconds
# Preprocessor visited node count: 8461/1000000
# Preprocessor generated node count: 0/1500000
# Post‐expand include size: 32340/2097152 bytes
# Template argument size: 8217/2097152 bytes
# Highest expansion depth: 19/40
# Expensive parser function count: 0/500
# Lua time usage: 0.264/10.000 seconds
# Lua memory usage: 2.22 MB/50 MB
#
#
#
#
# Transclusion expansion time report (%,ms,calls,template)
# 100.00%  422.223      1 -total
#  83.42%  352.212      1 Template:Speciesbox
#  81.41%  343.720      1 Template:Taxobox/core
#  41.66%  175.877      1 Template:Taxobox/taxonomy
#  27.41%  115.752    111 Template:Taxon_info
#  13.00%   54.903      1 Template:Reflist
#  10.67%   45.054     24 Template:Delink
#   9.72%   41.051      1 Template:IUCN2014.2
#   9.46%   39.922      3 Template:Cite_web
#   8.97%   37.860      1 Template:IUCN
#
#
#
#  Saved in parser cache with key enwiki:pcache:idhash:12371810-0!*!0!*!*!4!* and timestamp 20170312140105 and revision id 748246123
#
#
#
#
#
# 						Retrieved from "
# https://en.wikipedia.org/w/index.php?title=Argenteohyla_siemersi&oldid=748246123
# "
#
#
# Categories
# :
# IUCN Red List endangered species
# Hylinae
# Animals described in 1937
# Amphibians of Argentina
# Amphibians of Paraguay
# Amphibians of Uruguay
# Taxa named by Robert Mertens
# Hylinae stubs
# Hidden categories:
# Articles with 'species' microformats
# All stub articles
#
#
#
#
#
#
#
#
#
# Navigation menu
#
#
#
#
#
#
# Personal tools
#
#
#
#
# Not logged in
# Talk
# Contributions
# Create account
# Log in
#
#
#
#
#
#
#
#
#
# Namespaces
#
#
#
#
# Article
#
#
# Talk
#
#
#
#
#
#
#
#
#
#
# Variants
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Views
#
#
#
#
# Read
#
#
# Edit
#
#
# View history
#
#
#
#
#
#
#
#
# More
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Navigation
#
#
#
#
#
#
# Main page
# Contents
# Featured content
# Current events
# Random article
# Donate to Wikipedia
# Wikipedia store
#
#
#
#
#
#
#
#
#
# Interaction
#
#
#
#
#
#
# Help
# About Wikipedia
# Community portal
# Recent changes
# Contact page
#
#
#
#
#
#
#
#
#
# Tools
#
#
#
#
#
#
# What links here
# Related changes
# Upload file
# Special pages
# Permanent link
# Page information
# Wikidata item
# Cite this page
#
#
#
#
#
#
#
#
#
# Print/export
#
#
#
#
#
#
# Create a book
# Download as PDF
# Printable version
#
#
#
#
#
#
#
#
#
# In other projects
#
#
#
#
#
#
# Wikispecies
#
#
#
#
#
#
#
#
#
# Languages
#
#
#
#
#
#
# Azərbaycanca
# Български
# Català
# Cebuano
# Español
# Euskara
# Français
# Magyar
# Nederlands
# Polski
# Português
# Русский
# Svenska
# Tiếng Việt
# Winaray
#
#
#
# Edit links
#
#
#
#
#
#
#
#
#
#
#
#
#
#  This page was last modified on 7 November 2016, at 05:36.
#
#
# Text is available under the
# Creative Commons Attribution-ShareAlike License
# ;
# additional terms may apply.  By using this site, you agree to the
# Terms of Use
#  and
# Privacy Policy
# . Wikipedia® is a registered trademark of the
# Wikimedia Foundation, Inc.
# , a non-profit organization.
#
#
#
#
#
#
# Privacy policy
#
#
# About Wikipedia
#
#
# Disclaimers
#
#
# Contact Wikipedia
#
#
# Developers
#
#
# Cookie statement
#
#
# Mobile view
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Indexed:  en.wikipedia.org/wiki/Argenteohyla.html
# Processing File: en.wikipedia.org/wiki/Bokermannohyla.html
#
#
#
#
#
#
#
#
#
#
#
#
#
#  CentralNotice
#
#
#
#
#
#
# Bokermannohyla
#
#
#
#
# From Wikipedia, the free encyclopedia
#
#
#
#
#
# 					Jump to:
# navigation
# ,
# search
#
#
#
#
#
#
#
#
#
#
# Bokermannohyla
#
#
#
#
#
#
#
#
#
#
#
#
# Bokermannohyla saxicola
#
#
#
#
#
#
# Scientific classification
#
#
#
#
#
#
# Kingdom:
#
#
# Animalia
#
#
#
#
#
#
# Phylum:
#
#
# Chordata
#
#
#
#
#
#
# Class:
#
#
# Amphibia
#
#
#
#
#
#
# Order:
#
#
# Anura
#
#
#
#
#
#
# Family:
#
#
# Hylidae
#
#
#
#
#
#
# Subfamily:
#
#
# Hylinae
#
#
#
#
#
#
# Genus:
#
#
# Bokermannohyla
#
#
# Faivovich, et al. 2005
#
#
#
#
#
#
# Species
#
#
#
#
#
#
#
#
# See text.
#
#
#
#
#
#
#
#
#
#
# Bokermannohyla
#  is a genus of
# frogs
#  in the
# Hylidae
#  family. This genus was erected in 2005 following a major revision of the Hylidae family.
# [1]
#  Twenty-three species previously placed in the
# Hyla
#  genus were moved to this genus.
#
#
# Species
# [
# edit
# ]
#
#
#
#
#
#
# Binomial name and author
#
#
# Common name
#
#
#
#
#
#
# Bokermannohyla ahenea
#
# (Napoli & Caramaschi, 2004)
#
#
#
#
#
#
#
#
# Bokermannohyla alvarengai
#
# (Bokermann, 1956)
#
#
# Santa Barbara tree frog
#
#
#
#
#
#
# Bokermannohyla astartea
#
# (Bokermann, 1967)
#
#
# Paranapiacaba tree frog
#
#
#
#
#
#
# Bokermannohyla capra
#
# Napoli & Pimenta, 2009
#
#
#
#
#
#
#
#
# Bokermannohyla caramaschii
#
# (Napoli, 2005)
#
#
#
#
#
#
#
#
# Bokermannohyla carvalhoi
#
# (Peixoto, 1981)
#
#
# Carvalho's tree frog
#
#
#
#
#
#
# Bokermannohyla circumdata
#
# (Cope, 1871)
#
#
# Espirito Santo tree frog
#
#
#
#
#
#
# Bokermannohyla claresignata
#
# (A. Lutz & B. Lutz, 1939)
#
#
# Rio tree frog
#
#
#
#
#
#
# Bokermannohyla clepsydra
#
# (A. Lutz, 1925)
#
#
# São Paulo tree frog
#
#
#
#
#
#
# Bokermannohyla diamantina
#
# Napoli & Juncá, 2006
#
#
#
#
#
#
#
#
# Bokermannohyla flavopicta
#
# Leite, Pezzuti & Garcia, 2012
#
#
#
#
#
#
#
#
# Bokermannohyla gouveai
#
# (Peixoto & Cruz, 1992)
#
#
# Itatiaia tree frog
#
#
#
#
#
#
# Bokermannohyla hylax
#
# (Heyer, 1985)
#
#
# Atlantic forest tree frog
#
#
#
#
#
#
# Bokermannohyla ibitiguara
#
# (Cardoso, 1983)
#
#
# Fazenda Salto tree frog
#
#
#
#
#
#
# Bokermannohyla ibitipoca
#
# (Caramaschi & Feio, 1990)
#
#
# Ibitipoca tree frog
#
#
#
#
#
#
# Bokermannohyla itapoty
#
# Lugli & Haddad, 2006
#
#
#
#
#
#
#
#
# Bokermannohyla izeckshoni
#
# (Jim & Caramaschi, 1979)
#
#
# Izecksohn's tree frog
#
#
#
#
#
#
# Bokermannohyla juiju
#
# Faivovich, Lugli, Lourenço & Haddad, 2009
#
#
#
#
#
#
#
#
# Bokermannohyla langei
#
# (Bokermann, 1965)
#
#
# Marumbi tree frog
#
#
#
#
#
#
# Bokermannohyla lucianae
#
# (Napoli & Pimenta, 2003)
#
#
#
#
#
#
#
#
# Bokermannohyla luctuosa
#
# (Pombal & Haddad, 1993)
#
#
# Reservoir tree frog
#
#
#
#
#
#
# Bokermannohyla martinsi
#
# (Bokermann, 1964)
#
#
# Martins' tree frog
#
#
#
#
#
#
# Bokermannohyla nanuzae
#
# (Bokermann & Sazima, 1973)
#
#
# Jaboticatubas tree frog
#
#
#
#
#
#
# Bokermannohyla napolii
#
# de Carvalho, Giaretta & Magrini, 2012
#
#
#
#
#
#
#
#
# Bokermannohyla oxente
#
# Lugli & Haddad, 2006
#
#
#
#
#
#
#
#
# Bokermannohyla pseudopseudis
#
# (Miranda-Ribeiro, 1937)
#
#
# Veadeiros tree frog
#
#
#
#
#
#
# Bokermannohyla ravida
#
# (Caramaschi, Napoli & Bernardes, 2001)
#
#
#
#
#
#
#
#
# Bokermannohyla sagarana
#
# Leite, Pezzuti & Drummond, 2011
#
#
#
#
#
#
#
#
# Bokermannohyla sapiranga
#
# Brandão, de Magalhães, Garda, Campos, Sebben & Maciel, 2012
#
#
#
#
#
#
#
#
# Bokermannohyla saxicola
#
# (Bokermann, 1964)
#
#
#
#
#
#
#
#
# Bokermannohyla sazimai
#
# (Cardoso & Andrade, 1982)
#
#
# Zagaia tree frog
#
#
#
#
#
#
# Bokermannohyla vulcaniae
#
# Vasconcelos & Giaretta, 2005
#
#
#
#
#
#
#
#
# References
# [
# edit
# ]
#
#
#
#
#
#
# ^
#
# [1]
#
#
#
#
#
#
#
#
#
#
#
#
# This
# Hylinae
#  article is a
# stub
# . You can help Wikipedia by
# expanding it
# .
#
#
#
#
#
#
# v
#
#
# t
#
#
# e
#
#
#
#
#
#
#
#
#
#
#
#
#
# NewPP limit report
# Parsed by mw1173
# Cached time: 20170311213129
# Cache expiry: 2592000
# Dynamic content: false
# CPU time usage: 0.128 seconds
# Real time usage: 0.159 seconds
# Preprocessor visited node count: 3400/1000000
# Preprocessor generated node count: 0/1500000
# Post‐expand include size: 11413/2097152 bytes
# Template argument size: 3452/2097152 bytes
# Highest expansion depth: 24/40
# Expensive parser function count: 0/500
# Lua time usage: 0.031/10.000 seconds
# Lua memory usage: 1.84 MB/50 MB
#
#
#
#
# Transclusion expansion time report (%,ms,calls,template)
# 100.00%  136.073      1 -total
#  73.64%  100.209      1 Template:Taxobox
#  65.36%   88.938      1 Template:Taxobox/core
#  43.33%   58.965     14 Template:Taxobox_colour
#  37.85%   51.510     14 Template:Delink
#  22.47%   30.572      1 Template:If_empty
#  18.67%   25.406     11 Template:Sets_taxobox_colour
#  16.69%   22.706      7 Template:Taxonomy
#  13.04%   17.744      1 Template:Italic_title
#   8.45%   11.503     14 Template:Anglicise_rank
#
#
#
#  Saved in parser cache with key enwiki:pcache:idhash:5773423-0!*!0!!*!4!* and timestamp 20170311213129 and revision id 753659496
#
#
#
#
#
# 						Retrieved from "
# https://en.wikipedia.org/w/index.php?title=Bokermannohyla&oldid=753659496
# "
#
#
# Categories
# :
# Hylinae
# Bokermannohyla
# Amphibian genera
# Hylinae stubs
# Hidden categories:
# Articles with 'species' microformats
# All stub articles
#
#
#
#
#
#
#
#
#
# Navigation menu
#
#
#
#
#
#
# Personal tools
#
#
#
#
# Not logged in
# Talk
# Contributions
# Create account
# Log in
#
#
#
#
#
#
#
#
#
# Namespaces
#
#
#
#
# Article
#
#
# Talk
#
#
#
#
#
#
#
#
#
#
# Variants
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Views
#
#
#
#
# Read
#
#
# Edit
#
#
# View history
#
#
#
#
#
#
#
#
# More
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Navigation
#
#
#
#
#
#
# Main page
# Contents
# Featured content
# Current events
# Random article
# Donate to Wikipedia
# Wikipedia store
#
#
#
#
#
#
#
#
#
# Interaction
#
#
#
#
#
#
# Help
# About Wikipedia
# Community portal
# Recent changes
# Contact page
#
#
#
#
#
#
#
#
#
# Tools
#
#
#
#
#
#
# What links here
# Related changes
# Upload file
# Special pages
# Permanent link
# Page information
# Wikidata item
# Cite this page
#
#
#
#
#
#
#
#
#
# Print/export
#
#
#
#
#
#
# Create a book
# Download as PDF
# Printable version
#
#
#
#
#
#
#
#
#
# In other projects
#
#
#
#
#
#
# Wikimedia Commons
# Wikispecies
#
#
#
#
#
#
#
#
#
# Languages
#
#
#
#
#
#
# Català
# Cebuano
# Deutsch
# Español
# Euskara
# Français
# Magyar
# Nederlands
# Polski
# Português
# Svenska
# Tiếng Việt
# Winaray
#
#
#
# Edit links
#
#
#
#
#
#
#
#
#
#
#
#
#
#  This page was last modified on 8 December 2016, at 14:11.
#
#
# Text is available under the
# Creative Commons Attribution-ShareAlike License
# ;
# additional terms may apply.  By using this site, you agree to the
# Terms of Use
#  and
# Privacy Policy
# . Wikipedia® is a registered trademark of the
# Wikimedia Foundation, Inc.
# , a non-profit organization.
#
#
#
#
#
#
# Privacy policy
#
#
# About Wikipedia
#
#
# Disclaimers
#
#
# Contact Wikipedia
#
#
# Developers
#
#
# Cookie statement
#
#
# Mobile view
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Indexed:  en.wikipedia.org/wiki/Bokermannohyla.html
# Processing File: en.wikipedia.org/wiki/Bromeliohyla.html
#
#
#
#
#
#
#
#
#
#
#
#
#
#  CentralNotice
#
#
#
#
#
#
# Bromeliohyla
#
#
#
#
# From Wikipedia, the free encyclopedia
#
#
#
#
#
# 					Jump to:
# navigation
# ,
# search
#
#
#
#
#
#
#
#
#
#
# Bromeliohyla
#
#
#
#
#
#
# Scientific classification
#
#
#
#
#
#
#
# Kingdom:
#
#
# Animalia
#
#
#
#
#
#
# Phylum:
#
#
# Chordata
#
#
#
#
#
#
# Class:
#
#
# Amphibia
#
#
#
#
#
#
# Order:
#
#
# Anura
#
#
#
#
#
#
# Family:
#
#
# Hylidae
#
#
#
#
#
#
# Subfamily:
#
#
# Hylinae
#
#
#
#
#
#
# Genus:
#
#
# Bromeliohyla
#
#
# Faivovich
# et al.
# , 2005
# [1]
#
#
#
#
#
#
# Type species
#
#
#
#
#
#
# Hyla bromeliacia
#
#
# Schmidt
# , 1933
#
#
#
#
#
#
# Diversity
#
#
#
#
#
#
# 2 species (see
# text
# )
#
#
#
#
#
#
#
#
# Bromeliohyla
# , sometimes known as the
# bromeliad treefrogs
# , is a genus of
# frogs
#  in the
# Hylidae
#  family.
# [2]
#  This genus was erected in 2005 following a major revision of the Hylidae family. The two species in this genus were previously placed in the
# Hyla
#  genus.
# [1]
#  They are found in tropical southern
# Mexico
# ,
# Belize
# ,
# Guatemala
# , and northern
# Honduras
# .
# [2]
#
#
# Species
# [
# edit
# ]
#
#
# The genus contains two species:
# [2]
# [3]
#
#
#
#
#
#
# Binomial name and author
#
#
# Common name
#
#
#
#
#
#
# Bromeliohyla bromeliacia
#
# (Schmidt, 1933)
#
#
# Bromeliad tree frog
#
#
#
#
#
#
# Bromeliohyla dendroscarta
#
# (Taylor, 1940)
#
#
# Greater bromeliad tree frog
#
#
#
#
#
#
# References
# [
# edit
# ]
#
#
#
#
#
#
# ^
# a
#
# b
#
# Julián Faivovich; Célio F.B. Haddad; Paulo C.A. Garcia; Darrel R. Frost; Jonathan A. Campbell & Ward C. Wheeler (2005).
# "Systematic review of the frog family Hylidae, with special reference to Hylinae: phylogenetic analysis and taxonomic revision"
# .
# Bulletin of the American Museum of Natural History
# .
# 294
# : 1–240.
# doi
# :
# 10.1206/0003-0090(2005)294[0001:SROTFF]2.0.CO;2
# .
#
#
#
# ^
# a
#
# b
#
# c
#
# Frost, Darrel R. (2014).
# "
# Bromeliohyla
#  Faivovich, Haddad, Garcia, Frost, Campbell, and Wheeler, 2005"
# .
# Amphibian Species of the World: an Online Reference. Version 6.0
# . American Museum of Natural History
# . Retrieved
# 26 January
#  2015
# .
#
#
#
# ^
#
# "
# Bromeliohyla
# "
# .
# AmphibiaWeb: Information on amphibian biology and conservation. [web application]
# . Berkeley, California: AmphibiaWeb. 2015
# . Retrieved
# 26 January
#  2015
# .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# This
# Hylinae
#  article is a
# stub
# . You can help Wikipedia by
# expanding it
# .
#
#
#
#
#
#
# v
#
#
# t
#
#
# e
#
#
#
#
#
#
#
#
#
#
#
#
#
# NewPP limit report
# Parsed by mw1252
# Cached time: 20170311210109
# Cache expiry: 2592000
# Dynamic content: false
# CPU time usage: 0.408 seconds
# Real time usage: 0.476 seconds
# Preprocessor visited node count: 8031/1000000
# Preprocessor generated node count: 0/1500000
# Post‐expand include size: 25210/2097152 bytes
# Template argument size: 7957/2097152 bytes
# Highest expansion depth: 19/40
# Expensive parser function count: 1/500
# Lua time usage: 0.326/10.000 seconds
# Lua memory usage: 2.33 MB/50 MB
#
#
#
#
# Transclusion expansion time report (%,ms,calls,template)
# 100.00%  456.683      1 -total
#  85.91%  392.338      1 Template:Automatic_taxobox
#  84.73%  386.943      1 Template:Taxobox/core
#  44.18%  201.763      1 Template:Taxobox/taxonomy
#  28.08%  128.226    115 Template:Taxon_info
#  14.30%   65.287     24 Template:Delink
#  10.53%   48.098      1 Template:Reflist
#   9.23%   42.171      7 Template:Taxon_link
#   7.81%   35.675     28 Template:Taxobox/displayed_cell
#   6.77%   30.913      1 Template:Cite_journal
#
#
#
#  Saved in parser cache with key enwiki:pcache:idhash:5783557-0!*!0!!*!4!* and timestamp 20170311210109 and revision id 732560787
#
#
#
#
#
# 						Retrieved from "
# https://en.wikipedia.org/w/index.php?title=Bromeliohyla&oldid=732560787
# "
#
#
# Categories
# :
# Hylinae
# Bromeliohyla
# Amphibians of Central America
# Amphibians of North America
# Amphibian genera
# Hylinae stubs
# Hidden categories:
# Articles using diversity taxobox
# Articles with 'species' microformats
# All stub articles
#
#
#
#
#
#
#
#
#
# Navigation menu
#
#
#
#
#
#
# Personal tools
#
#
#
#
# Not logged in
# Talk
# Contributions
# Create account
# Log in
#
#
#
#
#
#
#
#
#
# Namespaces
#
#
#
#
# Article
#
#
# Talk
#
#
#
#
#
#
#
#
#
#
# Variants
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Views
#
#
#
#
# Read
#
#
# Edit
#
#
# View history
#
#
#
#
#
#
#
#
# More
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Navigation
#
#
#
#
#
#
# Main page
# Contents
# Featured content
# Current events
# Random article
# Donate to Wikipedia
# Wikipedia store
#
#
#
#
#
#
#
#
#
# Interaction
#
#
#
#
#
#
# Help
# About Wikipedia
# Community portal
# Recent changes
# Contact page
#
#
#
#
#
#
#
#
#
# Tools
#
#
#
#
#
#
# What links here
# Related changes
# Upload file
# Special pages
# Permanent link
# Page information
# Wikidata item
# Cite this page
#
#
#
#
#
#
#
#
#
# Print/export
#
#
#
#
#
#
# Create a book
# Download as PDF
# Printable version
#
#
#
#
#
#
#
#
#
# In other projects
#
#
#
#
#
#
# Wikispecies
#
#
#
#
#
#
#
#
#
# Languages
#
#
#
#
#
#
# Català
# Cebuano
# Deutsch
# Español
# Euskara
# Français
# Magyar
# Nederlands
# Polski
# Português
# Svenska
# Tiếng Việt
# Winaray
#
#
#
# Edit links
#
#
#
#
#
#
#
#
#
#
#
#
#
#  This page was last modified on 1 August 2016, at 19:35.
#
#
# Text is available under the
# Creative Commons Attribution-ShareAlike License
# ;
# additional terms may apply.  By using this site, you agree to the
# Terms of Use
#  and
# Privacy Policy
# . Wikipedia® is a registered trademark of the
# Wikimedia Foundation, Inc.
# , a non-profit organization.
#
#
#
#
#
#
# Privacy policy
#
#
# About Wikipedia
#
#
# Disclaimers
#
#
# Contact Wikipedia
#
#
# Developers
#
#
# Cookie statement
#
#
# Mobile view
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Indexed:  en.wikipedia.org/wiki/Bromeliohyla.html
# Processing File: en.wikipedia.org/wiki/Charadrahyla.html
#
#
#
#
#
#
#
#
#
#
#
#
#
#  CentralNotice
#
#
#
#
#
#
# Charadrahyla
#
#
#
#
# From Wikipedia, the free encyclopedia
#
#
#
#
#
# 					Jump to:
# navigation
# ,
# search
#
#
#
#
#
#
#
#
#
#
# Charadrahyla
#
#
#
#
#
#
# Scientific classification
#
#
#
#
#
#
# Kingdom:
#
#
# Animalia
#
#
#
#
#
#
# Phylum:
#
#
# Chordata
#
#
#
#
#
#
# Class:
#
#
# Amphibia
#
#
#
#
#
#
# Order:
#
#
# Anura
#
#
#
#
#
#
# Family:
#
#
# Hylidae
#
#
#
#
#
#
# Genus:
#
#
# Charadrahyla
#
#
# Faivovich, Haddad, Garcia, Frost, Campbell & Wheeler, 2005
#
#
#
#
#
#
# Species
#
#
#
#
#
#
#
#
# See text.
#
#
#
#
#
#
#
#
#
#
# Charadrahyla
#  is a genus of
# frogs
#  in the
# Hylidae
#  family. This genus was erected in 2005 following a major revision of the Hylidae family
# [1]
# . The five species in this genus were previously placed in the
# Hyla
#  genus. They are found in tropical southern
# Mexico
# .
#
#
# Species
# [
# edit
# ]
#
#
#
#
#
#
# Binomial name and author
#
#
# Common name
#
#
#
#
#
#
# C. altipotens
#
# (Duellman, 1968)
#
#
# Yellowbelly voiceless tree frog
#
#
#
#
#
#
# C. chaneque
#
# (Duellman, 1961)
#
#
# Fairy tree frog
#
#
#
#
#
#
# C. nephila
#
# (Mendelson and Campbell, 1999)
#
#
#
#
#
#
#
#
# C. taeniopus
#
# (Günther, 1901)
#
#
# Porthole tree frog
#
#
#
#
#
#
# C. trux
#
# (Adler and Dennis, 1972)
#
#
# Spine-fingered tree frog
#
#
#
#
#
#
# External links
# [
# edit
# ]
#
#
#
#
# Frost, Darrel R
# . 2007. Amphibian Species of the World: an Online Reference. Version 5.1 (10 October, 2007).
# Charadrahyla
# [
# permanent dead link
# ]
# . Electronic Database accessible at
# https://web.archive.org/web/20071024033938/http://research.amnh.org:80/herpetology/amphibia/index.php
# . American Museum of Natural History, New York, USA. (Accessed: Apr 21, 2008).
#
#
# AmphibiaWeb: Information on amphibian biology and conservation.
#  [web application]. 2008. Berkeley, California:
# Ecnomiohyla
# . AmphibiaWeb, available at
# http://amphibiaweb.org/
# . (Accessed: Apr 21, 2008).
#
#
#
#
#
#
#
#
#
#
#
#
# This
# Hylinae
#  article is a
# stub
# . You can help Wikipedia by
# expanding it
# .
#
#
#
#
#
#
# v
#
#
# t
#
#
# e
#
#
#
#
#
#
#
#
#
#
#
#
#
# NewPP limit report
# Parsed by mw1273
# Cached time: 20170312011705
# Cache expiry: 2592000
# Dynamic content: false
# CPU time usage: 0.136 seconds
# Real time usage: 0.175 seconds
# Preprocessor visited node count: 2962/1000000
# Preprocessor generated node count: 0/1500000
# Post‐expand include size: 11342/2097152 bytes
# Template argument size: 2570/2097152 bytes
# Highest expansion depth: 24/40
# Expensive parser function count: 1/500
# Lua time usage: 0.042/10.000 seconds
# Lua memory usage: 2.1 MB/50 MB
#
#
#
#
# Transclusion expansion time report (%,ms,calls,template)
# 100.00%  155.611      1 -total
#  61.23%   95.284      1 Template:Taxobox
#  54.17%   84.300      1 Template:Taxobox/core
#  34.47%   53.635     14 Template:Taxobox_colour
#  30.36%   47.238     14 Template:Delink
#  17.54%   27.297      1 Template:If_empty
#  16.71%   26.003      6 Template:Taxonomy
#  15.97%   24.845      1 Template:Dead_link
#  15.17%   23.612     11 Template:Sets_taxobox_colour
#  13.67%   21.267      1 Template:Fix
#
#
#
#  Saved in parser cache with key enwiki:pcache:idhash:5771854-0!*!0!!*!4!* and timestamp 20170312011705 and revision id 757413538
#
#
#
#
#
# 						Retrieved from "
# https://en.wikipedia.org/w/index.php?title=Charadrahyla&oldid=757413538
# "
#
#
# Categories
# :
# Hylinae stubs
# Hylinae
# Charadrahyla
# Amphibian genera
# Hidden categories:
# Articles with 'species' microformats
# All articles with dead external links
# Articles with dead external links from November 2016
# Articles with permanently dead external links
# All stub articles
#
#
#
#
#
#
#
#
#
# Navigation menu
#
#
#
#
#
#
# Personal tools
#
#
#
#
# Not logged in
# Talk
# Contributions
# Create account
# Log in
#
#
#
#
#
#
#
#
#
# Namespaces
#
#
#
#
# Article
#
#
# Talk
#
#
#
#
#
#
#
#
#
#
# Variants
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Views
#
#
#
#
# Read
#
#
# Edit
#
#
# View history
#
#
#
#
#
#
#
#
# More
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Navigation
#
#
#
#
#
#
# Main page
# Contents
# Featured content
# Current events
# Random article
# Donate to Wikipedia
# Wikipedia store
#
#
#
#
#
#
#
#
#
# Interaction
#
#
#
#
#
#
# Help
# About Wikipedia
# Community portal
# Recent changes
# Contact page
#
#
#
#
#
#
#
#
#
# Tools
#
#
#
#
#
#
# What links here
# Related changes
# Upload file
# Special pages
# Permanent link
# Page information
# Wikidata item
# Cite this page
#
#
#
#
#
#
#
#
#
# Print/export
#
#
#
#
#
#
# Create a book
# Download as PDF
# Printable version
#
#
#
#
#
#
#
#
#
# In other projects
#
#
#
#
#
#
# Wikimedia Commons
# Wikispecies
#
#
#
#
#
#
#
#
#
# Languages
#
#
#
#
#
#
# Català
# Cebuano
# Deutsch
# Español
# Euskara
# Français
# Italiano
# Magyar
# Nederlands
# Polski
# Português
# Svenska
# Tiếng Việt
# Winaray
#
#
#
# Edit links
#
#
#
#
#
#
#
#
#
#
#
#
#
#  This page was last modified on 30 December 2016, at 15:30.
#
#
# Text is available under the
# Creative Commons Attribution-ShareAlike License
# ;
# additional terms may apply.  By using this site, you agree to the
# Terms of Use
#  and
# Privacy Policy
# . Wikipedia® is a registered trademark of the
# Wikimedia Foundation, Inc.
# , a non-profit organization.
#
#
#
#
#
#
# Privacy policy
#
#
# About Wikipedia
#
#
# Disclaimers
#
#
# Contact Wikipedia
#
#
# Developers
#
#
# Cookie statement
#
#
# Mobile view
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Indexed:  en.wikipedia.org/wiki/Charadrahyla.html
# Processing File: en.wikipedia.org/wiki/Corythomantis.html
#
#
#
#
#
#
#
#
#
#
#
#
#
#  CentralNotice
#
#
#
#
#
#
# Corythomantis
#
#
#
#
# From Wikipedia, the free encyclopedia
#
#
#
#
#
# 					Jump to:
# navigation
# ,
# search
#
#
#
#
#
#
#
#
#
#
# Corythomantis
#
#
#
#
#
#
#
#
#
#
#
#
# Corythomantis greeningi
#
#
#
#
#
#
# Scientific classification
#
#
#
#
#
#
#
# Kingdom:
#
#
# Animalia
#
#
#
#
#
#
# Phylum:
#
#
# Chordata
#
#
#
#
#
#
# Class:
#
#
# Amphibia
#
#
#
#
#
#
# Order:
#
#
# Anura
#
#
#
#
#
#
# Family:
#
#
# Hylidae
#
#
#
#
#
#
# Subfamily:
#
#
# Hylinae
#
#
#
#
#
#
# Genus:
#
#
# Corythomantis
#
#
# Boulenger
# , 1896
#
#
#
#
#
#
# Type species
#
#
#
#
#
#
# Corythomantis greeningi
#
#
# Boulenger, 1896
#
#
#
#
#
#
# Diversity
#
#
#
#
#
#
# 2 species (see
# text
# )
#
#
#
#
#
#
#
#
# Corythomantis
#  is a small genus of
# hylid
#  frogs
# endemic
#  to northeastern
# Brazil
# . It was
# monotypic
#  until description of a second species,
# Corythomantis galeata
# , in 2012. These frogs are sometimes known under common name
# Greening's frogs
# .
# [1]
#
#
# Species
# [
# edit
# ]
#
#
# There are two species in this genus:
# [1]
# [2]
#
#
#
#
# Corythomantis galeata
#
# Pombal, Menezes, Fontes, Nunes, Rocha, and Van Sluys, 2012
#
#
# Corythomantis greeningi
#
# Boulenger, 1896
#
#
#
#
# References
# [
# edit
# ]
#
#
#
#
#
#
# ^
# a
#
# b
#
# Frost, Darrel R. (2014).
# "
# Corythomantis
#  Boulenger, 1896"
# .
# Amphibian Species of the World: an Online Reference. Version 6.0
# . American Museum of Natural History
# . Retrieved
# 4 August
#  2014
# .
#
#
#
# ^
#
# "Hylidae"
# .
# AmphibiaWeb: Information on amphibian biology and conservation. [web application]
# . Berkeley, California: AmphibiaWeb. 2014
# . Retrieved
# 4 August
#  2014
# .
#
#
#
#
#
#
#
#
#
#
#
#
#
# This
# Hylinae
#  article is a
# stub
# . You can help Wikipedia by
# expanding it
# .
#
#
#
#
#
#
# v
#
#
# t
#
#
# e
#
#
#
#
#
#
#
#
#
#
#
#
#
# NewPP limit report
# Parsed by mw1240
# Cached time: 20170311163324
# Cache expiry: 2592000
# Dynamic content: false
# CPU time usage: 0.304 seconds
# Real time usage: 0.370 seconds
# Preprocessor visited node count: 8001/1000000
# Preprocessor generated node count: 0/1500000
# Post‐expand include size: 22481/2097152 bytes
# Template argument size: 7993/2097152 bytes
# Highest expansion depth: 19/40
# Expensive parser function count: 1/500
# Lua time usage: 0.232/10.000 seconds
# Lua memory usage: 2.17 MB/50 MB
#
#
#
#
# Transclusion expansion time report (%,ms,calls,template)
# 100.00%  346.783      1 -total
#  86.66%  300.528      1 Template:Automatic_taxobox
#  84.91%  294.443      1 Template:Taxobox/core
#  45.87%  159.072      1 Template:Taxobox/taxonomy
#  29.60%  102.657    115 Template:Taxon_info
#  11.28%   39.111     24 Template:Delink
#  10.25%   35.553      7 Template:Taxon_link
#  10.24%   35.507      1 Template:Reflist
#   8.57%   29.712      2 Template:Cite_web
#   8.30%   28.789     28 Template:Taxobox/displayed_cell
#
#
#
#  Saved in parser cache with key enwiki:pcache:idhash:12371967-0!*!0!!*!4!* and timestamp 20170311163324 and revision id 732561092
#
#
#
#
#
# 						Retrieved from "
# https://en.wikipedia.org/w/index.php?title=Corythomantis&oldid=732561092
# "
#
#
# Categories
# :
# Hylinae
# Corythomantis
# Amphibians of South America
# Endemic fauna of Brazil
# Taxa named by George Albert Boulenger
# Hylinae stubs
# Hidden categories:
# Articles using diversity taxobox
# Articles with 'species' microformats
# All stub articles
#
#
#
#
#
#
#
#
#
# Navigation menu
#
#
#
#
#
#
# Personal tools
#
#
#
#
# Not logged in
# Talk
# Contributions
# Create account
# Log in
#
#
#
#
#
#
#
#
#
# Namespaces
#
#
#
#
# Article
#
#
# Talk
#
#
#
#
#
#
#
#
#
#
# Variants
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Views
#
#
#
#
# Read
#
#
# Edit
#
#
# View history
#
#
#
#
#
#
#
#
# More
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Navigation
#
#
#
#
#
#
# Main page
# Contents
# Featured content
# Current events
# Random article
# Donate to Wikipedia
# Wikipedia store
#
#
#
#
#
#
#
#
#
# Interaction
#
#
#
#
#
#
# Help
# About Wikipedia
# Community portal
# Recent changes
# Contact page
#
#
#
#
#
#
#
#
#
# Tools
#
#
#
#
#
#
# What links here
# Related changes
# Upload file
# Special pages
# Permanent link
# Page information
# Wikidata item
# Cite this page
#
#
#
#
#
#
#
#
#
# Print/export
#
#
#
#
#
#
# Create a book
# Download as PDF
# Printable version
#
#
#
#
#
#
#
#
#
# In other projects
#
#
#
#
#
#
# Wikimedia Commons
# Wikispecies
#
#
#
#
#
#
#
#
#
# Languages
#
#
#
#
#
#
# Cebuano
# Deutsch
# Español
# Français
# Magyar
# Nederlands
# Português
# Tiếng Việt
#
#
#
# Edit links
#
#
#
#
#
#
#
#
#
#
#
#
#
#  This page was last modified on 1 August 2016, at 19:37.
#
#
# Text is available under the
# Creative Commons Attribution-ShareAlike License
# ;
# additional terms may apply.  By using this site, you agree to the
# Terms of Use
#  and
# Privacy Policy
# . Wikipedia® is a registered trademark of the
# Wikimedia Foundation, Inc.
# , a non-profit organization.
#
#
#
#
#
#
# Privacy policy
#
#
# About Wikipedia
#
#
# Disclaimers
#
#
# Contact Wikipedia
#
#
# Developers
#
#
# Cookie statement
#
#
# Mobile view
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Indexed:  en.wikipedia.org/wiki/Corythomantis.html
# Processing File: en.wikipedia.org/wiki/Dendropsophus.html
#
#
#
#
#
#
#
#
#
#
#
#
#
#  CentralNotice
#
#
#
#
#
#
# Dendropsophus
#
#
#
#
# From Wikipedia, the free encyclopedia
#
#
#
#
#
# 					Jump to:
# navigation
# ,
# search
#
#
#
#
#
#
#
#
#
#
# Dendropsophus
#
#
#
#
#
#
#
#
#
#
#
#
# Brazilian coastal tree frog (
# Dendropsophus decipiens
# )
#
#
#
#
#
#
# Scientific classification
#
#
#
#
#
#
#
# Kingdom:
#
#
# Animalia
#
#
#
#
#
#
# Phylum:
#
#
# Chordata
#
#
#
#
#
#
# Class:
#
#
# Amphibia
#
#
#
#
#
#
# Order:
#
#
# Anura
#
#
#
#
#
#
# Family:
#
#
# Hylidae
#
#
#
#
#
#
# Subfamily:
#
#
# Hylinae
#
#
#
#
#
#
# Genus:
#
#
# Dendropsophus
#
#
# Fitzinger
# , 1843
#
#
#
#
#
#
# Species
#
#
#
#
#
#
#
#
# 95, see text.
#
#
#
#
#
#
#
#
#
#
# Dendropsophus
#  is a genus of
# frogs
#  in the
# Hylidae
#  family. They are distributed in Central and South America, from southern Mexico to northern Argentina and Uruguay. They are sometimes known under the common name
# Fitzinger neotropical treefrogs
#  or
# yellow treefrogs
# [1]
#
#
# This genus was resurrected in 2005 following a major revision of the Hylidae family.
# [2]
#  The species believed to have 30
# chromosomes
# , previously placed in the
# Hyla
#  genus, were later moved to this genus.
# [1]
#
#
# Species
# [
# edit
# ]
#
#
# 95 species are currently assigned to this genus.
# [1]
#
#
#
#
#
#
# Binomial name and author
#
#
# Common name
#
#
#
#
#
#
# D. acreanus
#
# (Bokermann, 1964)
#
#
# Acre tree frog
#
#
#
#
#
#
# D. amicorum
#
# (Mijares-Urrutia, 1998)
#
#
#
#
#
#
#
#
# D. anataliasiasi
#
# (Bokermann, 1972)
#
#
# Goias tree frog
#
#
#
#
#
#
# D. anceps
#
# (Lutz, 1929)
#
#
# Estrella tree frog
#
#
#
#
#
#
# D. aperomeus
#
# (Duellman, 1982)
#
#
# Balzapata tree frog
#
#
#
#
#
#
# D. araguaya
#
# (Napoli & Caramaschi, 1998)
#
#
#
#
#
#
#
#
# D. arndti
#  (Jansen 2017)
#
#
#
#
#
#
#
#
# D. battersbyi
#
# (Rivero, 1961)
#
#
# Battersby's tree frog
#
#
#
#
#
#
# D. berthalutzae
#
# (Bokermann, 1962)
#
#
# Bertha's tree frog
#
#
#
#
#
#
# D. bifurcus
#
# (Andersson, 1945)
#
#
# ...
#
#
#
#
#
#
#  CentralNotice
#
#
#
#
#
#
# Trachycephalus
#
#
#
#
# From Wikipedia, the free encyclopedia
#
#
#
#
#
# 					Jump to:
# navigation
# ,
# search
#
#
#
#
#
#
#
#
#
#
# Casque-headed tree frogs
#
#
#
#
#
#
#
#
#
#
#
#
# Trachycephalus resinifictrix
#
#
#
#
#
#
# Scientific classification
#
#
#
#
#
#
# Kingdom:
#
#
# Animalia
#
#
#
#
#
#
# Phylum:
#
#
# Chordata
#
#
#
#
#
#
# Class:
#
#
# Amphibia
#
#
#
#
#
#
# Order:
#
#
# Anura
#
#
#
#
#
#
# Family:
#
#
# Hylidae
#
#
#
#
#
#
# Subfamily:
#
#
# Hylinae
#
#
#
#
#
#
# Genus:
#
#
# Trachycephalus
#
#
# Tschudi
# , 1838
#
#
#
#
#
#
# Species
#
#
#
#
#
#
#
#
# See text.
#
#
#
#
#
#
#
#
# Synonyms
#
#
#
#
#
#
#
#
# Phrynohyas
#
# Fitzinger, 1843
#
#
#
#
#
#
#
#
#
#
# Trachycephalus
#  is a
# genus
#  of
# frogs
# , the casque-headed tree frogs, in the
# Hylidae
#  family. They are found in Mexico, Central America, and South America. In a recent revision, the seven species of the genus
# Phrynohyas
#  were included in this genus, and
# Phrynohyas
#  is now considered a synonym of
# Trachycephalus
# .
# [1]
#  These frogs inhabit the canopies of tropical rainforests, where they breed in tree cavities, and seldom, if ever, descend to the ground.
#
#
# Species
# [
# edit
# ]
#
#
#
#
#
#
# Binomial name and author
#
#
# Common name
#
#
#
#
#
#
# T. atlas
#
# Bokermann, 1966
#
#
# Bokermann's casque-headed tree frog
#
#
#
#
#
#
# T. coriaceus
#
# (Peters, 1867)
#
#
# Surinam golden-eyed tree frog
#
#
#
#
#
#
# T. dibernardoi
#
# Kwet and Solé, 2008
#
#
#
#
#
#
#
#
# T. hadroceps
#
# (Duellman and Hoogmoed, 1992)
#
#
# New River tree frog
#
#
#
#
#
#
# T. imitatrix
#
# (Miranda-Ribeiro, 1926)
#
#
# Rio golden-eyed tree frog
#
#
#
#
#
#
# T. jordani
#
# (Stejneger and Test, 1891)
#
#
# Jordan's casque-headed tree frog
#
#
#
#
#
#
# T. lepidus
#
# (Pombal, Haddad, and Cruz, 2003)
#
#
#
#
#
#
#
#
# T. mambaiensis
#
# Cintra, Silva, Silva, Garcia and Zaher, 2009
#
#
#
#
#
#
#
#
# T. mesophaeus
#
# (Hensel, 1867)
#
#
# Porto Alegre golden-eyed tree frog
#
#
#
#
#
#
# T. nigromaculatus
#
# Tschudi, 1838
#
#
# black-spotted casque-headed tree frog
#
#
#
#
#
#
# T. resinifictrix
#
# (Goeldi, 1907)
#
#
# Mission golden-eyed tree frog
#  or Amazon milk frog
#
#
#
#
#
#
# T. venulosus
#
# (Laurenti, 1768)
#
#
# veined tree frog
#
#
#
#
#
#
# References
# [
# edit
# ]
#
#
#
#
#
#
# ^
#
# Faivovich, J.; Haddad, C.F.B.; Garcia, P.C.A.; Frost, D.R.; Campbell, J.A.; Wheeler, W.C.
# , 2005: Systematic Review of the Frog Family Hylidae, with Special Reference to Hylinae: Phylogenetic Analysis and Taxonomic Revision.
# Bulletin of the American Museum of Natural History
# , Num.
# 294
# , pp.1-240.
# [1]
# .
#
#
#
#
#
#
# External links
# [
# edit
# ]
#
#
#
#
# Frost, Darrel R
# . 2007. Amphibian Species of the World: an Online Reference. Version 5.1 (10 October, 2007).
# Trachycephalus
# . Electronic Database accessible at
# http://research.amnh.org/herpetology/amphibia/index.php
# . American Museum of Natural History, New York, USA. (Accessed: Apr 25, 2008).
#
#
# AmphibiaWeb: Information on amphibian biology and conservation.
#  [web application]. 2008. Berkeley, California:
# Trachycephalus
# . AmphibiaWeb, available at
# http://amphibiaweb.org/
# . (Accessed: Apr 25, 2008).
#
#
# eol - Encyclopedia of Life
#  taxon
# Trachycephalus
#  at
# http://www.eol.org
# .
#
#
# ITIS - Integrated Taxonomic Information System on-line database
#  Taxon
# Trachycephalus
#  at
# http://www.itis.gov/index.html
# . (Accessed: Apr 25, 2008).
#
#
# GBIF - Global Biodiversity Information Facility
#  Taxon
# Trachycephalus
#  at
# http://data.gbif.org/welcome.htm
#
#
#
#
#
#
#
#
#
#
#
#
# This
# Hylinae
#  article is a
# stub
# . You can help Wikipedia by
# expanding it
# .
#
#
#
#
#
#
# v
#
#
# t
#
#
# e
#
#
#
#
#
#
#
#
#
#
#
#
#
# NewPP limit report
# Parsed by mw1187
# Cached time: 20170316043651
# Cache expiry: 2592000
# Dynamic content: false
# CPU time usage: 0.148 seconds
# Real time usage: 0.180 seconds
# Preprocessor visited node count: 3261/1000000
# Preprocessor generated node count: 0/1500000
# Post‐expand include size: 12211/2097152 bytes
# Template argument size: 3094/2097152 bytes
# Highest expansion depth: 24/40
# Expensive parser function count: 0/500
# Lua time usage: 0.033/10.000 seconds
# Lua memory usage: 1.84 MB/50 MB
#
#
#
#
# Transclusion expansion time report (%,ms,calls,template)
# 100.00%  145.918      1 -total
#  73.91%  107.854      1 Template:Taxobox
#  66.01%   96.324      1 Template:Taxobox/core
#  42.61%   62.180     14 Template:Taxobox_colour
#  37.19%   54.272     14 Template:Delink
#  21.19%   30.926      1 Template:If_empty
#  18.37%   26.800     11 Template:Sets_taxobox_colour
#  16.68%   24.335      7 Template:Taxonomy
#  12.62%   18.411      1 Template:Italics_title
#   8.29%   12.094     14 Template:Anglicise_rank
#
#
#
#  Saved in parser cache with key enwiki:pcache:idhash:2961159-0!*!0!!*!4!* and timestamp 20170316043651 and revision id 732570040
#
#
#
#
#
# 						Retrieved from "
# https://en.wikipedia.org/w/index.php?title=Trachycephalus&oldid=732570040
# "
#
#
# Categories
# :
# Hylinae
# Trachycephalus
# Amphibian genera
# Taxa named by Johann Jakob von Tschudi
# Hylinae stubs
# Hidden categories:
# Articles with 'species' microformats
# All stub articles
#
#
#
#
#
#
#
#
#
# Navigation menu
#
#
#
#
#
#
# Personal tools
#
#
#
#
# Not logged in
# Talk
# Contributions
# Create account
# Log in
#
#
#
#
#
#
#
#
#
# Namespaces
#
#
#
#
# Article
#
#
# Talk
#
#
#
#
#
#
#
#
#
#
# Variants
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Views
#
#
#
#
# Read
#
#
# Edit
#
#
# View history
#
#
#
#
#
#
#
#
# More
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Navigation
#
#
#
#
#
#
# Main page
# Contents
# Featured content
# Current events
# Random article
# Donate to Wikipedia
# Wikipedia store
#
#
#
#
#
#
#
#
#
# Interaction
#
#
#
#
#
#
# Help
# About Wikipedia
# Community portal
# Recent changes
# Contact page
#
#
#
#
#
#
#
#
#
# Tools
#
#
#
#
#
#
# What links here
# Related changes
# Upload file
# Special pages
# Permanent link
# Page information
# Wikidata item
# Cite this page
#
#
#
#
#
#
#
#
#
# Print/export
#
#
#
#
#
#
# Create a book
# Download as PDF
# Printable version
#
#
#
#
#
#
#
#
#
# In other projects
#
#
#
#
#
#
# Wikimedia Commons
# Wikispecies
#
#
#
#
#
#
#
#
#
# Languages
#
#
#
#
#
#
# Català
# Cebuano
# Deutsch
# Español
# Euskara
# Français
# Magyar
# Nederlands
# Polski
# Português
# Русский
# Svenska
# Українська
# Tiếng Việt
# Winaray
#
#
#
# Edit links
#
#
#
#
#
#
#
#
#
#
#
#
#
#  This page was last modified on 1 August 2016, at 20:39.
#
#
# Text is available under the
# Creative Commons Attribution-ShareAlike License
# ;
# additional terms may apply.  By using this site, you agree to the
# Terms of Use
#  and
# Privacy Policy
# . Wikipedia® is a registered trademark of the
# Wikimedia Foundation, Inc.
# , a non-profit organization.
#
#
#
#
#
#
# Privacy policy
#
#
# About Wikipedia
#
#
# Disclaimers
#
#
# Contact Wikipedia
#
#
# Developers
#
#
# Cookie statement
#
#
# Mobile view
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Indexed:  en.wikipedia.org/wiki/Trachycephalus.html
# Processing File: en.wikipedia.org/wiki/Triprion.html
#
#
#
#
#
#
#
#
#
#
#
#
#
#  CentralNotice
#
#
#
#
#
#
# Triprion
#
#
#
#
# From Wikipedia, the free encyclopedia
#
#
#
#
#
# 					Jump to:
# navigation
# ,
# search
#
#
#
#
#
#
#
#
#
#
# Triprion
#
#
#
#
#
#
#
#
#
#
#
#
# Triprion petasatus
#
#
#
#
#
#
# Scientific classification
#
#
#
#
#
#
# Kingdom:
#
#
# Animalia
#
#
#
#
#
#
# Phylum:
#
#
# Chordata
#
#
#
#
#
#
# Class:
#
#
# Amphibia
#
#
#
#
#
#
# Order:
#
#
# Anura
#
#
#
#
#
#
# Family:
#
#
# Hylidae
#
#
#
#
#
#
# Subfamily:
#
#
# Hylinae
#
#
#
#
#
#
# Genus:
#
#
# Triprion
#
#
# Cope
# , 1866
#
#
#
#
#
#
# Species
#
#
#
#
#
#
#
#
# See text.
#
#
#
#
#
#
#
#
#
#
# Triprion
#  is a genus of
# frogs
#  (the
# shovel-headed tree frogs
# ) in the
# Hylidae
#  family found in the Pacific lowlands of
# Mexico
# , the
# Yucatán Peninsula
# , and
# Guatemala
# . These frogs hide in tree-holes and plug the entrance with their strange-looking, bony heads.
#
#
# Species
# [
# edit
# ]
#
#
# Two species in this genus are recognized:
#
#
#
#
# Triprion petasatus
#
# (Cope, 1865)
#  - Yucatan shovel-headed tree frog
#
#
# Triprion spatulatus
#
# Günther, 1882
#  - Mexican shovel-headed tree frog
#
#
#
#
# External links
# [
# edit
# ]
#
#
#
#
# Frost, Darrel R
# . 2007. Amphibian Species of the World: an Online Reference. Version 5.1 (10 October 2007).
# Triprion
# . Electronic Database accessible at
# http://research.amnh.org/herpetology/amphibia/index.php
# . American Museum of Natural History, New York, USA. (Accessed: Apr 24, 2008).
#
#
# AmphibiaWeb: Information on amphibian biology and conservation.
#  [web application]. 2008. Berkeley, California:
# Triprion
# . AmphibiaWeb, available at
# http://amphibiaweb.org/
# . (Accessed: Apr 24, 2008).
#
#
# eol - Encyclopedia of Life
#  taxon
# Triprion
#  at
# http://www.eol.org
# .
#
#
# ITIS - Integrated Taxonomic Information System on-line database
#  Taxon
# Triprion
#  at
# http://www.itis.gov/index.html
# . (Accessed: Apr 24, 2008).
#
#
# GBIF - Global Biodiversity Information Facility
#  Taxon
# Triprion
#  at
# http://data.gbif.org/welcome.htm
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# This
# Hylinae
#  article is a
# stub
# . You can help Wikipedia by
# expanding it
# .
#
#
#
#
#
#
# v
#
#
# t
#
#
# e
#
#
#
#
#
#
#
#
#
#
#
#
#
# NewPP limit report
# Parsed by mw1210
# Cached time: 20170316043652
# Cache expiry: 2592000
# Dynamic content: false
# CPU time usage: 0.124 seconds
# Real time usage: 0.157 seconds
# Preprocessor visited node count: 3086/1000000
# Preprocessor generated node count: 0/1500000
# Post‐expand include size: 10578/2097152 bytes
# Template argument size: 2158/2097152 bytes
# Highest expansion depth: 24/40
# Expensive parser function count: 0/500
# Lua time usage: 0.032/10.000 seconds
# Lua memory usage: 1.84 MB/50 MB
#
#
#
#
# Transclusion expansion time report (%,ms,calls,template)
# 100.00%  136.079      1 -total
#  73.96%  100.643      1 Template:Taxobox
#  65.84%   89.593      1 Template:Taxobox/core
#  41.30%   56.206     14 Template:Taxobox_colour
#  36.08%   49.104     14 Template:Delink
#  21.23%   28.894      1 Template:If_empty
#  18.24%   24.825     11 Template:Sets_taxobox_colour
#  17.58%   23.919      7 Template:Taxonomy
#  14.93%   20.320      1 Template:Italics_title
#   8.70%   11.842     14 Template:Anglicise_rank
#
#
#
#  Saved in parser cache with key enwiki:pcache:idhash:2969396-0!*!0!!*!4!* and timestamp 20170316043652 and revision id 732570086
#
#
#
#
#
# 						Retrieved from "
# https://en.wikipedia.org/w/index.php?title=Triprion&oldid=732570086
# "
#
#
# Categories
# :
# Hylinae
# Triprion
# Amphibian genera
# Taxa named by Edward Drinker Cope
# Hylinae stubs
# Hidden categories:
# Articles with 'species' microformats
# All stub articles
#
#
#
#
#
#
#
#
#
# Navigation menu
#
#
#
#
#
#
# Personal tools
#
#
#
#
# Not logged in
# Talk
# Contributions
# Create account
# Log in
#
#
#
#
#
#
#
#
#
# Namespaces
#
#
#
#
# Article
#
#
# Talk
#
#
#
#
#
#
#
#
#
#
# Variants
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Views
#
#
#
#
# Read
#
#
# Edit
#
#
# View history
#
#
#
#
#
#
#
#
# More
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Navigation
#
#
#
#
#
#
# Main page
# Contents
# Featured content
# Current events
# Random article
# Donate to Wikipedia
# Wikipedia store
#
#
#
#
#
#
#
#
#
# Interaction
#
#
#
#
#
#
# Help
# About Wikipedia
# Community portal
# Recent changes
# Contact page
#
#
#
#
#
#
#
#
#
# Tools
#
#
#
#
#
#
# What links here
# Related changes
# Upload file
# Special pages
# Permanent link
# Page information
# Wikidata item
# Cite this page
#
#
#
#
#
#
#
#
#
# Print/export
#
#
#
#
#
#
# Create a book
# Download as PDF
# Printable version
#
#
#
#
#
#
#
#
#
# In other projects
#
#
#
#
#
#
# Wikimedia Commons
# Wikispecies
#
#
#
#
#
#
#
#
#
# Languages
#
#
#
#
#
#
# Català
# Cebuano
# Español
# Magyar
# Tiếng Việt
#
#
#
# Edit links
#
#
#
#
#
#
#
#
#
#
#
#
#
#  This page was last modified on 1 August 2016, at 20:40.
#
#
# Text is available under the
# Creative Commons Attribution-ShareAlike License
# ;
# additional terms may apply.  By using this site, you agree to the
# Terms of Use
#  and
# Privacy Policy
# . Wikipedia® is a registered trademark of the
# Wikimedia Foundation, Inc.
# , a non-profit organization.
#
#
#
#
#
#
# Privacy policy
#
#
# About Wikipedia
#
#
# Disclaimers
#
#
# Contact Wikipedia
#
#
# Developers
#
#
# Cookie statement
#
#
# Mobile view
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Indexed:  en.wikipedia.org/wiki/Triprion.html
# Processing File: en.wikipedia.org/wiki/Xenohyla.html
#
#
#
#
#
#
#
#
#
#
#
#
#
#  CentralNotice
#
#
#
#
#
#
# Xenohyla
#
#
#
#
# From Wikipedia, the free encyclopedia
#
#
#
#
#
# 					Jump to:
# navigation
# ,
# search
#
#
#
#
#
#
#
#
#
#
# Xenohyla
#
#
#
#
#
#
# Scientific classification
#
#
#
#
#
#
# Kingdom:
#
#
# Animalia
#
#
#
#
#
#
# Phylum:
#
#
# Chordata
#
#
#
#
#
#
# Class:
#
#
# Amphibia
#
#
#
#
#
#
# Order:
#
#
# Anura
#
#
#
#
#
#
# Family:
#
#
# Hylidae
#
#
#
#
#
#
# Subfamily:
#
#
# Hylinae
#
#
#
#
#
#
# Genus:
#
#
# Xenohyla
#
#
# Izecksohn
# , 1998
#
#
#
#
#
#
# Species
#
#
#
#
#
#
#
#
# See text.
#
#
#
#
#
#
#
#
#
#
# Xenohyla
#  is a genus of
# frog
#  in the
# Hylidae
#  family, and are found in the
# Brazilian
#  states of
# Bahia
#  and
# Rio de Janeiro
# .
#
#
# Species
# [
# edit
# ]
#
#
# Only two species are recognized in this genus:
#
#
#
#
# Xenohyla eugenioi
#
# Caramaschi, 1998
#
#
# Xenohyla truncata
#
# (Izecksohn, 1959)
#  - Izecksohn's Brazilian tree frog
#
#
#
#
#
#
# External links
# [
# edit
# ]
#
#
#
#
# Frost, Darrel R
# . 2007. Amphibian Species of the World: an Online Reference. Version 5.1 (October 10, 2007).
# Xenohyla
# [
# permanent dead link
# ]
# . Electronic Database accessible at
# http://research.amnh.org/herpetology/amphibia/index.php
# .
# [
# permanent dead link
# ]
#  American Museum of Natural History, New York, USA. (Accessed: Apr 22, 2008).
#
#
# AmphibiaWeb: Information on amphibian biology and conservation.
#  [web application]. 2008. Berkeley, California:
# Xenohyla
# . AmphibiaWeb, available at
# http://web.archive.org/web/20040827082534/http://www.amphibiaweb.org:80/
#  (Accessed: Apr 22, 2008).
#
#
# eol – Encyclopedia of Life
#  taxon
# Xenohyla
#  at
# http://www.eol.org
# .
#
#
# ITIS – Integrated Taxonomic Information System on-line database
#  Taxon
# Xenohyla
#  at
# http://www.itis.gov/index.html
# .
# [
# permanent dead link
# ]
#  (Accessed: Apr 22, 2008).
#
#
# GBIF – Global Biodiversity Information Facility
#  Taxon
# Xenohyla
#  at
# http://web.archive.org/web/20080501142231/http://data.gbif.org:80/welcome.htm
#
#
#
#
#
#
#
#
#
#
#
#
# This
# Hylinae
#  article is a
# stub
# . You can help Wikipedia by
# expanding it
# .
#
#
#
#
#
#
# v
#
#
# t
#
#
# e
#
#
#
#
#
#
#
#
#
#
#
#
#
# NewPP limit report
# Parsed by mw1161
# Cached time: 20170311225429
# Cache expiry: 2592000
# Dynamic content: false
# CPU time usage: 0.184 seconds
# Real time usage: 0.225 seconds
# Preprocessor visited node count: 3382/1000000
# Preprocessor generated node count: 0/1500000
# Post‐expand include size: 15496/2097152 bytes
# Template argument size: 3661/2097152 bytes
# Highest expansion depth: 24/40
# Expensive parser function count: 1/500
# Lua time usage: 0.055/10.000 seconds
# Lua memory usage: 2.12 MB/50 MB
#
#
#
#
# Transclusion expansion time report (%,ms,calls,template)
# 100.00%  207.652      1 -total
#  60.83%  126.310      1 Template:Taxobox
#  54.50%  113.170      1 Template:Taxobox/core
#  32.24%   66.951     14 Template:Taxobox_colour
#  27.96%   58.062     14 Template:Delink
#  18.12%   37.623      3 Template:Dead_link
#  17.25%   35.818      7 Template:Taxonomy
#  15.81%   32.836      1 Template:If_empty
#  13.43%   27.885     11 Template:Sets_taxobox_colour
#  13.10%   27.196      3 Template:Fix
#
#
#
#  Saved in parser cache with key enwiki:pcache:idhash:2969420-0!*!*!!*!4!* and timestamp 20170311225429 and revision id 738097366
#
#
#
#
#
# 						Retrieved from "
# https://en.wikipedia.org/w/index.php?title=Xenohyla&oldid=738097366
# "
#
#
# Categories
# :
# Hylinae stubs
# Hylinae
# Xenohyla
# Amphibian genera
# Taxa named by Eugênio Izecksohn
# Hidden categories:
# Articles with 'species' microformats
# All articles with dead external links
# Articles with dead external links from July 2016
# Articles with permanently dead external links
# All stub articles
#
#
#
#
#
#
#
#
#
# Navigation menu
#
#
#
#
#
#
# Personal tools
#
#
#
#
# Not logged in
# Talk
# Contributions
# Create account
# Log in
#
#
#
#
#
#
#
#
#
# Namespaces
#
#
#
#
# Article
#
#
# Talk
#
#
#
#
#
#
#
#
#
#
# Variants
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Views
#
#
#
#
# Read
#
#
# Edit
#
#
# View history
#
#
#
#
#
#
#
#
# More
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Navigation
#
#
#
#
#
#
# Main page
# Contents
# Featured content
# Current events
# Random article
# Donate to Wikipedia
# Wikipedia store
#
#
#
#
#
#
#
#
#
# Interaction
#
#
#
#
#
#
# Help
# About Wikipedia
# Community portal
# Recent changes
# Contact page
#
#
#
#
#
#
#
#
#
# Tools
#
#
#
#
#
#
# What links here
# Related changes
# Upload file
# Special pages
# Permanent link
# Page information
# Wikidata item
# Cite this page
#
#
#
#
#
#
#
#
#
# Print/export
#
#
#
#
#
#
# Create a book
# Download as PDF
# Printable version
#
#
#
#
#
#
#
#
#
# In other projects
#
#
#
#
#
#
# Wikispecies
#
#
#
#
#
#
#
#
#
# Languages
#
#
#
#
#
#
# Català
# Cebuano
# Español
# Euskara
# Français
# Magyar
# Nederlands
# Polski
# Português
# Svenska
# Tiếng Việt
# Winaray
#
#
#
# Edit links
#
#
#
#
#
#
#
#
#
#
#
#
#
#  This page was last modified on 6 September 2016, at 21:57.
#
#
# Text is available under the
# Creative Commons Attribution-ShareAlike License
# ;
# additional terms may apply.  By using this site, you agree to the
# Terms of Use
#  and
# Privacy Policy
# . Wikipedia® is a registered trademark of the
# Wikimedia Foundation, Inc.
# , a non-profit organization.
#
#
#
#
#
#
# Privacy policy
#
#
# About Wikipedia
#
#
# Disclaimers
#
#
# Contact Wikipedia
#
#
# Developers
#
#
# Cookie statement
#
#
# Mobile view
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Indexed:  en.wikipedia.org/wiki/Xenohyla.html
# Unhandled File
# Unhandled File
# Unhandled File
# Unhandled File
# Unhandled File
# recursing into  MAIN.tmp
# Processing folder:  MAIN.tmp
# root =  en.wikipedia.org/wiki/MAIN.tmp
# Unhandled File

# %% [markdown]
# ---
# <a id='search_me' ></a>
#
# ### 5) Executing Queries
#
# Read:
#   http://whoosh.readthedocs.io/en/latest/searching.html
#
# Previously, we hard-coded query strinigs into the code cells.
#
# Now, use the `input()` function collect a query string from the user.
# Then execute the search.

# %%
epass = input()
# Out:
# "America"

# %%
from whoosh.qparser import QueryParser

# Write your code below this comment:
# --------------------------------------
qp = QueryParser("content", schema=ix.schema)
q = qp.parse(epass)
with ix.searcher() as s:
    results = s.search(q)
    for hit in results:
        print(hit)
# Out:
# <Hit {'filename': 'en.wikipedia.org/wiki/Smilisca.html', 'class_': ['infobox', 'biota'], 'content': '  CentralNotice Mexican burrowing tree frogFrom Wikipedia, the free encyclopedia\xa0\xa0(Redirected from Smilisca)\t\t\t\t\tJump to:\t\t\t\t\tnavigation, \t\t\t\t\tsearchSmiliscaSmilisca phaeotaScientific classificationKingdom:AnimaliaPhylum:ChordataClass:AmphibiaOrder:AnuraFamily:HylidaeSubfamily:HylinaeGenus:SmiliscaCope, 1865SpeciesSee text.The Mexican burrowing tree frog (Smilisca, also known as the cross-banded tree frog) is a genus of frogs in the Hylidae family found in Mexico, southern Texas and Arizona, Central America, and northwestern South America. In a recent revision of the Hylidae family, the two species of the previous genus Pternohyla were included in this genus.[1] Its name is from the Ancient Greek smiliskos (‘little knife’), referring to the pointed frontoparietal processes.[2]Species[edit]Binomial name and authorCommon nameS. baudinii (Duméril and Bibron, 1841)common Mexican tree frogS. cyanosticta (Smith, 1953)blue-spotted Mexican tree frogS. dentata (Smith, 1957)upland burrowing tree frogS. fodiens (Boulenger, 1882)lowland burrowing tree frogS. phaeota (Cope, 1862)New Granada cross-banded tree frog or masked tree frogS. puma (Cope, 1885)Nicaragua cross-banded tree frogS. sila Duellman and Trueb, 1966Panama cross-banded tree frogS. sordida (Peters, 1863)Veragua cross-banded tree frogReferences[edit]^ Faivovich, J.; Haddad, C.F.B.; Garcia, P.C.A.; Frost, D.R.; Campbell, J.A.; Wheeler, W.C., 2005: Systematic Review of the Frog Family Hylidae, with Special Reference to Hylinae: Phylogenetic Analysis and Taxonomic Revision. Bulletin of the American Museum of Natural History, Num. 294, pp.1-240. [1]^ Dodd, C. Kenneth (2013). Frogs of the United States and Canada. 1. The Johns Hopkins University Press. p.\xa020. ISBN\xa0978-1-4214-0633-6.\xa0Duellman, W.E. (1993): Amphibian species of the world - Univ. Kansas Publ. Mus. Nat. Hist. (Spec. Publ.), Kansas 21, pp. [1-372]External links[edit]Frost, Darrel R. 2007. Amphibian Species of the World: an Online Reference. Version 5.1 (10 October 2007). Smilisca. Electronic Database accessible at http://research.amnh.org/herpetology/amphibia/index.php. American Museum of Natural History, New York, USA. (Accessed: April 23, 2008).AmphibiaWeb: Information on amphibian biology and conservation. [web application]. 2008. Berkeley, California: Smilisca. AmphibiaWeb, available at http://amphibiaweb.org/. (Accessed: April 23, 2008).Wikispecies has information related to: SmiliscasTaxon identifiersEoL:\xa041637GBIF:\xa02428679ITIS:\xa0173535NCBI:\xa044371This Hylinae article is a stub. You can help Wikipedia by expanding it.vte \nNewPP limit report\nParsed by mw1219\nCached time: 20170311224945\nCache expiry: 2592000\nDynamic content: false\nCPU time usage: 0.364 seconds\nReal time usage: 0.474 seconds\nPreprocessor visited node count: 4935/1000000\nPreprocessor generated node count: 0/1500000\nPost‐expand include size: 23578/2097152 bytes\nTemplate argument size: 3949/2097152 bytes\nHighest expansion depth: 24/40\nExpensive parser function count: 4/500\nLua time usage: 0.122/10.000 seconds\nLua memory usage: 4.46 MB/50 MBTransclusion expansion time report (%,ms,calls,template)\n100.00%  441.926      1 -total\n 46.22%  204.265      1 Template:Taxonbar\n 44.77%  197.859      1 Template:Navbox\n 41.73%  184.437      1 Template:1x\n 40.05%  177.006     34 Template:Taxonbar/Link\n 37.64%  166.335     44 Template:If_empty\n 34.97%  154.528      1 Template:Taxobox\n 31.59%  139.620      1 Template:Taxobox/core\n 21.63%   95.598     14 Template:Taxobox_colour\n 19.53%   86.304     14 Template:Delink Saved in parser cache with key enwiki:pcache:idhash:2960637-0!*!0!!*!4!* and timestamp 20170311224944 and revision id 742621186\n  \t\t\t\t\t\tRetrieved from "https://en.wikipedia.org/w/index.php?title=Mexican_burrowing_tree_frog&oldid=742621186"\t\t\t\t\tCategories: HylinaeSmiliscaFauna of Mex ...
# <Hit {'filename': 'en.wikipedia.org/wiki/Trachycephalus.html', 'class_': ['infobox', 'biota'], 'content': '  CentralNotice TrachycephalusFrom Wikipedia, the free encyclopedia\t\t\t\t\tJump to:\t\t\t\t\tnavigation, \t\t\t\t\tsearchCasque-headed tree frogsTrachycephalus resinifictrixScientific classificationKingdom:AnimaliaPhylum:ChordataClass:AmphibiaOrder:AnuraFamily:HylidaeSubfamily:HylinaeGenus:TrachycephalusTschudi, 1838SpeciesSee text.SynonymsPhrynohyas Fitzinger, 1843Trachycephalus is a genus of frogs, the casque-headed tree frogs, in the Hylidae family. They are found in Mexico, Central America, and South America. In a recent revision, the seven species of the genus Phrynohyas were included in this genus, and Phrynohyas is now considered a synonym of Trachycephalus.[1] These frogs inhabit the canopies of tropical rainforests, where they breed in tree cavities, and seldom, if ever, descend to the ground.Species[edit]Binomial name and authorCommon nameT. atlas Bokermann, 1966Bokermann\'s casque-headed tree frogT. coriaceus (Peters, 1867)Surinam golden-eyed tree frogT. dibernardoi Kwet and Solé, 2008T. hadroceps (Duellman and Hoogmoed, 1992)New River tree frogT. imitatrix (Miranda-Ribeiro, 1926)Rio golden-eyed tree frogT. jordani (Stejneger and Test, 1891)Jordan\'s casque-headed tree frogT. lepidus (Pombal, Haddad, and Cruz, 2003)T. mambaiensis Cintra, Silva, Silva, Garcia and Zaher, 2009T. mesophaeus (Hensel, 1867)Porto Alegre golden-eyed tree frogT. nigromaculatus Tschudi, 1838black-spotted casque-headed tree frogT. resinifictrix (Goeldi, 1907)Mission golden-eyed tree frog or Amazon milk frogT. venulosus (Laurenti, 1768)veined tree frogReferences[edit]^ Faivovich, J.; Haddad, C.F.B.; Garcia, P.C.A.; Frost, D.R.; Campbell, J.A.; Wheeler, W.C., 2005: Systematic Review of the Frog Family Hylidae, with Special Reference to Hylinae: Phylogenetic Analysis and Taxonomic Revision. Bulletin of the American Museum of Natural History, Num. 294, pp.1-240. [1].External links[edit]Frost, Darrel R. 2007. Amphibian Species of the World: an Online Reference. Version 5.1 (10 October, 2007). Trachycephalus. Electronic Database accessible at http://research.amnh.org/herpetology/amphibia/index.php. American Museum of Natural History, New York, USA. (Accessed: Apr 25, 2008).AmphibiaWeb: Information on amphibian biology and conservation. [web application]. 2008. Berkeley, California: Trachycephalus. AmphibiaWeb, available at http://amphibiaweb.org/. (Accessed: Apr 25, 2008).eol - Encyclopedia of Life taxon Trachycephalus at http://www.eol.org.ITIS - Integrated Taxonomic Information System on-line database Taxon Trachycephalus at http://www.itis.gov/index.html. (Accessed: Apr 25, 2008).GBIF - Global Biodiversity Information Facility Taxon Trachycephalus at http://data.gbif.org/welcome.htmThis Hylinae article is a stub. You can help Wikipedia by expanding it.vte \nNewPP limit report\nParsed by mw1187\nCached time: 20170316043651\nCache expiry: 2592000\nDynamic content: false\nCPU time usage: 0.148 seconds\nReal time usage: 0.180 seconds\nPreprocessor visited node count: 3261/1000000\nPreprocessor generated node count: 0/1500000\nPost‐expand include size: 12211/2097152 bytes\nTemplate argument size: 3094/2097152 bytes\nHighest expansion depth: 24/40\nExpensive parser function count: 0/500\nLua time usage: 0.033/10.000 seconds\nLua memory usage: 1.84 MB/50 MBTransclusion expansion time report (%,ms,calls,template)\n100.00%  145.918      1 -total\n 73.91%  107.854      1 Template:Taxobox\n 66.01%   96.324      1 Template:Taxobox/core\n 42.61%   62.180     14 Template:Taxobox_colour\n 37.19%   54.272     14 Template:Delink\n 21.19%   30.926      1 Template:If_empty\n 18.37%   26.800     11 Template:Sets_taxobox_colour\n 16.68%   24.335      7 Template:Taxonomy\n 12.62%   18.411      1 Template:Italics_title\n  8.29%   12.094     14 Template:Anglicise_rank Saved in parser cache with key enwiki:pcache:idhash:2961159-0!*!0!!*!4!* and timestamp 201703160 ...
# <Hit {'filename': 'en.wikipedia.org/wiki/Ecnomiohyla.html', 'class_': ['infobox', 'biota'], 'content': '  CentralNotice EcnomiohylaFrom Wikipedia, the free encyclopedia\t\t\t\t\tJump to:\t\t\t\t\tnavigation, \t\t\t\t\tsearchFringe-limbed treefrogsEcnomiohyla rabborumScientific classification Kingdom:AnimaliaPhylum:ChordataClass:AmphibiaOrder:AnuraFamily:HylidaeSubfamily:HylinaeGenus:EcnomiohylaFaivovich et al., 2005[1]Type speciesHypsiboas miliariusCope, 1886SpeciesSee textEcnomiohyla, commonly known as fringe-limbed treefrogs or marvelous frogs, is a genus of frogs in the family Hylidae.[2] This genus was erected in 2005 following a major revision of Hylidae. The ten original species in this genus (E. rabborum and E. sukia are later discoveries) were previously placed in the genus Hyla. The generic name Ecnomiohyla comes from Greek ecnomios ("marvelous" or "unusual") and Hylas, the companion of Hercules.[1][3][4]Contents1 Description2 Species3 See also4 References5 External linksDescription[edit]Members of Ecnomiohyla are moderately sized to very large frogs with distinctive scalloped fringes of skin on the outer edges of their limbs and relatively immense hands and feet. They are found in the canopies of wet forested highlands of southern Mexico through Central America to Colombia.[5] They are capable of gliding using their webbed hands and feet.[6]Species[edit]The genus currently includes 12 species,[2] though several authors have proposed that E. tuberculosa may not belong to the genus.[3][5]Binomial name and authorCommon nameEcnomiohyla echinata (Duellman, 1961)Oaxacan fringe-limbed treefrogEcnomiohyla fimbrimembra (Taylor, 1948)Heredia treefrogEcnomiohyla miliaria (Cope, 1886)Cope\'s brown treefrogEcnomiohyla minera (Wilson, McCranie, and Williams, 1985)Guatemala treefrogEcnomiohyla miotympanum (Cope, 1863)Small-eared treefrogEcnomiohyla phantasmagoria (Dunn, 1943)Ecnomiohyla rabborum Mendelson, Savage, Griffith, Ross, Kubicki, and Gagliardo, 2008Rabb\'s fringe-limbed treefrogEcnomiohyla salvaje (Wilson, McCranie, and Williams, 1985)Copan treefrogEcnomiohyla sukia Savage & Kubicki, 2010Ecnomiohyla thysanota (Duellman, 1966)Cerro Mali treefrogEcnomiohyla tuberculosa (Boulenger, 1882)Canelos treefrogEcnomiohyla valancifer (Firschein and Smith, 1956)San Martin fringe-limbed treefrogSee also[edit]Flying frogReferences[edit]^ a b Julián Faivovich; Célio F.B. Haddad; Paulo C.A. Garcia; Darrel R. Frost; Jonathan A. Campbell; Ward C. Wheeler (2005). "Systematic review of the frog family Hylidae, with special reference to Hylinae: phylogenetic analysis and taxonomic revision". Bulletin of the American Museum of Natural History (294): 1–240. doi:10.1206/0003-0090(2005)294[0001:SROTFF]2.0.CO;2.\xa0^ a b Frost, Darrel R. (2014). "Ecnomiohyla Faivovich, Haddad, Garcia, Frost, Campbell, and Wheeler, 2005". Amphibian Species of the World: an Online Reference. Version 6.0. American Museum of Natural History. Retrieved 23 May 2014.\xa0^ a b Joseph R. Mendelson III; Jay M. Savage; Edgardo Griffith; Heidi Ross; Brian Kubicki; Ronald Gagliardo (2008). "Spectacular new gliding species of Ecnomiohyla (Anura: Hylidae) from Central Panama". Journal of Herpetology. 42 (4): 750–759. doi:10.1670/08-025R1.1.\xa0^ Charles W. Myers; Richard B. Stothers (2006). "The myth of Hylas revisited: the frog name Hyla and other commentary on Specimen medicum (1768) of J. N. Laurenti, the "father of herpetology"". Archives of Natural History. 33: 241–266. doi:10.3366/anh.2006.33.2.241.\xa0^ a b Jay M. Savage; Brian Kubicki (2010). "A new species of fringe-limb frog, genus Ecnomiohyla (Anura: Hylidae), from the Atlantic slope of Costa Rica, Central America". Zootaxa. 2719: 21–34.\xa0^ Robert W. Hansen, ed. (2008). "About our cover: Ecnomiohyla rabborum". Herpetological Review. 42 (1): 3.\xa0External links[edit]AmphibiaWeb: Information on amphibian biology and conservation. [web application]. 2008. Berkeley, California: Ecnomiohyla. AmphibiaWeb, available at http ...
# <Hit {'filename': 'en.wikipedia.org/wiki/Pseudis.html', 'class_': ['infobox', 'biota'], 'content': '  CentralNotice PseudisFrom Wikipedia, the free encyclopedia\t\t\t\t\tJump to:\t\t\t\t\tnavigation, \t\t\t\t\tsearchPseudisPseudis paradoxaScientific classification Kingdom:AnimaliaPhylum:ChordataClass:AmphibiaOrder:AnuraFamily:HylidaeSubfamily:HylinaeGenus:PseudisWagler, 1830Type speciesRana paradoxaLinnaeus, 1758SpeciesSee text.Pseudis is a genus of frogs (swimming frogs) in the Hylidae family, and are found in the Guianas, Colombia, Venezuela, Trinidad, Brazil, Paraguay, southeastern Peru, eastern Bolivia, northeastern Argentina, and Uruguay.[1]Pseudis species are distributed throughout tropical and subtropical South America, almost entirely east of the Andes (P. paradoxa is the only species with population west of the Andes). They are commonly found in ponds associated with river floodplains, from Trinidad to northern Argentina, being absent only in Ecuador and Chile, highland regions, and the southernmost part of South America. Most species occur in Brazil, and P. fusca, P. tocantins, P. cardosoi, and P. bolbodactyla are endemic to this country.Contents1 Description2 Species3 Phylogenetic relationships4 References5 External linksDescription[edit]These frogs have several adaptations to aquatic life, such as protuberant eyes, robust hind limbs, and fully webbed feet.[2] Nevertheless, they belong to the "true" tree frogs, family Hylidae.[1]These frogs are commonly known because their giant tadpoles can reach up to 26\xa0cm (10\xa0in).[3] They are closely related to a second genus, Lysapsus, that lacks giant tadpoles and in which adults are smaller, up to 2.4\xa0cm (0.94\xa0in), compared to up to 7.5\xa0cm (3.0\xa0in) in Pseudis.[2] Lysapsus has been considered a synonym of Pseudis, but molecular evidence support their separateness.[1]Species[edit]There are seven species in this genus (given that Lysapsus is accepted as a separate genus):[1]Binomial name and authorCommon namePseudis bolbodactyla Lutz, 1925Pseudis cardosoi Kwet, 2000Pseudis fusca Garman, 1883Pseudis minuta Günther, 1858lesser swimming frogPseudis paradoxa (Linnaeus, 1758)paradoxical frogPseudis platensis Gallardo, 1961Pseudis tocantins Caramaschi & Cruz, 1998Phylogenetic relationships[edit]The phylogenetic position of frogs currently included in the genus Pseudis in relation to other anurans was for a long time a matter of debate. They have been placed in Ranidae, Leptodactylidae,[4] Hylidae,[5] and as their own family Pseudidae[6] This results from their highly derived body plan for a hylid frog due to their mostly aquatic habits. Recent morphological[7] and molecular[8] phylogenetic reconstructions have unambiguously placed them within the subfamily Hylinae with Scarthyla as a sister group.Phylogenetic relationships among species of the group were recently proposed using molecular evidences.[2][9][7] Both publications found identical trees, but proposed different taxonomic solutions for the nonmonophyly of Pseudis, either resurrecting the genus Podonectes[2] or placing Lysapsus as a junior synonym of Pseudis.[9] More recent molecular evidence did not find Pseudis paraphyletic with respect to Lysapsus, so the synonymy is unnecessary.[1]References[edit]^ a b c d e Frost, Darrel R. (2013). "Pseudis Wagler, 1830". Amphibian Species of the World 5.6, an Online Reference. American Museum of Natural History. Retrieved 11 December 2013.\xa0^ a b c d GARDA, A. A., and D. C. CANNATELLA. 2007. Phylogeny and biogeography of paradoxical frogs (Anura, Hylidae, Pseudae) inferred from 12S and 16S mitochondrial DNA. Molecular Phylogenetics and Evolution. Molecular Phylogenetics and Evolution. 44:104-114.^ Emerson, S. B. (1988). "The giant tadpole of Pseudis paradoxa". Biological Journal of the Linnean Society. 34 (2): 93–104. doi:10.1111/j.1095-8312.1988.tb01951.x.\xa0^ NOBLE, G. K. 1922. The phylogeny of Salientia. I. The osteology and thigh musculature; their bearing on clas ...
# <Hit {'filename': 'en.wikipedia.org/wiki/Scarthyla.html', 'class_': ['infobox', 'biota'], 'content': '  CentralNotice ScarthylaFrom Wikipedia, the free encyclopedia\t\t\t\t\tJump to:\t\t\t\t\tnavigation, \t\t\t\t\tsearchScarthylaScientific classification Kingdom:AnimaliaPhylum:ChordataClass:AmphibiaOrder:AnuraFamily:HylidaeSubfamily:HylinaeGenus:ScarthylaDuellman and de Sá, 1988Scarthyla is a genus of tree frogs, the family Hylidae, from South America. They are sometimes known under common name Madre de Dios treefrogs. It contains two species:[1]Scarthyla goinorum — Tarauaca snouted treefrogScarthyla vigilans — Maracaibo Basin treefrogReferences[edit]^ Frost, Darrel R. (2013). "Scarthyla Duellman and de Sá, 1988". Amphibian Species of the World 5.6, an Online Reference. American Museum of Natural History. Retrieved 2 May 2013.\xa0 \nNewPP limit report\nParsed by mw1248\nCached time: 20170311164958\nCache expiry: 2592000\nDynamic content: false\nCPU time usage: 0.312 seconds\nReal time usage: 0.364 seconds\nPreprocessor visited node count: 7820/1000000\nPreprocessor generated node count: 0/1500000\nPost‐expand include size: 15108/2097152 bytes\nTemplate argument size: 7220/2097152 bytes\nHighest expansion depth: 19/40\nExpensive parser function count: 1/500\nLua time usage: 0.251/10.000 seconds\nLua memory usage: 1.92 MB/50 MBTransclusion expansion time report (%,ms,calls,template)\n100.00%  353.975      1 -total\n 85.14%  301.385      1 Template:Automatic_taxobox\n 83.55%  295.757      1 Template:Taxobox/core\n 51.65%  182.829      1 Template:Taxobox/taxonomy\n 33.87%  119.900    115 Template:Taxon_info\n 12.66%   44.817      7 Template:Taxon_link\n 10.21%   36.138     24 Template:Delink\n  9.86%   34.888      1 Template:Reflist\n  9.09%   32.179     28 Template:Taxobox/displayed_cell\n  8.84%   31.276      1 Template:Cite_web Saved in parser cache with key enwiki:pcache:idhash:12375810-0!*!0!*!*!4!* and timestamp 20170311164958 and revision id 732568511\n  \t\t\t\t\t\tRetrieved from "https://en.wikipedia.org/w/index.php?title=Scarthyla&oldid=732568511"\t\t\t\t\tCategories: Tree frogsAmphibians of South AmericaAmphibian generaHidden categories: Articles with \'species\' microformats Navigation menuPersonal toolsNot logged inTalkContributionsCreate accountLog in NamespacesArticleTalkVariantsViewsReadEditView historyMoreSearch NavigationMain pageContentsFeatured contentCurrent eventsRandom articleDonate to WikipediaWikipedia store InteractionHelpAbout WikipediaCommunity portalRecent changesContact page ToolsWhat links hereRelated changesUpload fileSpecial pagesPermanent linkPage informationWikidata itemCite this page Print/exportCreate a bookDownload as PDFPrintable version In other projectsWikispecies LanguagesCebuanoEspañolEuskaraFrançaisMagyarNederlandsPolskiPortuguêsSvenskaTiếng ViệtWinaray Edit links  This page was last modified on 1 August 2016, at 20:28.Text is available under the Creative Commons Attribution-ShareAlike License;\nadditional terms may apply.  By using this site, you agree to the Terms of Use and Privacy Policy. Wikipedia® is a registered trademark of the Wikimedia Foundation, Inc., a non-profit organization.Privacy policyAbout WikipediaDisclaimersContact WikipediaDevelopersCookie statementMobile view  '}>
# <Hit {'filename': 'en.wikipedia.org/wiki/Lysapsus.html', 'class_': ['infobox', 'biota'], 'content': '  CentralNotice LysapsusFrom Wikipedia, the free encyclopedia\t\t\t\t\tJump to:\t\t\t\t\tnavigation, \t\t\t\t\tsearchLysapsusLysapsus limellumScientific classification Kingdom:AnimaliaPhylum:ChordataClass:AmphibiaOrder:AnuraFamily:HylidaeSubfamily:HylinaeGenus:LysapsusCope, 1862Type speciesLysapsus limellumCope, 1862Diversity4 species (see text)Lysapsus is a genus of frogs in the Hylidae family found in South America east of the Andes. Their common name is harlequin frogs.[1]Species[edit]There are four species:[1][2]Lysapsus bolivianus (Gallardo, 1961)Lysapsus caraya Gallardo, 1964Lysapsus laevis (Parker, 1935)Lysapsus limellum Cope, 1862The status of Lysapsus bolivianus is unclear; it might be a subspecies of Lysapsus limellum.[3]References[edit]^ a b Frost, Darrel R. (2015). "Lysapsus Cope, 1862". Amphibian Species of the World: an Online Reference. Version 6.0. American Museum of Natural History. Retrieved 13 June 2015.\xa0^ "Hylidae". AmphibiaWeb: Information on amphibian biology and conservation. [web application]. Berkeley, California: AmphibiaWeb. 2015. Retrieved 13 June 2015.\xa0^ Frost, Darrel R. (2015). "Lysapsus bolivianus (Gallardo, 1961)". Amphibian Species of the World: an Online Reference. Version 6.0. American Museum of Natural History. Retrieved 13 June 2015.\xa0Taxon identifiersGBIF:\xa02427643ITIS:\xa0208068This Hylinae article is a stub. You can help Wikipedia by expanding it.vte \nNewPP limit report\nParsed by mw1250\nCached time: 20170316021022\nCache expiry: 2592000\nDynamic content: false\nCPU time usage: 0.476 seconds\nReal time usage: 0.614 seconds\nPreprocessor visited node count: 9403/1000000\nPreprocessor generated node count: 0/1500000\nPost‐expand include size: 29404/2097152 bytes\nTemplate argument size: 8548/2097152 bytes\nHighest expansion depth: 19/40\nExpensive parser function count: 3/500\nLua time usage: 0.338/10.000 seconds\nLua memory usage: 4.21 MB/50 MBTransclusion expansion time report (%,ms,calls,template)\n100.00%  593.431      1 -total\n 62.00%  367.948      1 Template:Automatic_taxobox\n 60.64%  359.849      1 Template:Taxobox/core\n 35.43%  210.251      1 Template:Taxobox/taxonomy\n 27.97%  165.977      1 Template:Taxonbar\n 27.09%  160.762      1 Template:Navbox\n 25.66%  152.274      5 Template:1x\n 23.10%  137.071    115 Template:Taxon_info\n 22.06%  130.914     34 Template:Taxonbar/Link\n 18.96%  112.528     39 Template:If_empty Saved in parser cache with key enwiki:pcache:idhash:2969661-0!*!0!!*!4!* and timestamp 20170316021022 and revision id 754536472\n  \t\t\t\t\t\tRetrieved from "https://en.wikipedia.org/w/index.php?title=Lysapsus&oldid=754536472"\t\t\t\t\tCategories: HylinaeLysapsusAmphibians of South AmericaAmphibian generaTaxa named by Edward Drinker CopeHylinae stubsHidden categories: Articles using diversity taxoboxArticles with \'species\' microformatsAll stub articles Navigation menuPersonal toolsNot logged inTalkContributionsCreate accountLog in NamespacesArticleTalkVariantsViewsReadEditView historyMoreSearch NavigationMain pageContentsFeatured contentCurrent eventsRandom articleDonate to WikipediaWikipedia store InteractionHelpAbout WikipediaCommunity portalRecent changesContact page ToolsWhat links hereRelated changesUpload fileSpecial pagesPermanent linkPage informationWikidata itemCite this page Print/exportCreate a bookDownload as PDFPrintable version LanguagesCatalàEspañolFrançaisMagyarNederlandsPortuguês Edit links  This page was last modified on 13 December 2016, at 05:15.Text is available under the Creative Commons Attribution-ShareAlike License;\nadditional terms may apply.  By using this site, you agree to the Terms of Use and Privacy Policy. Wikipedia® is a registered trademark of the Wikimedia Foundation, Inc., a non-profit organization.Privacy policyAbout WikipediaDisclaimersContact WikipediaDevelopersCookie statementMobile view  '}>
# <Hit {'filename': 'en.wikipedia.org/wiki/Hylinae.html', 'class_': ['infobox', 'biota'], 'content': '  CentralNotice HylinaeFrom Wikipedia, the free encyclopedia\t\t\t\t\tJump to:\t\t\t\t\tnavigation, \t\t\t\t\tsearchHylinaeHyla arboreaScientific classification Kingdom:AnimaliaPhylum:ChordataClass:AmphibiaOrder:AnuraFamily:HylidaeSubfamily:HylinaeRafinesque, 1815Type genusHylariaRafinesque, 1814Genera41 genera.The Hylinae are the largest of three subfamilies of Hylidae, the "tree frogs".[1] It contains nearly 700 species in 41 genera. They are generally found in North and South America, Europe, temperate Asia, and Africa north of the Sahara.[2][3]Genera[edit]The 41 recognized genera are:[3]Acris – cricket frogsAnotheca – spiny-headed tree frogsAparasphenodon – casque-headed frogsAplastodiscus – canebreak tree frogsArgenteohyla – Argentinian frogsBokermannohylaBromeliohylaCharadrahylaCorythomantis – casque-headed tree frogDendropsophusDiaglenaDryadercesDuellmanohyla – brook frogsEcnomiohylaExerodontaHyla – common tree frogsHyloscirtusHypsiboas – gladiator frogsIsthmohylaItapotihylaLysapsusMegastomatohylaMyersiohylaNyctimantis – brown-eyed tree frogOsteocephalus – slender-legged tree frogsOsteopilusPhyllodytes – heart-tongued frogsPhytotriadesPlectrohyla – spike-thumb frogsPseudacris – chorus frogsPseudis – swimming frogsPtychohyla – stream frogsScarthyla – Madre de Dios tree frogsScinax – snouted tree frogsSmilisca – burrowing frogsSphaenorhynchus – lime tree frogsTepuihyla – Amazon tree frogsTlalocohylaTrachycephalus – casque-headed tree frogsTriprion – shovel-headed tree frogsXenohylaReferences[edit]^ Frost, Darrel R. (2014). "Hylidae Rafinesque, 1815". Amphibian Species of the World: an Online Reference. Version 6.0. American Museum of Natural History. Retrieved 20 January 2014.\xa0^ Britannica.com^ a b Frost, Darrel R. (2014). "Hylinae Rafinesque, 1815". Amphibian Species of the World: an Online Reference. Version 6.0. American Museum of Natural History. Retrieved 20 January 2014.\xa0External links[edit]Wikispecies has information related to: HylinaeWikimedia Commons has media related to Hylinae.http://www.tolweb.org/HylinaeThis Hylinae article is a stub. You can help Wikipedia by expanding it.vte \nNewPP limit report\nParsed by mw1243\nCached time: 20170312194046\nCache expiry: 2592000\nDynamic content: false\nCPU time usage: 0.324 seconds\nReal time usage: 0.411 seconds\nPreprocessor visited node count: 7933/1000000\nPreprocessor generated node count: 0/1500000\nPost‐expand include size: 31082/2097152 bytes\nTemplate argument size: 13325/2097152 bytes\nHighest expansion depth: 20/40\nExpensive parser function count: 1/500\nLua time usage: 0.228/10.000 seconds\nLua memory usage: 2.41 MB/50 MBTransclusion expansion time report (%,ms,calls,template)\n100.00%  381.761      1 -total\n 76.15%  290.711      1 Template:Automatic_taxobox\n 74.71%  285.229      1 Template:Taxobox/core\n 39.97%  152.576      1 Template:Taxobox/taxonomy\n 26.46%  101.002    109 Template:Taxon_info\n 10.11%   38.588      1 Template:Reflist\n  9.97%   38.045     23 Template:Delink\n  8.43%   32.186      2 Template:Cite_web\n  8.36%   31.924      6 Template:Taxon_link\n  7.40%   28.256     27 Template:Taxobox/displayed_cell Saved in parser cache with key enwiki:pcache:idhash:28798509-0!*!0!!*!4!* and timestamp 20170312194046 and revision id 732559460\n  \t\t\t\t\t\tRetrieved from "https://en.wikipedia.org/w/index.php?title=Hylinae&oldid=732559460"\t\t\t\t\tCategories: HylinaeVertebrate subfamiliesTaxa named by Constantine Samuel RafinesqueHylinae stubsHidden categories: Articles with \'species\' microformatsCommons category with local link same as on WikidataAll stub articles Navigation menuPersonal toolsNot logged inTalkContributionsCreate accountLog in NamespacesArticleTalkVariantsViewsReadEditView historyMoreSearch NavigationMain pageContentsFeatured contentCurrent eventsRandom articleDonate to WikipediaWikipedia store InteractionHelpAbout WikipediaCo ...
# <Hit {'filename': 'en.wikipedia.org/wiki/Sphaenorhynchus.html', 'class_': ['infobox', 'biota'], 'content': '  CentralNotice SphaenorhynchusFrom Wikipedia, the free encyclopedia\t\t\t\t\tJump to:\t\t\t\t\tnavigation, \t\t\t\t\tsearchSphaenorhynchusSphaenorhynchus lacteusScientific classificationKingdom:AnimaliaPhylum:ChordataClass:AmphibiaOrder:AnuraFamily:HylidaeSubfamily:HylinaeGenus:SphaenorhynchusTschudi, 1838SpeciesSee text.Sphaenorhynchus is a genus of frogs (lime treefrogs) in the Hylidae family found in the Amazon and Orinoco River basins of South America, the Guianas, Trinidad, and southern and eastern Brazil. Sphaenorhynchus caramaschiiSpecies[edit]Binomial name and authorCommon nameS. botocudo Caramaschi, Almeida & Gasparini, 2009S. bromelicola Bokermann, 1966Bahia lime tree frogS. canga Araujo-Vieira, Lacerda, Pezzuti, Leite, Assis & Cruz, 2015S. caramaschii Toledo, Garcia, Lingnau & Haddad, 2007S. carneus (Cope, 1868)Napo lime tree frogS. dorisae (Goin, 1957)Doris\' lime tree frogS. lacteus (Daudin, 1800)Orinoco lime tree frogS. orophilus (Lutz and Lutz, 1938)Lutz\'s lime tree frogS. mirim Caramaschi, Almeida & Gasparini, 2009S. palustris Bokermann, 1966Linhares lime tree frogS. pauloalvini Bokermann, 1973Paulo\'s lime tree frogS. planicola (Lutz and Lutz, 1938)Rio lime tree frogS. platycephalus (Werner, 1894)South American lime tree frogS. prasinus Bokermann, 1973Bokermann\'s lime tree frogS. surdus (Cochran, 1953)Cochran\'s lime tree frogReferences[edit]Frost, Darrel R. 2007. Amphibian Species of the World: an Online Reference. Version 5.1 (10 October 2007). Electronic Database accessible at http://research.amnh.org/herpetology/amphibia/index.php. American Museum of Natural History, New York, USA. Sphaenorhynchus access date: 2008-04-18eol - Encyclopedia of Life at [1] Taxon Sphaenorhynchus"Sphaenorhynchus". Integrated Taxonomic Information System. Retrieved 18 April 2008.\xa0GBIF - Global Biodiversity Information Facility at [2] Taxon SphaenorhynchusThis Hylinae article is a stub. You can help Wikipedia by expanding it.vte \nNewPP limit report\nParsed by mw1267\nCached time: 20170316043649\nCache expiry: 2592000\nDynamic content: false\nCPU time usage: 0.136 seconds\nReal time usage: 0.174 seconds\nPreprocessor visited node count: 3237/1000000\nPreprocessor generated node count: 0/1500000\nPost‐expand include size: 14265/2097152 bytes\nTemplate argument size: 2800/2097152 bytes\nHighest expansion depth: 24/40\nExpensive parser function count: 0/500\nLua time usage: 0.044/10.000 seconds\nLua memory usage: 2.09 MB/50 MBTransclusion expansion time report (%,ms,calls,template)\n100.00%  157.454      1 -total\n 58.45%   92.030      1 Template:Taxobox\n 51.67%   81.349      1 Template:Taxobox/core\n 35.46%   55.840     14 Template:Taxobox_colour\n 31.70%   49.920     14 Template:Delink\n 18.90%   29.765      1 Template:If_empty\n 17.61%   27.727      1 Template:ITIS\n 16.44%   25.892      1 Template:Cite_web\n 15.44%   24.310     11 Template:Sets_taxobox_colour\n 14.89%   23.438      1 Template:Italics_title Saved in parser cache with key enwiki:pcache:idhash:2961033-0!*!0!!*!4!* and timestamp 20170316043649 and revision id 732568704\n  \t\t\t\t\t\tRetrieved from "https://en.wikipedia.org/w/index.php?title=Sphaenorhynchus&oldid=732568704"\t\t\t\t\tCategories: HylinaeSphaenorhynchusAmphibian generaTaxa named by Johann Jakob von TschudiHylinae stubsHidden categories: Articles with \'species\' microformatsAll stub articles Navigation menuPersonal toolsNot logged inTalkContributionsCreate accountLog in NamespacesArticleTalkVariantsViewsReadEditView historyMoreSearch NavigationMain pageContentsFeatured contentCurrent eventsRandom articleDonate to WikipediaWikipedia store InteractionHelpAbout WikipediaCommunity portalRecent changesContact page ToolsWhat links hereRelated changesUpload fileSpecial pagesPermanent linkPage informationWikidata itemCite this page Print/exportCreate a bookDownload as PDFPrintable version In other ...
# <Hit {'filename': 'en.wikipedia.org/wiki/Ptychohyla.html', 'class_': ['infobox', 'biota'], 'content': '  CentralNotice PtychohylaFrom Wikipedia, the free encyclopedia\t\t\t\t\tJump to:\t\t\t\t\tnavigation, \t\t\t\t\tsearch"Mountain stream frog" redirects here. For the frog native to highland areas of New South Wales, Australia, see Mountain stream tree frog.PtychohylaPtychohyla salvadorensisScientific classification Kingdom:AnimaliaPhylum:ChordataClass:AmphibiaOrder:AnuraFamily:HylidaeSubfamily:HylinaeGenus:PtychohylaTaylor, 1944SpeciesSee text.Ptychohyla is a genus of frogs (common names: stream frogs, mountain stream frogs) in the Hylidae family.[1][2] These frogs are found in the southern Mexican states of Chiapas, Guerrero, and Oaxaca, and Central America to western Panama.[1]Species[edit]There are 13 species in this genus.[1]Binomial name and authorCommon nameP. acrochorda Campbell and Duellman, 2000Warty Mountain stream frogP. dendrophasma (Campbell, Smith, and Acevedo, 2000)phantom treefrogP. erythromma (Taylor, 1937)Guerreran stream frogP. euthysanota (Kellogg, 1928)cloud forest stream frogP. hypomykter McCranie and Wilson, 1993Copan stream frogP. legleri (Taylor, 1958)Legler\'s stream frogP. leonhardschultzei (Ahl, 1934)Schultze\'s stream frogP. macrotympanum (Tanner, 1957)pine forest stream frogP. panchoi Duellman and Campbell, 1982Guatemala stream frogP. salvadorensis (Mertens, 1952)Salvador stream frogP. sanctaecrucis Campbell and Smith, 1992[3]Chinamococh stream frogP. spinipollex (Schmidt, 1936)Ceiba stream frogP. zophodes Campbell and Duellman, 2000Gloomy Mountain stream frogReferences[edit]^ a b c Frost, Darrel R. (2014). "Ptychohyla Taylor, 1944". Amphibian Species of the World: an Online Reference. Version 6.0. American Museum of Natural History. Retrieved 18 April 2014.\xa0^ "Ptychohyla Taylor, 1944". Integrated Taxonomic Information System.\xa0^ Campbell, J.A., Smith, E.N. (1992): A new frog of the genus Ptychohyla (Hylidae) from the Sierra de Santa Cruz, Guatemala, and description of a new genus of Middle American stream-breeding treefrogs. - Herpetologica 48(2): 153-167Duellman, W. E. (1960): Synonymy, variation, and distribution of Ptychohyla leonhard-schultzei Ahl. Studies of American hylid frogs. IV - Herpetologica 16: 191–197External links[edit]AmphibiaWeb: Information on amphibian biology and conservation. [web application]. 2008. Berkeley, California: Ptychohyla. AmphibiaWeb, available at http://amphibiaweb.org/. (Accessed: April 23, 2008).Taxon identifiersEoL:\xa039788GBIF:\xa02428624ITIS:\xa0207422NCBI:\xa0317389This Hylinae article is a stub. You can help Wikipedia by expanding it.vte \nNewPP limit report\nParsed by mw1179\nCached time: 20170316034736\nCache expiry: 2592000\nDynamic content: false\nCPU time usage: 0.488 seconds\nReal time usage: 0.613 seconds\nPreprocessor visited node count: 9742/1000000\nPreprocessor generated node count: 0/1500000\nPost‐expand include size: 32396/2097152 bytes\nTemplate argument size: 9797/2097152 bytes\nHighest expansion depth: 19/40\nExpensive parser function count: 6/500\nLua time usage: 0.321/10.000 seconds\nLua memory usage: 4.43 MB/50 MBTransclusion expansion time report (%,ms,calls,template)\n100.00%  586.282      1 -total\n 55.53%  325.579      1 Template:Automatic_taxobox\n 54.46%  319.261      1 Template:Taxobox/core\n 30.67%  179.815      1 Template:Taxobox/taxonomy\n 27.76%  162.723      1 Template:Taxonbar\n 26.75%  156.847      1 Template:Navbox\n 25.28%  148.197      5 Template:1x\n 23.97%  140.553     34 Template:Taxonbar/Link\n 19.86%  116.410    115 Template:Taxon_info\n 16.56%   97.105     43 Template:If_empty Saved in parser cache with key enwiki:pcache:idhash:2969455-0!*!0!!*!4!* and timestamp 20170316034736 and revision id 754523344\n  \t\t\t\t\t\tRetrieved from "https://en.wikipedia.org/w/index.php?title=Ptychohyla&oldid=754523344"\t\t\t\t\tCategories: HylinaePtychohylaAmphibians of Central AmericaAmphibians of North AmericaAmphibian gen ...
# <Hit {'filename': 'en.wikipedia.org/wiki/Duellmanohyla.html', 'class_': ['infobox', 'biota'], 'content': '  CentralNotice DuellmanohylaFrom Wikipedia, the free encyclopedia\t\t\t\t\tJump to:\t\t\t\t\tnavigation, \t\t\t\t\tsearchDuellmanohylaDuellmanohyla uranochroaScientific classification Kingdom:AnimaliaPhylum:ChordataClass:AmphibiaOrder:AnuraFamily:HylidaeSubfamily:HylinaeGenus:DuellmanohylaCampbell & Smith , 1992Species8 species (see text)Duellmanohyla is a genus of frogs (mountain brook frogs) in the Hylidae family found in Oaxaca, Mexico, as well as Central America.[1] These are small stream-breeding frogs have bright red, bronze or yellow irises. Their dorsa are uniform pale green, olive, red-brown or lichenose, with green or olive spots on a black background. Several species have pale upper labial and lateral stripes. Some fingers or toes have moderate webbing.Contents1 Description2 Ecology3 Species4 ReferencesDescription[edit]Duellmanohyla are small or moderately small frogs. The dorsum is uniformly pale green, olive, reddish brown, or lichenose, and bears green or olive spots on a black background. The iris is bright red, orange, or yellow. The fingers and toes are moderately webbed.[2]Ecology[edit]Duellmanohyla breed in fast-flowing mountain streams. To adapt to this habitat, the frogs have a moderate degree of webbing on the forefeet and on some digits of the hind-feet. Egg-laying has not been observed in any species in the genus, and it is thought that the females may deposit their eggs on the foliage above the water of swift-flowing mountain streams, the tadpoles then falling into the stream when they hatch. The tadpoles have dangling oral discs by which they can attach themselves to the substrate.[2]Species[edit]The genus contains eight species:[1]Binomial name and authorCommon nameD. chamulae (Duellman, 1961)Chamula mountain brook frogD. ignicolor (Duellman, 1961)Sierra Juarez brook frogD. lythrodes (Savage, 1968)Savage\'s brook frogD. rufioculis (Taylor, 1952)Rufous-eyed brook frogD. salvavida (McCranie and Wilson, 1986)Honduran brook frogD. schmidtorum (Stuart, 1954)Schmidt\'s mountain brook frogD. soralia (Wilson and McCranie, 1985)Copan brook frogD. uranochroa (Cope, 1875)Costa Rica brook frogReferences[edit]^ a b Frost, Darrel R. (2015). "Duellmanohyla Campbell and Smith, 1992". Amphibian Species of the World: an Online Reference. Version 6.0. American Museum of Natural History. Retrieved 17 December 2015.\xa0^ a b Savage, Jay M. (2002). The Amphibians and Reptiles of Costa Rica: A Herpetofauna Between Two Continents, Between Two Seas. University of Chicago Press. p.\xa0297. ISBN\xa0978-0-226-73537-5.\xa0eol - Encyclopedia of Life at http://www.eol.org Taxon Duellmanohyla"Duellmanohyla". Integrated Taxonomic Information System. Retrieved 18 April 2008.\xa0GBIF - Global Biodiversity Information Facility at https://web.archive.org/web/20080501142231/http://data.gbif.org:80/welcome.htm Taxon Duellmanohyla \nNewPP limit report\nParsed by mw1252\nCached time: 20170316043007\nCache expiry: 2592000\nDynamic content: false\nCPU time usage: 0.312 seconds\nReal time usage: 0.387 seconds\nPreprocessor visited node count: 8088/1000000\nPreprocessor generated node count: 0/1500000\nPost‐expand include size: 23011/2097152 bytes\nTemplate argument size: 8317/2097152 bytes\nHighest expansion depth: 19/40\nExpensive parser function count: 1/500\nLua time usage: 0.236/10.000 seconds\nLua memory usage: 2.22 MB/50 MBTransclusion expansion time report (%,ms,calls,template)\n100.00%  370.061      1 -total\n 82.07%  303.701      1 Template:Automatic_taxobox\n 80.06%  296.276      1 Template:Taxobox/core\n 43.78%  162.030      1 Template:Taxobox/taxonomy\n 28.32%  104.800    115 Template:Taxon_info\n 10.24%   37.889      1 Template:Reflist\n  9.84%   36.420     24 Template:Delink\n  9.65%   35.711      7 Template:Taxon_link\n  7.94%   29.398      2 Template:Cite_web\n  7.88%   29.171     28 Template:Taxobox/displayed_cell Saved i ...

# %% [markdown]
# ### 6) Write example queries to ensure you can search the
#
# ```HTML
# <table class="infobox biota"
# ```

# %%
name=input()
# Out:
# "Nyctimantis rugiceps"

# %%
# Write your code below this comment:
# --------------------------------------


qp = QueryParser("content", schema=ix.schema)
q = qp.parse(name)
with ix.searcher() as s:
    results = s.search(q)
    for hit in results:
        print(hit)
# Out:
# <Hit {'filename': 'en.wikipedia.org/wiki/Nyctimantis.html', 'class_': ['infobox', 'biota'], 'content': '  CentralNotice Nyctimantis rugicepsFrom Wikipedia, the free encyclopedia\xa0\xa0(Redirected from Nyctimantis)\t\t\t\t\tJump to:\t\t\t\t\tnavigation, \t\t\t\t\tsearchNyctimantis rugicepsConservation statusLeast Concern\xa0(IUCN 3.1)[1]Scientific classification Kingdom:AnimaliaPhylum:ChordataClass:AmphibiaOrder:AnuraFamily:HylidaeSubfamily:HylinaeGenus:NyctimantisBoulenger, 1882Species:N.\xa0rugicepsBinomial nameNyctimantis rugicepsBoulenger, 1882Nyctimantis rugiceps (common name: brown-eyed treefrog) is a species of frog in the Hylidae family.[2] It is monotypic within the genus Nyctimantis.[3] It is known from the Amazonian Ecuador, Peru, and Colombia, and it is likely to occur also in adjacent Brazil.[2] Its natural habitats are primary and secondary lowland tropical rainforest.[1]Nyctimantis rugiceps breeds in bamboo and tree holes. Females raise the tadpoles on unfertilized eggs.[1]References[edit]^ a b c Coloma, L.A.; Ron, S.; Cisneros-Heredia, D.; Monteza, J.I.; Angulo, A. & Jungfer, K.-H. (2004). "Nyctimantis rugiceps". IUCN Red List of Threatened Species. Version 2013.2. International Union for Conservation of Nature. Retrieved 17 April 2014.\xa0^ a b Frost, Darrel R. (2014). "Nyctimantis rugiceps Boulenger, 1882". Amphibian Species of the World: an Online Reference. Version 6.0. American Museum of Natural History. Retrieved 17 April 2014.\xa0^ Frost, Darrel R. (2014). "Nyctimantis Boulenger, 1882". Amphibian Species of the World: an Online Reference. Version 6.0. American Museum of Natural History. Retrieved 17 April 2014.\xa0This Hylinae article is a stub. You can help Wikipedia by expanding it.vte \nNewPP limit report\nParsed by mw1238\nCached time: 20170218150218\nCache expiry: 2592000\nDynamic content: false\nCPU time usage: 0.392 seconds\nReal time usage: 0.466 seconds\nPreprocessor visited node count: 8666/1000000\nPreprocessor generated node count: 0/1500000\nPost‐expand include size: 32582/2097152 bytes\nTemplate argument size: 8443/2097152 bytes\nHighest expansion depth: 19/40\nExpensive parser function count: 0/500\nLua time usage: 0.290/10.000 seconds\nLua memory usage: 2.44 MB/50 MBTransclusion expansion time report (%,ms,calls,template)\n100.00%  447.330      1 -total\n 86.28%  385.975      1 Template:Speciesbox\n 84.71%  378.937      1 Template:Taxobox/core\n 46.36%  207.370      1 Template:Taxobox/taxonomy\n 28.89%  129.228    114 Template:Taxon_info\n 10.61%   47.475      1 Template:Reflist\n 10.26%   45.902     24 Template:Delink\n  9.14%   40.879      7 Template:Taxon_link\n  7.82%   34.967     28 Template:Taxobox/displayed_cell\n  7.75%   34.646      1 Template:IUCN2013.2 Saved in parser cache with key enwiki:pcache:idhash:12373761-0!*!0!*!*!4!* and timestamp 20170218150218 and revision id 748274925\n  \t\t\t\t\t\tRetrieved from "https://en.wikipedia.org/w/index.php?title=Nyctimantis_rugiceps&oldid=748274925"\t\t\t\t\tCategories: IUCN Red List least concern speciesHylinaeAnimals described in 1882Amphibians of ColombiaAmphibians of EcuadorAmphibians of PeruHylinae stubsHidden categories: Articles with \'species\' microformatsAll stub articles Navigation menuPersonal toolsNot logged inTalkContributionsCreate accountLog in NamespacesArticleTalkVariantsViewsReadEditView historyMoreSearch NavigationMain pageContentsFeatured contentCurrent eventsRandom articleDonate to WikipediaWikipedia store InteractionHelpAbout WikipediaCommunity portalRecent changesContact page ToolsWhat links hereRelated changesUpload fileSpecial pagesPermanent linkPage informationWikidata itemCite this page Print/exportCreate a bookDownload as PDFPrintable version In other projectsWikimedia CommonsWikispecies LanguagesCatalàCebuanoEspañolEuskaraFrançaisMagyarNederlandsPortuguêsSvenskaTiếng ViệtWinaray Edit links  This page was last modified on 7 November 2016, at 10:22.Text is available under the Creative Commons Attribution-Share ...

# %%
genus=input()
# Out:
# Osteocephalus

# %%
# Write your code below this comment:
# --------------------------------------
qp = QueryParser("content", schema=ix.schema)
q = qp.parse(genus)
with ix.searcher() as s:
    results = s.search(q)
    for hit in results:
        print(hit)
# Out:
# <Hit {'filename': 'en.wikipedia.org/wiki/Osteocephalus.html', 'class_': ['infobox', 'biota'], 'content': '  CentralNotice Slender-legged tree frogsFrom Wikipedia, the free encyclopedia\xa0\xa0(Redirected from Osteocephalus)\t\t\t\t\tJump to:\t\t\t\t\tnavigation, \t\t\t\t\tsearchSlender-legged tree frogsOsteocephalus taurinusScientific classificationKingdom:AnimaliaPhylum:ChordataClass:AmphibiaOrder:AnuraFamily:HylidaeGenus:OsteocephalusSteindachner, 1862SpeciesSee text.Osteocephalus is a genus of frogs (slender-legged tree frogs)in the Hylidae family found in the Guianas, the Amazon Basin, Venezuela, Colombia, southeastern Brazil, and northeastern Argentina. Males are warty, while females are smooth.Species[edit]Binomial name and authorCommon nameO. buckleyi (Boulenger, 1882)Buckley\'s slender-legged tree frogO. cabrerai (Cochran and Goin, 1970)O. carri (Cochran and Goin, 1970)O. deridens Jungfer, Ron, Seipp, and Almendáriz, 2000O. elkejungingerae (Henle, 1981)Henle\'s slender-legged tree frogO. exophthalmus Smith and Noonan, 2001O. fuscifacies Jungfer, Ron, Seipp, and Almendáriz, 2000O. heyeri Lynch, 2002O. langsdorfiiOcellated tree frogO. leoniae Jungfer and Lehr, 2001O. leprieurii (Duméril and Bibron, 1841)Cayenne slender-legged tree frogO. mutabor Jungfer and Hödl, 2002O. oophagus Jungfer and Schiesari, 1995O. pearsoni (Gaige, 1929)Pearson\'s slender-legged tree frogO. phasmatus MacCulloch and Lathrop, 2005O. planiceps Cope, 1874O. subtilis Martins and Cardoso, 1987Brazilian slender-legged tree frogO. taurinus Steindachner, 1862Manaus slender-legged tree frogO. verruciger (Werner, 1901)Ecuador slender-legged tree frogO. yasuni Ron and Pramuk, 1999References[edit]Jungfer, K.-H., Schiesari, L.C. (1995a): Description of a central Amazonian and Guianan tree frog, genus Osteocephalus (Anura, Hylidae), with oophagous tadpoles. - Alytes, Paris 13(1), pp. [1-13]Jungfer, K.-H., Ron, S., Seipp, R., Almendáriz, A. (2000): Two new species of hylid frogs, genus Osteocephalus, from Amazonian Ecuador. - Amphibia-Reptilia 21(3), pp. [327-340]Jungfer, K.-H., Hödl, W. (2002): A new species of Osteocephalus from Ecuador and a redescription of O. leprieurii (Duméril & Bibron, 1841) (Anura: Hylidae). - Amphibia-Reptilia 23(1), pp. [21-46]Jungfer, K.-H., J. Faivovich, J.M. Padial, S. Castroviejo-Fisher, M. Lyra, B. Von Muller Berneck, P. Iglesias, P.J.R. Kok, R.D. MacCulloch, M.T. Rodrigues, V.K. Verdade, C.P. Torres Gastello, J.C. Chaparro, P.H. Valdujo, S. Reichle, J. Moravec, V. Gvoždík, G. Gagliardi-Urrutia, R. Ernst, I. De la Riva, D.B. Means, A.P. Lima, J.C. Señaris, W.C. Wheeler and C.F.B. Haddad. (2013). Systematics of spiny-backed treefrogs (Hylidae: Osteocephalus) an Amazonian puzzle. Zoologica Scripta 42: 351–380.External links[edit]Frost, Darrel R. 2007. Amphibian Species of the World: an Online Reference. Version 5.1 (10 October 2007). Osteocephalus. Electronic Database accessible at http://research.amnh.org/herpetology/amphibia/index.php. American Museum of Natural History, New York, USA. (Accessed: Apr 24, 2008).AmphibiaWeb: Information on amphibian biology and conservation. [web application]. 2008. Berkeley, California: Osteocephalus. AmphibiaWeb, available at http://amphibiaweb.org/. (Accessed: Apr 24, 2008).eol - Encyclopedia of Life taxon Osteocephalus at http://www.eol.org.ITIS - Integrated Taxonomic Information System on-line database Taxon Osteocephalus at http://www.itis.gov/index.html. (Accessed: Apr 24, 2008).GBIF - Global Biodiversity Information Facility Taxon Osteocephalus at http://data.gbif.org/welcome.htmThis Hylinae article is a stub. You can help Wikipedia by expanding it.vte \nNewPP limit report\nParsed by mw1268\nCached time: 20170311203004\nCache expiry: 2592000\nDynamic content: false\nCPU time usage: 0.116 seconds\nReal time usage: 0.138 seconds\nPreprocessor visited node count: 3073/1000000\nPreprocessor generated node count: 0/1500000\nPost‐expand include size: 11240/2097152 bytes\nTemplate argument size: ...
# <Hit {'filename': 'en.wikipedia.org/wiki/Tepuihyla.html', 'class_': ['infobox', 'biota'], 'content': '  CentralNotice TepuihylaFrom Wikipedia, the free encyclopedia\t\t\t\t\tJump to:\t\t\t\t\tnavigation, \t\t\t\t\tsearchTepuihylaScientific classification Kingdom:AnimaliaPhylum:ChordataClass:AmphibiaOrder:AnuraFamily:HylidaeSubfamily:HylinaeGenus:TepuihylaAyarzagüena, Señaris & Gorzula, 1993[1]Diversity7 species (see text)Tepuihyla (common names: Amazon tree frogs, Tepui tree frogs) is a genus of frogs in the Hylidae family found in mountains of eastern and southeastern Venezuela and Guyana, and likely in adjacent Brazil.[2] A tepui is a table-top mountain characteristic of the Guiana Highlands.Species[edit]There are seven species in this genus:[2]Binomial name and authorCommon nameT. aecii Ayarzagüena, Señaris, and Gorzula, 1993Monte Duida tree frogT. edelcae (Ayarzagüena, Señaris, and Gorzula, 1993)Ayarzaguena\'s tree frogT. exophthalma (Smith and Noonan, 2001)T. luteolabris Ayarzagüena, Señaris, and Gorzula, 1993T. rimarum Ayarzagüena, Señaris, and Gorzula, 1993Gorzula\'s Amazon tree frogT. rodriguezi (Rivero, 1968)Rodriguez\'s Amazon tree frogT. warreni (Duellman and Hoogmoed, 1992)References[edit]^ Ayarzagüena, J., J.C. Señaris y S. Gorzula (1992) Un nuevo genero para las especies del "grupo Osteocephalus rodriguezi" (Anura: ylidae). Memorias de la Sociedad de Ciencias Naturales La Salle. 52(138): 213-221^ a b Frost, Darrel R. (2014). "Tepuihyla Ayarzagüena, Señaris, and Gorzula, 1993". Amphibian Species of the World: an Online Reference. Version 6.0. American Museum of Natural History. Retrieved 27 June 2014.\xa0External links[edit]AmphibiaWeb: Information on amphibian biology and conservation. [web application]. 2008. Berkeley, California: Tepuihyla. AmphibiaWeb, available at http://amphibiaweb.org/. (Accessed: Apr 25, 2008).eol - Encyclopedia of Life taxon Tepuihyla at http://www.eol.org.ITIS - Integrated Taxonomic Information System on-line database Taxon Tepuihyla at http://www.itis.gov/index.html. (Accessed: Apr 25, 2008).GBIF - Global Biodiversity Information Facility Taxon Tepuihyla at http://data.gbif.org/welcome.htmThis Hylinae article is a stub. You can help Wikipedia by expanding it.vte \nNewPP limit report\nParsed by mw1265\nCached time: 20170311201034\nCache expiry: 2592000\nDynamic content: false\nCPU time usage: 0.344 seconds\nReal time usage: 0.404 seconds\nPreprocessor visited node count: 7995/1000000\nPreprocessor generated node count: 0/1500000\nPost‐expand include size: 20639/2097152 bytes\nTemplate argument size: 8520/2097152 bytes\nHighest expansion depth: 19/40\nExpensive parser function count: 1/500\nLua time usage: 0.263/10.000 seconds\nLua memory usage: 1.89 MB/50 MBTransclusion expansion time report (%,ms,calls,template)\n100.00%  383.898      1 -total\n 87.07%  334.266      1 Template:Automatic_taxobox\n 85.43%  327.967      1 Template:Taxobox/core\n 47.14%  180.978      1 Template:Taxobox/taxonomy\n 30.66%  117.721    115 Template:Taxon_info\n 11.38%   43.694     24 Template:Delink\n 10.12%   38.860      7 Template:Taxon_link\n  9.14%   35.070      1 Template:Reflist\n  8.52%   32.691     28 Template:Taxobox/displayed_cell\n  7.57%   29.080      1 Template:Cite_web Saved in parser cache with key enwiki:pcache:idhash:2961103-0!*!0!!*!4!* and timestamp 20170311201034 and revision id 732568769\n  \t\t\t\t\t\tRetrieved from "https://en.wikipedia.org/w/index.php?title=Tepuihyla&oldid=732568769"\t\t\t\t\tCategories: Hylinae stubsHylinaeTepuihylaAmphibians of South AmericaAmphibian generaTaxa named by Josefa Celsa SeñarisHidden categories: Articles using diversity taxoboxArticles with \'species\' microformatsAll stub articles Navigation menuPersonal toolsNot logged inTalkContributionsCreate accountLog in NamespacesArticleTalkVariantsViewsReadEditView historyMoreSearch NavigationMain pageContentsFeatured contentCurrent eventsRandom articleDonate to WikipediaWikipedia store InteractionHelpAbout Wikiped ...

# %% [markdown]
# # SAVE YOUR NOTEBOOK WITH ALL EXECUTED CELLS
