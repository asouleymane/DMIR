# %% [markdown]
# # This exercise is to use whoosh to build a search engine
# # over your own DSA Notebooks
#
# Have you ever had the thought:
# "I know we did this before! Where did I see that in the course materials?"
#
# This exercise is to build a technical solution to aid in answering that question.
#
# **NOTE:** This is a little more like a practice, but it is the exercise for the week.
#
# ## Here are the steps
# ### I) Build (conceptual):
#   1. Crawl through your home directory and find all notebooks (`.ipynb`)
#   2. Extract the visible text from the notebooks
#   3. Use Whoosh to Index
#
# ### II) Query:
#   1. Open the index
#   1. Query

# %% [markdown]
# ---
# ## Preliminaries
# ### Parsing Visible Text from a notebook

# %%
import sys
import json

# Test on my self, like all evil scientists
filename = './DSA_Notebook_Search_Engine.ipynb'

# Use the JSON library to get it in a DOM-like structure
# This is similar to using BeautifulSoup on HTML/KML/XML
file_data = json.load(open(filename))

# File data is now a map, recall a JSON format is a combo of dictionaries and lists
cells = file_data.get('cells')

print("Dumping {} Non-output Cells from {}".format(len(cells), filename))

# Count the Cells
cno = 1

# for each cell in the notebook
for c in cells:
    
    #extract and test the cell type
    cell_type = c['cell_type']
    if ('code'==cell_type or 'markdown'==cell_type or 'raw'==cell_type ):
        print("# -------------{}----------------".format(cno))
        
        # run the source into lines, it is actually a list of strings/lines
        source = c['source']
        for l in source:
            print(l.strip('\n'))
        cno += 1
# Out:
# Dumping 30 Non-output Cells from ./DSA_Notebook_Search_Engine.ipynb
# # -------------1----------------
# # This exercise is to use whoosh to build a search engine
# # over your own DSA Notebooks
#
# Have you ever had the thought:
# "I know we did this before! Where did I see that in the course materials?"
#
# This exercise is to build a technical solution to aid in answering that question.
#
# **NOTE:** This is a little more like a practice, but it is the exercise for the week.
#
# ## Here are the steps
# ### I) Build (conceptual):
#   1. Crawl through your home directory and find all notebooks (`.ipynb`)
#   2. Extract the visible text from the notebooks
#   3. Use Whoosh to Index
#
# ### II) Query:
#   1. Open the index
#   1. Query
# # -------------2----------------
# ---
# ## Preliminaries
# ### Parsing Visible Text from a notebook
# # -------------3----------------
# import sys
# import json
#
# # Test on my self, like all evil scientists
# filename = './DSA_Notebook_Search_Engine.ipynb'
#
# # Use the JSON library to get it in a DOM-like structure
# # This is similar to using BeautifulSoup on HTML/KML/XML
# file_data = json.load(open(filename))
#
# # File data is now a map, recall a JSON format is a combo of dictionaries and lists
# cells = file_data.get('cells')
#
# print("Dumping {} Non-output Cells from {}".format(len(cells), filename))
#
# # Count the Cells
# cno = 1
#
# # for each cell in the notebook
# for c in cells:
#
#     #extract and test the cell type
#     cell_type = c['cell_type']
#     if ('code'==cell_type or 'markdown'==cell_type or 'raw'==cell_type ):
#         print("# -------------{}----------------".format(cno))
#
#         # run the source into lines, it is actually a list of strings/lines
#         source = c['source']
#         for l in source:
#             print(l.strip('\n'))
#         cno += 1
# # -------------4----------------
# If you have followed the pattern of the way Dr. Scott builds up code...
#
# ## a) Time to create function!
#
# ### Your function should return a set of cells, each cell having all
# ### lines concatentated into one long `string` of data.
#
# The comment lines, `# TODO ... `, will define steps for you to complete.
# # -------------5----------------
# def visibleTextFromNB(filename):
#     '''
#     # TODO Describe this function's purpose and return result
#
#     This function pulls all the non-output visible cells from
#     a JupyterNotebook and concatenates it all into a block of
#     text.
#
#     Returns : a list of the cells
#     '''
#     #####################################
#     # TODO: Parse file, pull cells
#     #####################################
#
#
#
#
#
#
#     #####################################
#     # TODO: Append cells into a list of cells
#     # HINT: Do not strip the newline, \n
#     #####################################
#
#     cell_list = []
#
#     if cells == None:
#         return cell_list
#
#
#
#
#
#
#
#
#
#     #####################################
#     # TODO: Append cells into a list of cells
#     # HINT: Do not strip the newline, \n
#     #####################################
#
#     # return the list
#     return cell_list
#
# #End of function: visibleTextFromNB
# # -------------6----------------
# ## Test your function:
# # -------------7----------------
# #################################
# #        NO EDIT CELL
# #################################
#
# # Use the lab notebook
# filename = '../labs/Text_Search_TFIDF.ipynb'
# cells = visibleTextFromNB(filename)
#
# # Print the begin and end
# print(cells[0])
# print(cells[1])
# print('...')
# print(cells[len(cells)-1])
# # -------------8----------------
# #### <span style="background:yellow">Expected Output</span>
#
# ```
# # Building and Loading Text Search in Python Whoosh using TFIDF
#
#
# ## OUTLINE
#
#  1. [Task at hand](#task)
#  1. [Buiding our Whoosh Schema](#build_it)
#  1. [Loading Data](#load_it)
#  1. [Scoring](#Scoring)
#  1. [Executing Queries, Google-lite...very very lite](#TFIFD)
# ---
# <a id='task' ></a>
#
# ## Task at hand
#
# For this lab, we are going to revist the IR_with_Python_Whoosh lab in module 5 which walks us through the process of creating full text search capability within Python. In addition to that we are going to incorporate a scoring technique called TFIDF for ranking documents based on TFIDF scores of the terms occuring in the documents.
#
# We will walk through the process to build the search engine in Python using whoosh. We will compare the serach results with and without TFIDF method.
# ...
# The line_num above is the actual line number in the text file. docnum should be the index number in the whole indexes we have created.
# ```
# # -------------9----------------
# # b) Create a _draft_ function to walk through directory and find notebooks (.ipynb)
#
# Collect up the directory walking code from module 5 examples.
#
# #### Note, the starting folder will be `'~'`, the alias for your home directory
#
# #### Note, do not process files yet, just construct the function and print the notebook path names
# # -------------10----------------
# import os, os.path
#
# def walkFolder(folder):
#     '''
#     Process a folder for files and subfolders
#     Prints the files and folders that are processed.
#     '''
#     #print('Processing folder: ',folder)
#
#     #####################################
#     # TODO: walk through the filesystem starting at folder
#     # HINT: os.walk
#     #####################################
#
#
#
#
#         #####################################
#         # TODO: Process Files
#         # HINT: skips file.endswith("-checkpoint.ipynb")
#         #####################################
#
#
#
#
#
#
#         #####################################
#         # TODO: Recurse into subfolders
#         # HINT: Skip these
#         #           .config
#         #           .cache
#         #           .ssh
#         #           ... etc.
#         #####################################
#
#
#
#
#
#
# ############# END for walkFolder
# # -------------11----------------
# ## Test your function:
# # -------------12----------------
# #################################
# #        NO EDIT CELL
# #################################
#
# # Use your top-level home directory
# initial_root = os.path.expanduser('~')
# walkFolder(initial_root)
# # -------------13----------------
# #### <span style="background:yellow">Expected Output</span>
#
#    * Expected output similar to
#
# ```
# Found Notebook: /dsa/home/scottgs/Testing Python.ipynb
# Found Notebook: /dsa/home/scottgs/Testing R.ipynb
# ...
# Found Notebook: /dsa/home/scottgs/sp17DMIR/modules/module5/practices/Text_Preprocessing.ipynb
# Found Notebook: /dsa/home/scottgs/sp17DMIR/modules/module5/exercises/Exercises_Python_text_search.ipynb
# Found Notebook: /dsa/home/scottgs/sp17DMIR/modules/module5/answers/Text_Preprocessing_Answers.ipynb
# ```
# # -------------14----------------
# # c) Create the schema for whoosh and initialize
# # the index in `notebooks` folder
#
# Recall, in the work above you pulled each visible cell from the notebook into a list of cells.
#
# So, we can store the data such as our results are:
#   * Filename
#   * Cell No.
#
# Then, we will also index the cell content.
# # -------------15----------------
# from whoosh.fields import Schema, TEXT, KEYWORD, ID, STORED
# from whoosh.analysis import StemmingAnalyzer
# from whoosh import index
#
#
# #####################################
# # TODO: Create the schema
# #####################################
#
#
#
#
#
# #####################################
# # TODO: Create the index and initialize a `writer`
# #####################################
#
#
#
#
# # -------------16----------------
# #################################
# #        NO EDIT CELL
# #################################
#
# #  REPEATED for better review
#
# def visibleTextFromNB(filename):
#     '''
#     # TODO Describe this function's purpose and return result
#     This function pulls all the non-output visible cells from
#     a JupyterNotebook and concatenates it all into a block of
#     text.
#     Returns : a list of the cells
#     '''
#     #####################################
#     # TODO: Parse file, pull cells
#     #####################################
#
#     file_data = json.load(open(filename))
#
#     # File data is now a map, recall a JSON format is a combo of dictionaries and lists
#     cells = file_data.get('cells')
#
#     #####################################
#     # TODO: Append cells into a list of cells
#     # HINT: Do not strip the newline, \n
#     #####################################
#
#     cell_list = []
#     if cells == None:
#         return cell_list
#
#     # for each cell in the notebook
#     for c in cells:
#
#         #extract and test the cell type
#         cell_type = c['cell_type']
#         if ('code'==cell_type or 'markdown'==cell_type or 'raw'==cell_type ):
#             cell_text = ""
#             # run the source into lines, it is actually a list of strings/lines
#             source = c['source']
#             for l in source:
#                 cell_text += l
#             cell_list.append(cell_text)
#
#
#     #####################################
#     # TODO: Append cells into a list of cells
#     # HINT: Do not strip the newline, \n
#     #####################################
#
#     # return the list
#     return cell_list
#
# #End of function: visibleTextFromNB
# # -------------17----------------
# ## d) Write function to load file into the index
#   * See [Module 5 Lab](../../module5/labs/IR_with_Python_Whoosh.ipynb#This-should-look-familiar!)
# # -------------18----------------
# def loadFile(writer, fname):
#     '''
#     Read file contents, load into database.
#     '''
#     #####################################
#     # TODO: Get cell text from function
#     #####################################
#
#
#
#
#     #####################################
#     # TODO: Iterate through cells, index
#     #####################################
#     counter = 1;
#
#
#
#
#     print("Indexed: ", fname)
#
# # END of function
# # -------------19----------------
# # e) Adapt the folder walking function to invoke file load
#
# ### HINT: add the `writer` as a parameter
# # -------------20----------------
# import os, os.path
#
# #####################################
# # TODO: Adapt the parameters
# #####################################
# def walkFolder(writer, folder):
#     '''
#     Process a folder for files and subfolders
#     Prints the files and folders that are processed.
#     '''
#     #print('Processing folder: ',folder)
#
#     #####################################
#     # TODO: walk through the filesystem starting at folder
#     # HINT: os.walk
#     #####################################
#
#
#
#
#
#
#         #####################################
#         # TODO: Process Files
#         # HINT: skips file.endswith("-checkpoint.ipynb")
#         #####################################
#
#
#
#
#
#
#
#         #####################################
#         # TODO: Recurse into subfolders
#         # HINT: Skip these
#         #           .config
#         #           .cache
#         #           .ssh
#         #           ... etc.
#         #####################################
#
#
#
#
#
#
#
# ############# END for walkFolder
# # -------------21----------------
# # f) Run the index build
# # -------------22----------------
# #################################
# #        NO EDIT CELL
# #################################
#
# # Use your top-level home directory
# initial_root = os.path.expanduser('~')
# walkFolder(writer,initial_root)
#
#
# # Commit changes
# writer.commit() # save changes
# # -------------23----------------
# # DO NOT RUN UNLESS YOU NEED A RESET
# from whoosh import writing
# writer.commit(mergetype=writing.CLEAR)
# # -------------24----------------
# # g) Execute three queries
#
# ## 1
# # -------------25----------------
# from whoosh.qparser import QueryParser
# from whoosh import scoring
#
# # Get input, conver to unicode
# qstr = input("Input a qeury: ")
#
# print("searching for ",qstr)
#
# ####################################
# # TODO: Build query parser and parse query
# ####################################
#
#
#
#
# ####################################
# # TODO: Search the content field
# ####################################
#
#
#
#
# # -------------26----------------
# #### <span style="background:yellow">Expected Output</span>
#
#   *  Example output from searching for QueryParser
#
# ```
# Input a qeury: QueryParser
# searching for  QueryParser
# content:queryparser
# Cell 11 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module5/labs/IR_with_Python_Whoosh.ipynb'
# Cell 27 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module5/answers/ParsingWikipediaLifeformPage.ipynb'
# Cell 25 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb'
# Cell 9 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module6/labs/Text_Search_TFIDF.ipynb'
# Cell 14 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module6/labs/Text_Search_TFIDF.ipynb'
# Cell 17 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module6/labs/Text_Search_TFIDF.ipynb'
# Cell 45 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module6/labs/Topic_modelling.ipynb'
# Cell 7 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module6/answers/TFIDF_Scoring_Practice.ipynb'
# Cell 8 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module6/answers/TFIDF_Scoring_Practice.ipynb'
# Cell 11 of Notebook '/dsa/home/scottgs/sp17DMIR/modules/module5/labs/IR_with_Python_Whoosh.ipynb'
# ```
#
# ---
# ## 2
# # -------------27----------------
# # Get input, conver to unicode
# qstr = input("Input a qeury: ")
#
# print("searching for ",qstr)
#
# ####################################
# # TODO: Build query parser and parse query
# ####################################
#
#
#
#
# ####################################
# # TODO: Search the content field
# ####################################
#
#
#
# # -------------28----------------
# ## 3
# # -------------29----------------
# # Get input, conver to unicode
# qstr = input("Input a qeury: ")
#
# print("searching for ",qstr)
#
# ####################################
# # TODO: Build query parser and parse query
# ####################################
#
#
#
#
# ####################################
# # TODO: Search the content field
# ####################################
#
#
#
#
# # -------------30----------------
# # SAVE YOUR NOTEBOOK

# %% [markdown]
# If you have followed the pattern of the way Dr. Scott builds up code...
#
# ## a) Time to create function!
#
# ### Your function should return a set of cells, each cell having all
# ### lines concatentated into one long `string` of data.
#
# The comment lines, `# TODO ... `, will define steps for you to complete.

# %%
def visibleTextFromNB(filename):
    '''
    # TODO Describe this function's purpose and return result
    
    This function pulls all the non-output visible cells from
    a JupyterNotebook and concatenates it all into a block of
    text.
    
    Returns : a list of the cells
    '''
    #####################################
    # TODO: Parse file, pull cells
    #####################################
    file_data = json.load(open(filename))

    cells = file_data.get('cells')
   
   
    #####################################
    # TODO: Append cells into a list of cells
    # HINT: Do not strip the newline, \n
    #####################################

    cell_list = []
    
    if cells == None:
        return cell_list
    
    for c in cells:
        cell_type = c['cell_type']
        if ('code'==cell_type or 'markdown'==cell_type or 'raw'==cell_type ):
            cell_text = ""
            source = c['source']
            for l in source:
                cell_text += l
            cell_list.append(cell_text)     
        
   
    #####################################
    # TODO: Append cells into a list of cells
    # HINT: Do not strip the newline, \n
    #####################################

    # return the list
    return cell_list


#End of function: visibleTextFromNB

# %% [markdown]
# ## Test your function:

# %%
#################################
#        NO EDIT CELL
#################################

# Use the lab notebook
filename = '../labs/Text_Search_TFIDF.ipynb'
cells = visibleTextFromNB(filename)

# Print the begin and end
print(cells[0])
print(cells[1])
print('...')
print(cells[len(cells)-1])
# Out:
# # Building and Loading Text Search in Python Whoosh using TFIDF
#
#
# ## OUTLINE
#
#  1. [Task at hand](#task)
#  1. [Buiding our Whoosh Schema](#build_it)
#  1. [Loading Data](#load_it)
#  1. [Scoring](#Scoring)
#  1. [Executing Queries, Google-lite...very very lite](#TFIFD)
# ---
# <a id='task' ></a>
#
# ## Task at hand
#
# For this lab, we are going to revist the IR_with_Python_Whoosh lab in module 5 which walks us through the process of creating full text search capability within Python. In addition to that we are going to incorporate a scoring technique called TFIDF for ranking documents based on TFIDF scores of the terms occuring in the documents.
#
# We will walk through the process to build the search engine in Python using whoosh. We will compare the serach results with and without TFIDF method.
# ...
# The line_num above is the actual line number in the text file. docnum should be the index number in the whole indexes we have created.

# %% [markdown]
# #### <span style="background:yellow">Expected Output</span>
#
# ```
# # Building and Loading Text Search in Python Whoosh using TFIDF
#
#
# ## OUTLINE
#
#  1. [Task at hand](#task)
#  1. [Buiding our Whoosh Schema](#build_it)
#  1. [Loading Data](#load_it)
#  1. [Scoring](#Scoring)
#  1. [Executing Queries, Google-lite...very very lite](#TFIFD)
# ---
# <a id='task' ></a>
#
# ## Task at hand
#
# For this lab, we are going to revist the IR_with_Python_Whoosh lab in module 5 which walks us through the process of creating full text search capability within Python. In addition to that we are going to incorporate a scoring technique called TFIDF for ranking documents based on TFIDF scores of the terms occuring in the documents.
#
# We will walk through the process to build the search engine in Python using whoosh. We will compare the serach results with and without TFIDF method.
# ...
# The line_num above is the actual line number in the text file. docnum should be the index number in the whole indexes we have created.
# ```

# %% [markdown]
# # b) Create a _draft_ function to walk through directory and find notebooks (.ipynb)
#
# Collect up the directory walking code from module 5 examples.
#
# #### Note, the starting folder will be `'~'`, the alias for your home directory
#
# #### Note, do not process files yet, just construct the function and print the notebook path names

# %%
import os, os.path

def walkFolder(folder):
    '''
    Process a folder for files and subfolders
    Prints the files and folders that are processed. 
    '''
    #print('Processing folder: ',folder)
    
    #####################################
    # TODO: walk through the filesystem starting at folder
    # HINT: os.walk
    #####################################
    for root,dirs,files in os.walk(folder):
        print("root=",root)
    
    
        
        #####################################
        # TODO: Process Files
        # HINT: skips file.endswith("-checkpoint.ipynb")
        #####################################
    
        for file in files:
            filename = os.path.join(root, file)
            if file.endswith("-checkpoint.ipynb"):
                pass
            elif file.endswith(".ipynb"):
                print('Found Notebook:',filename)
            else:
                print("unhandled file")
   
                
                
            
        #####################################
        # TODO: Recurse into subfolders
        # HINT: Skip these
        #           .config
        #           .cache
        #           .ssh
        #           ... etc.         
        #####################################
            
            
        for d in dirs:
            if d.startswith("."):
                 pass
            else:
                 walkFolder(d)
 
    
    
    

############# END for walkFolder

# %% [markdown]
# ## Test your function:

# %%
#################################
#        NO EDIT CELL
#################################

# Use your top-level home directory
initial_root = os.path.expanduser('~') 
walkFolder(initial_root)
# Out:
# root= /dsa/home/souleymanesaleya
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/.config
# root= /dsa/home/souleymanesaleya/.config/matplotlib
# root= /dsa/home/souleymanesaleya/.config/htop
# unhandled file
# root= /dsa/home/souleymanesaleya/.ipython
# root= /dsa/home/souleymanesaleya/.ipython/extensions
# root= /dsa/home/souleymanesaleya/.ipython/nbextensions
# root= /dsa/home/souleymanesaleya/.ipython/profile_default
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/.ipython/profile_default/db
# root= /dsa/home/souleymanesaleya/.ipython/profile_default/log
# root= /dsa/home/souleymanesaleya/.ipython/profile_default/pid
# root= /dsa/home/souleymanesaleya/.ipython/profile_default/security
# root= /dsa/home/souleymanesaleya/.ipython/profile_default/startup
# unhandled file
# root= /dsa/home/souleymanesaleya/.local
# root= /dsa/home/souleymanesaleya/.local/share
# root= /dsa/home/souleymanesaleya/.local/share/jupyter
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/.local/share/jupyter/runtime
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/.ssh
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya
# Found Notebook: /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/Course-Schedule.ipynb
# root= notebooks
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/branches
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/hooks
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/info
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/logs
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/logs/refs
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/logs/refs/heads
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/logs/refs/remotes
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/logs/refs/remotes/origin
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/objects
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/objects/11
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/objects/1a
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/objects/34
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/objects/54
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/objects/62
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/objects/7b
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/objects/b7
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/objects/df
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/objects/f6
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/objects/info
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/objects/pack
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/refs
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/refs/heads
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/refs/remotes
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/refs/remotes/origin
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/refs/tags
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/datasets
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks
# Found Notebook: /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/L2-LoadData.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/L3-LoadPackages.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/L5-DataLoadingPandas.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/L6-ControlStructures.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/L7-BeautifulSoup.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/L7-JSON_Parsing.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/L8-UnivariateDataVisualization.ipynb
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/ThinkPython2
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/files
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/python_lectures
# Found Notebook: /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/python_lectures/00.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/python_lectures/01.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/python_lectures/02.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/python_lectures/03.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/python_lectures/04.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/python_lectures/05.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/python_lectures/06.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/python_lectures/07.ipynb
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/python_lectures/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/resources
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya
# unhandled file
# Found Notebook: /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/Course-Schedule.ipynb
# root= notebooks
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/branches
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/hooks
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/info
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/logs
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/logs/refs
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/logs/refs/heads
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/logs/refs/remotes
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/logs/refs/remotes/origin
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/04
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/15
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/16
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/1a
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/1d
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/1f
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/2d
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/34
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/46
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/53
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/55
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/69
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/6f
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/71
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/87
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/90
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/96
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/b4
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/b7
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/ba
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/bc
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/c6
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/cf
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/eb
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/f1
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/f6
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/f9
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/info
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/pack
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/refs
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/refs/heads
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/refs/remotes
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/refs/remotes/origin
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/refs/tags
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/datasets
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks
# Found Notebook: /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/M1-L2-ExploringSQLite.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/M1-L3-ExploringPostgresSQL.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/M2-L2-PostgreSQLAccess.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/M2-L2-SQLite_LoadAccessUpdate.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/M2-L3-PythonPostgreSQL.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/M2-L3-PythonSQLite.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/M3-L1-Joins.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/M3-L2-Aggregations.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/M3-L3-AdvancedAggregations.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/M3-L4-WindowFunctions.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/M3-L5-SubsetStatWindowFunctions.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/M4-Final-GetAnswers.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/M4-L1-DatabaseDesign.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/M4-L4-DatabaseLoading.ipynb
# unhandled file
# Found Notebook: /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/Untitled.ipynb
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/branches
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/hooks
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/info
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/logs
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/logs/refs
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/logs/refs/heads
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/logs/refs/remotes
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/logs/refs/remotes/origin
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/00
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/02
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/03
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/04
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/06
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/0a
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/0e
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/0f
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/11
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/18
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/1f
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/24
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/26
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/28
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/29
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/31
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/33
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/3a
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/3c
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/3d
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/3e
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/41
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/49
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/4b
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/4e
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/50
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/54
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/55
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/59
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/5b
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/5f
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/60
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/62
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/65
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/6a
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/6c
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/7b
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/7d
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/7f
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/81
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/87
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/88
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/8c
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/8d
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/90
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/96
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/97
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/9a
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/9b
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/9c
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/9f
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/a2
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/a4
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/a6
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/a8
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/aa
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/ac
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/ad
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/b1
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/b2
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/b3
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/b4
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/ba
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/be
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/bf
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/c5
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/c6
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/cb
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/d4
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/d7
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/dd
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/de
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/e5
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/e6
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/ec
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/f4
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/f6
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/f7
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/fa
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/fb
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/info
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/pack
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/db
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/a3
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/23
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/40
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/78
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/63
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/52
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/5d
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/9e
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/35
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/27
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/39
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/e1
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/82
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/51
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/6e
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/2d
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/ca
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/5e
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/08
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/66
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/2e
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/c2
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/9d
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/05
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/6b
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/85
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/94
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/1a
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/6f
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/8f
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/b0
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/a1
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/d6
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/af
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/b5
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/1d
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/f9
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/d1
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/5c
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/5a
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/38
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/75
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/95
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/70
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/83
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/e0
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/dc
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/30
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/ae
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/44
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/19
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/4f
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/10
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/ea
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/cd
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/32
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/12
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/a7
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/d8
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/2b
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/c1
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/09
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/8a
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/b6
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/16
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/ef
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/8e
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/15
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/d0
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/48
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/d2
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/f3
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/93
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/e8
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/bc
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/77
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/f1
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/e7
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/47
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/45
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/80
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/a5
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/da
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/3b
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/42
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/cf
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/14
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/8b
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/7e
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/ce
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/20
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/57
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/4a
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/e4
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/64
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/ab
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/61
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/cc
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/99
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/1b
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/f0
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/refs
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/refs/heads
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/refs/remotes
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/refs/remotes/origin
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/refs/tags
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/datasets
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/datasets/baby-names
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/datasets/baseball-databank
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/datasets/baseball-databank/data
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/datasets/game-of-thrones
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/datasets/stature-hand-foot
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/datasets/wine-quality
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1/module1.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1/exercises
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1/exercises/intro_data_science_exercise_python.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1/exercises/intro_data_science_exercise_r.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1/exercises/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1/images
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1/labs
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1/labs/intro_data_science_python.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1/labs/intro_data_science_r.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1/labs/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1/practices
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1/practices/data_science_practice_r.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1/practices/data_science_practice_python.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1/practices/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2/module2.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2/exercises
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2/exercises/exercises_descriptive_stats_r.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2/exercises/exercises_descriptive_stats_python.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2/exercises/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2/images
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2/labs
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2/labs/intro_descriptive_stats_python.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2/labs/intro_descriptive_stats_r.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2/labs/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2/practices
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2/practices/practice_descriptive_stats_python.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2/practices/practice_descriptive_stats_r.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2/practices/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3
# unhandled file
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/module3.ipynb
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/exercises
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/exercises/data_query.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/exercises/data_carpentry_exercises.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/exercises/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/images
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/labs
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/labs/data_carpentry.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/labs/database_loading.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/labs/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/practices
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/practices/SQL_auxillary.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/practices/data_carpentry_practice.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/practices/database_querying_practice_python.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/practices/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/readings
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/resources
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/resources/sql_tutorial
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/resources/sql_tutorial/sql.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/resources/sql_tutorial/sql_INSERT_UPDATE_DELETE.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/resources/sql_tutorial/sql_SELECT.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/resources/sql_tutorial/sql_relations.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/resources/sqlite
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/resources/sqlite/sqlite.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/resources/sqlite/sqlite_loading_exporting.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/resources/sqlite/sqlite_python_data_oh_my.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module5
# unhandled file
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module5/module5.ipynb
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module5/exercises
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module5/exercises/plotting_exercises_r.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module5/exercises/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module5/images
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module5/labs
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module5/labs/ggplot2_theming.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module5/labs/ggplot2_intro_r.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module5/labs/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module5/practices
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module5/practices/ggplot2_plotting_practice.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module5/practices/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module5/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6/module6.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6/images
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6/labs
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6/labs/intro_decision_tree_r.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6/labs/intro_naive_bayes_python.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6/labs/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6/exercises
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6/exercises/ml_exercises_python.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6/exercises/ml_exercises_r.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6/exercises/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6/practices
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6/practices/practice_ml_python.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6/practices/practice_ml_r.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6/practices/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module7
# unhandled file
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module7/module7.ipynb
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module7/exercises
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module7/exercises/linear_regression_exercise_python.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module7/exercises/linear_regression_exercise_r.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module7/exercises/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module7/labs
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module7/labs/linear_regression_r.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module7/labs/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module7/practices
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module7/practices/regression_practice_python.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module7/practices/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module7/readings
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8
# unhandled file
# unhandled file
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/Storytelling.ipynb
# unhandled file
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/NFL_Story.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/exercises
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/exercises/info_graphics_story_exercise.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/exercises/visual_story_exercise.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/exercises/Storytelling .ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/exercises/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/labs
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/labs/info_graphics_story.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/labs/story_development_example.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/labs/visual_story.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/labs/Untitled.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/labs/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/practices
# ...
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/corpora/words
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/corpora/ycoe
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/corpora/mte_teip5
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/corpora/mte_teip5/schema
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/corpora/panlex_lite
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/corpora/nonbreaking_prefixes
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/models
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/models/moses_sample
# root= /dsa/home/souleymanesaleya/nltk_data/models/moses_sample/lm
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/models/moses_sample/phrase-model
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/models/moses_sample/string-to-tree
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/models/moses_sample/string-to-tree/rules
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/models/moses_sample/tree-to-tree
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/models/bllip_wsj_no_aux
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/models/bllip_wsj_no_aux/parser
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/models/bllip_wsj_no_aux/parser/PStatInfo
# root= /dsa/home/souleymanesaleya/nltk_data/models/bllip_wsj_no_aux/reranker
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/models/word2vec_sample
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/models/wmt15_eval
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/stemmers
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/stemmers/rslp
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/stemmers/porter_test
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/taggers
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/taggers/hmm_treebank_pos_tagger
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/taggers/maxent_treebank_pos_tagger
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/taggers/maxent_treebank_pos_tagger/PY3
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/taggers/universal_tagset
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/taggers/averaged_perceptron_tagger
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/chunkers
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/chunkers/maxent_ne_chunker
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/chunkers/maxent_ne_chunker/PY3
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/tokenizers
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/tokenizers/punkt
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/tokenizers/punkt/PY3
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/grammars
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/grammars/book_grammars
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/grammars/sample_grammars
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/grammars/spanish_grammars
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/grammars/basque_grammars
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/grammars/large_grammars
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/help
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/help/tagsets
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/help/tagsets/PY3
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/misc
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/misc/perluniprops
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/misc/mwa_ppdb
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/sentiment
# unhandled file
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1
# Found Notebook: /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/Twitter_project.ipynb
# unhandled file
# unhandled file
# Found Notebook: /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/Data_Carpentry.R.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/Twitter_project_day2.ipynb
# unhandled file
# Found Notebook: /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/Untitled.ipynb
# unhandled file
# Found Notebook: /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/Day2.ipynb
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/branches
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/hooks
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/info
# unhandled file
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/refs
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/refs/heads
# unhandled file
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/refs/tags
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/objects
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/objects/pack
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/objects/info
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/objects/96
# unhandled file
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/objects/dd
# unhandled file
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/objects/2c
# unhandled file
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/objects/70
# unhandled file
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/objects/7e
# unhandled file
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/logs
# unhandled file
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/logs/refs
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/logs/refs/heads
# unhandled file
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/Untitled Folder
# Found Notebook: /dsa/home/souleymanesaleya/Untitled Folder/Untitled.ipynb
# root= /dsa/home/souleymanesaleya/Untitled Folder/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/Student_Exec_Week
# unhandled file
# unhandled file
# Found Notebook: /dsa/home/souleymanesaleya/Student_Exec_Week/Untitled.ipynb
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/branches
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/hooks
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/info
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/refs
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/refs/heads
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/refs/tags
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/refs/remotes
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/refs/remotes/origin
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/pack
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/info
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/e4
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/42
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/6b
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/ca
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/c1
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/ee
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/c9
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/72
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/8a
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/00
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/51
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/e3
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/22
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/04
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/ce
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/b7
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/logs
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/logs/refs
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/logs/refs/remotes
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/logs/refs/remotes/origin
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/logs/refs/heads
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day1
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day2
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day2/Team1
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day2/Team2
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day2/Team3
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day2/Team4
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day2/Team5
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day2/Team6
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day3
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day3/Team1
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day3/Team2
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day3/Team3
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day3/Team4
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day3/Team5
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day3/Team6
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day4
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day4/Team1
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day4/Team2
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day4/Team3
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day4/Team4
# unhandled file
# Found Notebook: /dsa/home/souleymanesaleya/Student_Exec_Week/Day4/Team4/Untitled.ipynb
# Found Notebook: /dsa/home/souleymanesaleya/Student_Exec_Week/Day4/Team4/team3_heath.ipynb
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day4/Team4/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day4/Team5
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day4/Team6
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day4/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.ipynb_checkpoints

# %% [markdown]
# #### <span style="background:yellow">Expected Output</span>
#
#    * Expected output similar to
#
# ```
# Found Notebook: /dsa/home/scottgs/Testing Python.ipynb
# Found Notebook: /dsa/home/scottgs/Testing R.ipynb
# ...
# Found Notebook: /dsa/home/scottgs/sp17DMIR/modules/module5/practices/Text_Preprocessing.ipynb
# Found Notebook: /dsa/home/scottgs/sp17DMIR/modules/module5/exercises/Exercises_Python_text_search.ipynb
# Found Notebook: /dsa/home/scottgs/sp17DMIR/modules/module5/answers/Text_Preprocessing_Answers.ipynb
# ```

# %% [markdown]
# # c) Create the schema for whoosh and initialize
# # the index in `notebooks` folder
#
# Recall, in the work above you pulled each visible cell from the notebook into a list of cells.
#
# So, we can store the data such as our results are:
#   * Filename
#   * Cell No.
#
# Then, we will also index the cell content.

# %%
from whoosh.fields import Schema, TEXT, KEYWORD, ID, STORED
from whoosh.analysis import StemmingAnalyzer
from whoosh import index


#####################################
# TODO: Create the schema
#####################################
schema = Schema(filename=ID(stored=True),
                line_num=ID(stored=True),
                content=TEXT(analyzer=StemmingAnalyzer())
               )




#####################################
# TODO: Create the index and initialize a `writer`
#####################################
import os, os.path
from whoosh import index

# Note, this clears the existing index in the directory
ix = index.create_in("notebooks", schema)

# Get a writer form the created index in 
writer = ix.writer()

# %%
import json

def is_json(myjson):
    try:
        json_object = json.loads(myjson)
    except ValueError:
        return False
    return True

# %%
#################################
#        NO EDIT CELL
#################################

#  REPEATED for better review

def visibleTextFromNB(filename):
    '''
    # TODO Describe this function's purpose and return result
    This function pulls all the non-output visible cells from
    a JupyterNotebook and concatenates it all into a block of
    text.
    Returns : a list of the cells
    '''
    #####################################
    # TODO: Parse file, pull cells
    #####################################

    #file_data = json.load(open(filename))

    # File data is now a map, recall a JSON format is a combo of dictionaries and lists
    #cells = file_data.get('cells')
    
    cell_list = []

    if is_json(filename):
        file_data = json.loads(open(filename))
    else: 
        return cell_list
    # File data is now a map,recall a Json format is a combo of dictionaries and lists
   
    cells = file_data.get('cells')

    #####################################
    # TODO: Append cells into a list of cells
    # HINT: Do not strip the newline, \n
    #####################################

#     cell_list = []
    if cells == None:
        return cell_list
    
    # for each cell in the notebook
    for c in cells:

        #extract and test the cell type
        cell_type = c['cell_type']
        if ('code'==cell_type or 'markdown'==cell_type or 'raw'==cell_type ):
            cell_text = ""
            # run the source into lines, it is actually a list of strings/lines
            source = c['source']
            for l in source:
                cell_text += l
            cell_list.append(cell_text)

            
    #####################################
    # TODO: Append cells into a list of cells
    # HINT: Do not strip the newline, \n
    #####################################

    # return the list
    return cell_list

#End of function: visibleTextFromNB

# %% [markdown]
# ## d) Write function to load file into the index
#   * See [Module 5 Lab](../../module5/labs/IR_with_Python_Whoosh.ipynb#This-should-look-familiar!)

# %%
def loadFile(writer, fname):
    '''
    Read file contents, load into database.
    '''
    #####################################
    # TODO: Get cell text from function
    #####################################
    cells=visibleTextFromNB(fname)

    
    #####################################
    # TODO: Iterate through cells, index
    #####################################
    counter = 1;
    
    for c in cells:
        writer.add_document(filename=fname,line_num=str(counter),content=c)
        counter+= 1
    
    
    
    print("Indexed: ", fname)

# END of function

# %% [markdown]
# # e) Adapt the folder walking function to invoke file load
#
# ### HINT: add the `writer` as a parameter

# %%
import os, os.path

#####################################
# TODO: Adapt the parameters
#####################################
def walkFolder(writer, folder):
    '''
    Process a folder for files and subfolders
    Prints the files and folders that are processed.
    '''
        
    #print('Processing folder: ',folder)
    
    #####################################
    # TODO: walk through the filesystem starting at folder
    # HINT: os.walk
    #####################################
    for root,dirs,files in os.walk(folder):
        print("root=",root)
    

    
    
    
    
        #####################################
        # TODO: Process Files
        # HINT: skips file.endswith("-checkpoint.ipynb")
        #####################################
        for file in files:
            filename = os.path.join(root, file)
            if file.endswith("-checkpoint.ipynb"):
                pass
#             elif file.endswith("DSA-8620_souleymanesaleya/modules/module4/labs/regression.ipynb"):
#                 pass
            elif file.endswith(".ipynb"): 
                loadFile(writer,filename)
            else:
                print("unhandled file")
        






        #####################################
        # TODO: Recurse into subfolders
        # HINT: Skip these
        #           .config
        #           .cache
        #           .ssh
        #           ... etc.         
        #####################################
    for d in dirs:
        if (d.startswith(".")):
            pass
        else:
            walkFolder(writer,d)
        
        
        
        
        

############# END for walkFolder

# %% [markdown]
# # f) Run the index build

# %%
#################################
#        NO EDIT CELL
#################################

# Use your top-level home directory
initial_root = os.path.expanduser('~') 
walkFolder(writer,initial_root)


# Commit changes
writer.commit() # save changes
# Out:
# root= /dsa/home/souleymanesaleya
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/.config
# root= /dsa/home/souleymanesaleya/.config/matplotlib
# root= /dsa/home/souleymanesaleya/.config/htop
# unhandled file
# root= /dsa/home/souleymanesaleya/.ipython
# root= /dsa/home/souleymanesaleya/.ipython/extensions
# root= /dsa/home/souleymanesaleya/.ipython/nbextensions
# root= /dsa/home/souleymanesaleya/.ipython/profile_default
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/.ipython/profile_default/db
# root= /dsa/home/souleymanesaleya/.ipython/profile_default/log
# root= /dsa/home/souleymanesaleya/.ipython/profile_default/pid
# root= /dsa/home/souleymanesaleya/.ipython/profile_default/security
# root= /dsa/home/souleymanesaleya/.ipython/profile_default/startup
# unhandled file
# root= /dsa/home/souleymanesaleya/.local
# root= /dsa/home/souleymanesaleya/.local/share
# root= /dsa/home/souleymanesaleya/.local/share/jupyter
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/.local/share/jupyter/runtime
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/.ssh
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya
# Indexed:  /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/Course-Schedule.ipynb
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/branches
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/hooks
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/info
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/logs
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/logs/refs
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/logs/refs/heads
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/logs/refs/remotes
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/logs/refs/remotes/origin
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/objects
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/objects/11
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/objects/1a
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/objects/34
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/objects/54
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/objects/62
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/objects/7b
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/objects/b7
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/objects/df
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/objects/f6
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/objects/info
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/objects/pack
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/refs
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/refs/heads
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/refs/remotes
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/refs/remotes/origin
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.git/refs/tags
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/datasets
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks
# Indexed:  /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/L2-LoadData.ipynb
# Indexed:  /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/L3-LoadPackages.ipynb
# Indexed:  /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/L5-DataLoadingPandas.ipynb
# Indexed:  /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/L6-ControlStructures.ipynb
# Indexed:  /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/L7-BeautifulSoup.ipynb
# Indexed:  /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/L7-JSON_Parsing.ipynb
# Indexed:  /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/L8-UnivariateDataVisualization.ipynb
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/ThinkPython2
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/files
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/python_lectures
# Indexed:  /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/python_lectures/00.ipynb
# Indexed:  /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/python_lectures/01.ipynb
# Indexed:  /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/python_lectures/02.ipynb
# Indexed:  /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/python_lectures/03.ipynb
# Indexed:  /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/python_lectures/04.ipynb
# Indexed:  /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/python_lectures/05.ipynb
# Indexed:  /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/python_lectures/06.ipynb
# Indexed:  /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/python_lectures/07.ipynb
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/notebooks/python_lectures/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/resources
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-Python_souleymanesaleya/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya
# unhandled file
# Indexed:  /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/Course-Schedule.ipynb
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/branches
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/hooks
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/info
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/logs
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/logs/refs
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/logs/refs/heads
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/logs/refs/remotes
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/logs/refs/remotes/origin
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/04
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/15
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/16
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/1a
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/1d
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/1f
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/2d
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/34
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/46
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/53
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/55
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/69
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/6f
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/71
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/87
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/90
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/96
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/b4
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/b7
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/ba
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/bc
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/c6
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/cf
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/eb
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/f1
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/f6
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/f9
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/info
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/objects/pack
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/refs
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/refs/heads
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/refs/remotes
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/refs/remotes/origin
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/.git/refs/tags
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/datasets
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks
# Indexed:  /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/M1-L2-ExploringSQLite.ipynb
# Indexed:  /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/M1-L3-ExploringPostgresSQL.ipynb
# Indexed:  /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/M2-L2-PostgreSQLAccess.ipynb
# Indexed:  /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/M2-L2-SQLite_LoadAccessUpdate.ipynb
# Indexed:  /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/M2-L3-PythonPostgreSQL.ipynb
# Indexed:  /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/M2-L3-PythonSQLite.ipynb
# Indexed:  /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/M3-L1-Joins.ipynb
# Indexed:  /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/M3-L2-Aggregations.ipynb
# Indexed:  /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/M3-L3-AdvancedAggregations.ipynb
# Indexed:  /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/M3-L4-WindowFunctions.ipynb
# Indexed:  /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/M3-L5-SubsetStatWindowFunctions.ipynb
# Indexed:  /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/M4-Final-GetAnswers.ipynb
# Indexed:  /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/M4-L1-DatabaseDesign.ipynb
# Indexed:  /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/M4-L4-DatabaseLoading.ipynb
# unhandled file
# Indexed:  /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/Untitled.ipynb
# root= /dsa/home/souleymanesaleya/BC-SQL_souleymanesaleya/notebooks/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/branches
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/hooks
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/info
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/logs
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/logs/refs
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/logs/refs/heads
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/logs/refs/remotes
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/logs/refs/remotes/origin
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/00
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/02
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/03
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/04
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/06
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/0a
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/0e
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/0f
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/11
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/18
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/1f
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/24
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/26
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/28
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/29
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/31
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/33
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/3a
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/3c
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/3d
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/3e
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/41
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/49
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/4b
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/4e
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/50
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/54
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/55
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/59
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/5b
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/5f
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/60
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/62
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/65
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/6a
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/6c
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/7b
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/7d
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/7f
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/81
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/87
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/88
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/8c
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/8d
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/90
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/96
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/97
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/9a
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/9b
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/9c
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/9f
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/a2
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/a4
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/a6
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/a8
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/aa
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/ac
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/ad
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/b1
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/b2
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/b3
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/b4
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/ba
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/be
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/bf
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/c5
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/c6
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/cb
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/d4
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/d7
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/dd
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/de
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/e5
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/e6
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/ec
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/f4
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/f6
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/f7
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/fa
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/fb
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/info
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/pack
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/db
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/a3
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/23
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/40
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/78
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/63
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/52
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/5d
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/9e
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/35
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/27
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/39
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/e1
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/82
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/51
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/6e
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/2d
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/ca
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/5e
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/08
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/66
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/2e
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/c2
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/9d
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/05
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/6b
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/85
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/94
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/1a
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/6f
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/8f
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/b0
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/a1
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/d6
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/af
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/b5
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/1d
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/f9
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/d1
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/5c
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/5a
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/38
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/75
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/95
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/70
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/83
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/e0
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/dc
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/30
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/ae
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/44
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/19
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/4f
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/10
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/ea
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/cd
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/32
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/12
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/a7
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/d8
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/2b
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/c1
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/09
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/8a
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/b6
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/16
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/ef
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/8e
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/15
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/d0
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/48
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/d2
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/f3
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/93
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/e8
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/bc
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/77
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/f1
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/e7
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/47
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/45
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/80
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/a5
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/da
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/3b
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/42
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/cf
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/14
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/8b
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/7e
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/ce
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/20
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/57
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/4a
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/e4
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/64
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/ab
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/61
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/cc
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/99
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/1b
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/objects/f0
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/refs
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/refs/heads
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/refs/remotes
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/refs/remotes/origin
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/.git/refs/tags
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/datasets
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/datasets/baby-names
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/datasets/baseball-databank
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/datasets/baseball-databank/data
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/datasets/game-of-thrones
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/datasets/stature-hand-foot
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/datasets/wine-quality
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1/module1.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1/exercises
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1/exercises/intro_data_science_exercise_python.ipynb
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1/exercises/intro_data_science_exercise_r.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1/exercises/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1/images
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1/labs
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1/labs/intro_data_science_python.ipynb
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1/labs/intro_data_science_r.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1/labs/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1/practices
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1/practices/data_science_practice_r.ipynb
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1/practices/data_science_practice_python.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module1/practices/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2/module2.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2/exercises
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2/exercises/exercises_descriptive_stats_r.ipynb
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2/exercises/exercises_descriptive_stats_python.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2/exercises/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2/images
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2/labs
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2/labs/intro_descriptive_stats_python.ipynb
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2/labs/intro_descriptive_stats_r.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2/labs/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2/practices
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2/practices/practice_descriptive_stats_python.ipynb
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2/practices/practice_descriptive_stats_r.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module2/practices/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3
# unhandled file
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/module3.ipynb
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/exercises
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/exercises/data_query.ipynb
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/exercises/data_carpentry_exercises.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/exercises/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/images
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/labs
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/labs/data_carpentry.ipynb
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/labs/database_loading.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/labs/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/practices
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/practices/SQL_auxillary.ipynb
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/practices/data_carpentry_practice.ipynb
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/practices/database_querying_practice_python.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/practices/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/readings
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/resources
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/resources/sql_tutorial
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/resources/sql_tutorial/sql.ipynb
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/resources/sql_tutorial/sql_INSERT_UPDATE_DELETE.ipynb
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/resources/sql_tutorial/sql_SELECT.ipynb
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/resources/sql_tutorial/sql_relations.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/resources/sqlite
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/resources/sqlite/sqlite.ipynb
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/resources/sqlite/sqlite_loading_exporting.ipynb
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module3/resources/sqlite/sqlite_python_data_oh_my.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module5
# unhandled file
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module5/module5.ipynb
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module5/exercises
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module5/exercises/plotting_exercises_r.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module5/exercises/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module5/images
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module5/labs
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module5/labs/ggplot2_theming.ipynb
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module5/labs/ggplot2_intro_r.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module5/labs/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module5/practices
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module5/practices/ggplot2_plotting_practice.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module5/practices/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module5/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6/module6.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6/images
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6/labs
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6/labs/intro_decision_tree_r.ipynb
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6/labs/intro_naive_bayes_python.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6/labs/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6/exercises
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6/exercises/ml_exercises_python.ipynb
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6/exercises/ml_exercises_r.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6/exercises/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6/practices
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6/practices/practice_ml_python.ipynb
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6/practices/practice_ml_r.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module6/practices/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module7
# unhandled file
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module7/module7.ipynb
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module7/exercises
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module7/exercises/linear_regression_exercise_python.ipynb
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module7/exercises/linear_regression_exercise_r.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module7/exercises/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module7/labs
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module7/labs/linear_regression_r.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module7/labs/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module7/practices
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module7/practices/regression_practice_python.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module7/practices/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module7/readings
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8
# unhandled file
# unhandled file
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/Storytelling.ipynb
# unhandled file
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/NFL_Story.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/exercises
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/exercises/info_graphics_story_exercise.ipynb
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/exercises/visual_story_exercise.ipynb
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/exercises/Storytelling .ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/exercises/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/labs
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/labs/info_graphics_story.ipynb
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/labs/story_development_example.ipynb
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/labs/visual_story.ipynb
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/labs/Untitled.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/labs/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/practices
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/practices/info_graphics_story_example.ipynb
# Indexed:  /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/practices/visual_story_example.ipynb
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/practices/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/readings
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/DSA-7600_souleymanesaleya/modules/module8/resources
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# ...
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/corpora/words
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/corpora/ycoe
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/corpora/mte_teip5
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/corpora/mte_teip5/schema
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/corpora/panlex_lite
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/corpora/nonbreaking_prefixes
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/models
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/models/moses_sample
# root= /dsa/home/souleymanesaleya/nltk_data/models/moses_sample/lm
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/models/moses_sample/phrase-model
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/models/moses_sample/string-to-tree
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/models/moses_sample/string-to-tree/rules
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/models/moses_sample/tree-to-tree
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/models/bllip_wsj_no_aux
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/models/bllip_wsj_no_aux/parser
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/models/bllip_wsj_no_aux/parser/PStatInfo
# root= /dsa/home/souleymanesaleya/nltk_data/models/bllip_wsj_no_aux/reranker
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/models/word2vec_sample
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/models/wmt15_eval
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/stemmers
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/stemmers/rslp
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/stemmers/porter_test
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/taggers
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/taggers/hmm_treebank_pos_tagger
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/taggers/maxent_treebank_pos_tagger
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/taggers/maxent_treebank_pos_tagger/PY3
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/taggers/universal_tagset
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/taggers/averaged_perceptron_tagger
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/chunkers
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/chunkers/maxent_ne_chunker
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/chunkers/maxent_ne_chunker/PY3
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/tokenizers
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/tokenizers/punkt
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/tokenizers/punkt/PY3
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/grammars
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/grammars/book_grammars
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/grammars/sample_grammars
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/grammars/spanish_grammars
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/grammars/basque_grammars
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/grammars/large_grammars
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/help
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/help/tagsets
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/help/tagsets/PY3
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/misc
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/misc/perluniprops
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/misc/mwa_ppdb
# unhandled file
# root= /dsa/home/souleymanesaleya/nltk_data/sentiment
# unhandled file
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1
# Indexed:  /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/Twitter_project.ipynb
# unhandled file
# unhandled file
# Indexed:  /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/Data_Carpentry.R.ipynb
# Indexed:  /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/Twitter_project_day2.ipynb
# unhandled file
# Indexed:  /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/Untitled.ipynb
# unhandled file
# Indexed:  /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/Day2.ipynb
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/branches
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/hooks
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/info
# unhandled file
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/refs
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/refs/heads
# unhandled file
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/refs/tags
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/objects
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/objects/pack
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/objects/info
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/objects/96
# unhandled file
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/objects/dd
# unhandled file
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/objects/2c
# unhandled file
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/objects/70
# unhandled file
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/objects/7e
# unhandled file
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/logs
# unhandled file
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/logs/refs
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.git/logs/refs/heads
# unhandled file
# root= /dsa/home/souleymanesaleya/Data_Carpentry_Lab_1/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/Untitled Folder
# Indexed:  /dsa/home/souleymanesaleya/Untitled Folder/Untitled.ipynb
# root= /dsa/home/souleymanesaleya/Untitled Folder/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/Student_Exec_Week
# unhandled file
# unhandled file
# Indexed:  /dsa/home/souleymanesaleya/Student_Exec_Week/Untitled.ipynb
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/branches
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/hooks
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/info
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/refs
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/refs/heads
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/refs/tags
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/refs/remotes
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/refs/remotes/origin
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/pack
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/info
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/e4
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/42
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/6b
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/ca
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/c1
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/ee
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/c9
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/72
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/8a
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/00
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/51
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/e3
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/22
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/04
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/ce
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/objects/b7
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/logs
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/logs/refs
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/logs/refs/remotes
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/logs/refs/remotes/origin
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.git/logs/refs/heads
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day1
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day2
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day2/Team1
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day2/Team2
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day2/Team3
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day2/Team4
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day2/Team5
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day2/Team6
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day3
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day3/Team1
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day3/Team2
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day3/Team3
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day3/Team4
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day3/Team5
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day3/Team6
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day4
# unhandled file
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day4/Team1
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day4/Team2
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day4/Team3
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day4/Team4
# unhandled file
# Indexed:  /dsa/home/souleymanesaleya/Student_Exec_Week/Day4/Team4/Untitled.ipynb
# Indexed:  /dsa/home/souleymanesaleya/Student_Exec_Week/Day4/Team4/team3_heath.ipynb
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day4/Team4/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day4/Team5
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day4/Team6
# unhandled file
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/Day4/.ipynb_checkpoints
# root= /dsa/home/souleymanesaleya/Student_Exec_Week/.ipynb_checkpoints

# %%
# DO NOT RUN UNLESS YOU NEED A RESET
#from whoosh import writing
#writer.commit(mergetype=writing.CLEAR)

# %% [markdown]
# # g) Execute three queries
#
# ## 1

# %%
from whoosh.qparser import QueryParser
from whoosh import scoring

# Get input, convert to unicode
qstr = input("Input a query: ")

print("searching for ",qstr)

####################################
# TODO: Build query parser and parse query
####################################

qp = QueryParser("content", schema=ix.schema)
search_str = qp.parse(qstr)




####################################
# TODO: Search the content field
####################################
#with ix.searcher() as s:
    #results = s.search(qstr)
    #for hit in results:
        #print(hit)  

with ix.searcher() as s:
    results = s.search(search_str)
    for hit in results:
        print(hit)
# Out:
# Input a query: linear
# searching for  linear

# %% [markdown]
# #### <span style="background:yellow">Expected Output</span>
#
#   *  Example output from searching for QueryParser
#
# ```
# Input a qeury: QueryParser
# searching for  QueryParser
# content:queryparser
# Cell 11 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module5/labs/IR_with_Python_Whoosh.ipynb'
# Cell 27 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module5/answers/ParsingWikipediaLifeformPage.ipynb'
# Cell 25 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb'
# Cell 9 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module6/labs/Text_Search_TFIDF.ipynb'
# Cell 14 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module6/labs/Text_Search_TFIDF.ipynb'
# Cell 17 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module6/labs/Text_Search_TFIDF.ipynb'
# Cell 45 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module6/labs/Topic_modelling.ipynb'
# Cell 7 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module6/answers/TFIDF_Scoring_Practice.ipynb'
# Cell 8 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module6/answers/TFIDF_Scoring_Practice.ipynb'
# Cell 11 of Notebook '/dsa/home/scottgs/sp17DMIR/modules/module5/labs/IR_with_Python_Whoosh.ipynb'
# ```
#
# ---
# ## 2

# %%
# Get input, conver to unicode
qstr = input("Input a query: ")

print("searching for ",qstr)

####################################
# TODO: Build query parser and parse query
####################################
qp = QueryParser("content", schema=ix.schema)
qstr = qp.parse("regression")




####################################
# TODO: Search the content field
####################################
with ix.searcher() as s:
    results = s.search(qstr)
    for hit in results:
        print('Cell ',hit["line_num"],'of Notebook:', hit["filename"])
# Out:
# Input a query: regression
# searching for  regression

# %% [markdown]
# ## 3

# %%
# Get input, conver to unicode
qstr = input("Input a query: ")

print("searching for ",qstr)

####################################
# TODO: Build query parser and parse query
####################################
qp = QueryParser("content", schema=ix.schema)
qstr = qp.parse("classification")






####################################
# TODO: Search the content field
####################################

with ix.searcher() as s:
    results = s.search(qstr)
    for hit in results:
        print('Cell ',hit["line_num"],'of Notebook:', hit["filename"])
# Out:
# Input a query: classification
# searching for  classification

# %% [markdown]
# # SAVE YOUR NOTEBOOK
